# %% [markdown]
# <h3 align="right">hPu, &nbsp; dSPN, &nbsp; 150917_c6_D1, &nbsp; AB5_porta76_cel5 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/AB5_porta76_cel5.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_499.soma.v': 'expdata/ECBL_IV_ch5_499.dat',
    'IV_500.soma.v': 'expdata/ECBL_IV_ch5_500.dat',
    'IV_502.soma.v': 'expdata/ECBL_IV_ch5_502.dat',
    'IV_504.soma.v': 'expdata/ECBL_IV_ch5_504.dat',
    'IV_506.soma.v': 'expdata/ECBL_IV_ch5_506.dat',
    'IV_508.soma.v': 'expdata/ECBL_IV_ch5_508.dat'
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/AB5_porta76_cel5.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -85.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-90, -70]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20
#     q_kir.somatic: ['somatic'] q_kir = 1
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20
#     q_kir.basal: ['basal'] q_kir = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.003054   0.00904  0.007789  0.007946  0.001599    0.0038
# g_pas.somatic    0.0006955 1.474e-05 8.995e-05 1.248e-05 0.0006205 0.0005497
# g_pas.basal      1.009e-05 1.015e-05 1.112e-05  1.06e-05 1.957e-05 1.298e-05
# e_pas.all           -86.59    -87.07    -86.56    -85.49    -85.97     -87.1
# gbar_kir.somatic  0.000667 0.0003823 0.0007547 8.081e-06  0.000151   0.00014
# gbar_kir.basal    1.14e-05 1.664e-05 1.231e-06 7.375e-05 6.547e-05 2.973e-05
#
#                          6         7         8         9
# g_pas.axonal      0.008234  0.008024  0.006861   0.00904
# g_pas.somatic    1.035e-05 0.0001359  0.000221  1.45e-05
# g_pas.basal      1.078e-05 1.009e-05 1.031e-05 1.015e-05
# e_pas.all           -86.36    -87.02    -85.99    -87.07
# gbar_kir.somatic 0.0007664 0.0004386 5.464e-05 0.0003025
# gbar_kir.basal   1.595e-05 1.011e-05 5.855e-05 1.582e-05

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_c041c_row0_col0, #T_c041c_row1_col1, #T_c041c_row2_col2, #T_c041c_row3_col3, #T_c041c_row4_col4, #T_c041c_row5_col5, #T_c041c_row6_col6, #T_c041c_row7_col7, #T_c041c_row8_col8, #T_c041c_row9_col9 {
#   background-color: #007fff;
# }
# #T_c041c_row0_col1 {
#   background-color: #c9e4ff;
# }
# #T_c041c_row0_col2, #T_c041c_row9_col2 {
#   background-color: #c2e0ff;
# }
# #T_c041c_row0_col3, #T_c041c_row2_col4, #T_c041c_row3_col0, #T_c041c_row3_col2, #T_c041c_row3_col5, #T_c041c_row3_col7, #T_c041c_row4_col1, #T_c041c_row4_col6, #T_c041c_row4_col9, #T_c041c_row6_col8 {
#   background-color: #ffffff;
# }
# #T_c041c_row0_col4, #T_c041c_row6_col0 {
#   background-color: #abd5ff;
# }
# #T_c041c_row0_col5 {
#   background-color: #93c8ff;
# }
# #T_c041c_row0_col6, #T_c041c_row8_col3 {
#   background-color: #b8dbff;
# }
# #T_c041c_row0_col7 {
#   background-color: #90c7ff;
# }
# #T_c041c_row0_col8, #T_c041c_row7_col3, #T_c041c_row9_col8 {
#   background-color: #e8f3ff;
# }
# #T_c041c_row0_col9, #T_c041c_row3_col9 {
#   background-color: #cfe7ff;
# }
# #T_c041c_row1_col0, #T_c041c_row4_col8 {
#   background-color: #b1d8ff;
# }
# #T_c041c_row1_col2, #T_c041c_row6_col2 {
#   background-color: #bedeff;
# }
# #T_c041c_row1_col3, #T_c041c_row9_col0, #T_c041c_row9_col3 {
#   background-color: #b5d9ff;
# }
# #T_c041c_row1_col4 {
#   background-color: #e9f4ff;
# }
# #T_c041c_row1_col5 {
#   background-color: #d2e8ff;
# }
# #T_c041c_row1_col6 {
#   background-color: #409fff;
# }
# #T_c041c_row1_col7, #T_c041c_row2_col7 {
#   background-color: #92c8ff;
# }
# #T_c041c_row1_col8 {
#   background-color: #eef6ff;
# }
# #T_c041c_row1_col9, #T_c041c_row9_col1 {
#   background-color: #1589ff;
# }
# #T_c041c_row2_col0 {
#   background-color: #bcddff;
# }
# #T_c041c_row2_col1, #T_c041c_row5_col1 {
#   background-color: #d0e7ff;
# }
# #T_c041c_row2_col3 {
#   background-color: #f7fbff;
# }
# #T_c041c_row2_col5, #T_c041c_row2_col8 {
#   background-color: #fbfdff;
# }
# #T_c041c_row2_col6 {
#   background-color: #c5e2ff;
# }
# #T_c041c_row2_col9 {
#   background-color: #d9ebff;
# }
# #T_c041c_row3_col1 {
#   background-color: #cde5ff;
# }
# #T_c041c_row3_col4 {
#   background-color: #f5faff;
# }
# #T_c041c_row3_col6, #T_c041c_row7_col8 {
#   background-color: #c7e3ff;
# }
# #T_c041c_row3_col8, #T_c041c_row5_col6 {
#   background-color: #d8ebff;
# }
# #T_c041c_row4_col0 {
#   background-color: #a5d1ff;
# }
# #T_c041c_row4_col2 {
#   background-color: #fdfeff;
# }
# #T_c041c_row4_col3 {
#   background-color: #ecf5ff;
# }
# #T_c041c_row4_col5 {
#   background-color: #69b4ff;
# }
# #T_c041c_row4_col7, #T_c041c_row5_col2, #T_c041c_row8_col9 {
#   background-color: #e3f1ff;
# }
# #T_c041c_row5_col0 {
#   background-color: #81bfff;
# }
# #T_c041c_row5_col3 {
#   background-color: #dfefff;
# }
# #T_c041c_row5_col4 {
#   background-color: #60afff;
# }
# #T_c041c_row5_col7 {
#   background-color: #aed6ff;
# }
# #T_c041c_row5_col8 {
#   background-color: #8cc5ff;
# }
# #T_c041c_row5_col9 {
#   background-color: #cee6ff;
# }
# #T_c041c_row6_col1 {
#   background-color: #43a1ff;
# }
# #T_c041c_row6_col3 {
#   background-color: #b9dcff;
# }
# #T_c041c_row6_col4 {
#   background-color: #f6faff;
# }
# #T_c041c_row6_col5 {
#   background-color: #e5f2ff;
# }
# #T_c041c_row6_col7 {
#   background-color: #a0cfff;
# }
# #T_c041c_row6_col9 {
#   background-color: #55a9ff;
# }
# #T_c041c_row7_col0 {
#   background-color: #84c1ff;
# }
# #T_c041c_row7_col1 {
#   background-color: #97cbff;
# }
# #T_c041c_row7_col2 {
#   background-color: #8ac4ff;
# }
# #T_c041c_row7_col4 {
#   background-color: #d7ebff;
# }
# #T_c041c_row7_col5 {
#   background-color: #b5daff;
# }
# #T_c041c_row7_col6 {
#   background-color: #9dcdff;
# }
# #T_c041c_row7_col9 {
#   background-color: #9bcdff;
# }
# #T_c041c_row8_col0 {
#   background-color: #c6e2ff;
# }
# #T_c041c_row8_col1, #T_c041c_row9_col4 {
#   background-color: #e6f2ff;
# }
# #T_c041c_row8_col2 {
#   background-color: #dcedff;
# }
# #T_c041c_row8_col4 {
#   background-color: #9ccdff;
# }
# #T_c041c_row8_col5 {
#   background-color: #88c3ff;
# }
# #T_c041c_row8_col6 {
#   background-color: #e9f3ff;
# }
# #T_c041c_row8_col7 {
#   background-color: #badcff;
# }
# #T_c041c_row9_col5 {
#   background-color: #cce5ff;
# }
# #T_c041c_row9_col6 {
#   background-color: #4fa6ff;
# }
# #T_c041c_row9_col7 {
#   background-color: #94c9ff;
# }
# </style>
# <table id="T_c041c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c041c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c041c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c041c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c041c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c041c_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_c041c_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_c041c_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_c041c_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_c041c_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_c041c_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c041c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c041c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_c041c_row0_col1" class="data row0 col1" >1.130000</td>
#       <td id="T_c041c_row0_col2" class="data row0 col2" >1.200000</td>
#       <td id="T_c041c_row0_col3" class="data row0 col3" >1.620000</td>
#       <td id="T_c041c_row0_col4" class="data row0 col4" >1.050000</td>
#       <td id="T_c041c_row0_col5" class="data row0 col5" >0.820000</td>
#       <td id="T_c041c_row0_col6" class="data row0 col6" >1.090000</td>
#       <td id="T_c041c_row0_col7" class="data row0 col7" >0.840000</td>
#       <td id="T_c041c_row0_col8" class="data row0 col8" >1.260000</td>
#       <td id="T_c041c_row0_col9" class="data row0 col9" >1.150000</td>
#     </tr>
#     <tr>
#       <th id="T_c041c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c041c_row1_col0" class="data row1 col0" >1.130000</td>
#       <td id="T_c041c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c041c_row1_col2" class="data row1 col2" >1.170000</td>
#       <td id="T_c041c_row1_col3" class="data row1 col3" >1.150000</td>
#       <td id="T_c041c_row1_col4" class="data row1 col4" >1.430000</td>
#       <td id="T_c041c_row1_col5" class="data row1 col5" >1.170000</td>
#       <td id="T_c041c_row1_col6" class="data row1 col6" >0.380000</td>
#       <td id="T_c041c_row1_col7" class="data row1 col7" >0.850000</td>
#       <td id="T_c041c_row1_col8" class="data row1 col8" >1.290000</td>
#       <td id="T_c041c_row1_col9" class="data row1 col9" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_c041c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c041c_row2_col0" class="data row2 col0" >1.200000</td>
#       <td id="T_c041c_row2_col1" class="data row2 col1" >1.170000</td>
#       <td id="T_c041c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c041c_row2_col3" class="data row2 col3" >1.570000</td>
#       <td id="T_c041c_row2_col4" class="data row2 col4" >1.560000</td>
#       <td id="T_c041c_row2_col5" class="data row2 col5" >1.400000</td>
#       <td id="T_c041c_row2_col6" class="data row2 col6" >1.170000</td>
#       <td id="T_c041c_row2_col7" class="data row2 col7" >0.850000</td>
#       <td id="T_c041c_row2_col8" class="data row2 col8" >1.360000</td>
#       <td id="T_c041c_row2_col9" class="data row2 col9" >1.200000</td>
#     </tr>
#     <tr>
#       <th id="T_c041c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c041c_row3_col0" class="data row3 col0" >1.620000</td>
#       <td id="T_c041c_row3_col1" class="data row3 col1" >1.150000</td>
#       <td id="T_c041c_row3_col2" class="data row3 col2" >1.570000</td>
#       <td id="T_c041c_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_c041c_row3_col4" class="data row3 col4" >1.500000</td>
#       <td id="T_c041c_row3_col5" class="data row3 col5" >1.420000</td>
#       <td id="T_c041c_row3_col6" class="data row3 col6" >1.180000</td>
#       <td id="T_c041c_row3_col7" class="data row3 col7" >1.480000</td>
#       <td id="T_c041c_

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
e_pas = np.mean([x['e_pas.all'] for x in best_models])
#Ra = np.mean([x['Ra.all'] for x in best_models])
#shift_kir = np.mean([x['shift_kir.somatic'] for x in best_models] + [x['shift_kir.basal'] for x in best_models])

# %%
print(f'{e_pas=}')
# Out:
# e_pas=-86.52096437621086

# %%
best_models[0]['e_pas.all'] #, best_models[0]['shift_kir.somatic']
# Out:
# -86.59039914376213
