# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 160118_c8_D1, &nbsp; animal_5_n27_04102017_cel2 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_5_n27_04102017_cel2.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_546.soma.v': 'expdata/ECall_IV_ch5_546.dat',
    'IV_556.soma.v': 'expdata/ECall_IV_ch5_556.dat',    
    'IDthresh-sub_586.soma.v': 'expdata/ECall_IDthresh_ch5_586.dat',    
    'IDthresh_588.soma.v': 'expdata/ECall_IDthresh_ch5_588.dat',    
    'IDthresh_589.soma.v': 'expdata/ECall_IDthresh_ch5_589.dat',    
    'IDthresh_599.soma.v': 'expdata/ECall_IDthresh_ch5_599.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_5_n27_04102017_cel2.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -91.0
#     g_pas.axonal: ['axonal'] g_pas = [0.0012082189699717276, 0.12082189699717276]
#     g_pas.somatic: ['somatic'] g_pas = [0.00021490099107399413, 0.021490099107399414]
#     g_pas.basal: ['basal'] g_pas = [1.473848645733365e-06, 0.0001473848645733365]
#     e_pas.all: ['all'] e_pas = -89.98487036684676
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 1.0]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.5]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.01]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.00026518973609924345, 0.026518973609924345]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0.0001, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0.0001, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.01, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [4.73627291153198e-05, 0.00473627291153198]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 43
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal        0.1038   0.09896   0.09896   0.09896   0.09364   0.08981
# g_pas.somatic    0.0002163 0.0002167 0.0002167 0.0002151 0.0002211 0.0002167
# g_pas.basal      5.161e-05 5.161e-05 5.161e-05 5.161e-05 5.157e-05 5.161e-05
# gbar_naf.axonal      2.026    0.3625    0.3625     5.063     4.653    0.4286
# gbar_kas.axonal     0.9655    0.8072    0.8072    0.6942    0.7556    0.9474
# gbar_Im.axonal    0.006678  0.006039  0.006678  0.003134    0.1297  0.006788
# gbar_naf.somatic     11.51     11.51     11.51     11.51     12.21     11.76
# gbar_kaf.somatic    0.5309    0.5309    0.5309    0.5309    0.5794    0.5309
# gbar_kas.somatic 0.0002555 0.0002555 0.0002555 0.0002222  0.002322 0.0002555
# gbar_kdr.somatic 0.0004561 1.395e-05 1.395e-05 1.395e-05 1.539e-05  0.009989
# gbar_kir.somatic 0.0002731 0.0002699 0.0002732 0.0002732 0.0002652 0.0002732
# gbar_bk.somatic  0.0002474 0.0003482 0.0003194 0.0003194 0.0003142 0.0001135
# gbar_sk.somatic  0.0005722 0.0005722 0.0005722 0.0005205 0.0007396  0.000187
# gbar_Im.somatic   0.001156  0.001133  0.001609  0.001887   0.00202  0.001609
# gbar_naf.basal     0.07682   0.08381   0.07682   0.07556   0.08527   0.08491
# gbar_kaf.basal     0.02238   0.02238   0.02238   0.02181   0.01628   0.01819
# gbar_kas.basal   8.981e-05 8.981e-05 8.981e-05 8.981e-05 3.854e-05 8.981e-05
# gbar_kdr.basal   0.0001495 0.0001495 0.0001495 0.0001707 0.0001775 0.0001364
# gbar_kir.basal   0.0007239 0.0007239 0.0007239 0.0007346 0.0007455 0.0007239
# gbar_bk.basal    1.041e-06 1.653e-07 1.041e-06 1.041e-06 1.041e-06 1.041e-06
# gbar_sk.basal    4.062e-07 3.381e-06 3.381e-06 2.136e-05 1.583e-05 1.961e-05
#
#                          6         7         8         9
# g_pas.axonal       0.07934   0.09364   0.08764   0.08729
# g_pas.somatic    0.0002211 0.0002163 0.0002276  0.000216
# g_pas.basal      5.157e-05 5.157e-05 4.957e-05 4.912e-05
# gbar_naf.axonal      4.653     1.802     4.355     1.802
# gbar_kas.axonal     0.7724    0.7556    0.8272    0.7543
# gbar_Im.axonal      0.1297   0.06258    0.1135   0.06456
# gbar_naf.somatic     12.21     12.21     12.26     12.22
# gbar_kaf.somatic    0.5794    0.5794    0.5794    0.5794
# gbar_kas.somatic  0.003723  0.002322 0.0007227  0.002067
# gbar_kdr.somatic 1.539e-05 1.539e-05 5.918e-06 1.092e-05
# gbar_kir.somatic 0.0002698 0.0002652 0.0007718 0.0002713
# gbar_bk.somatic  0.0001509 0.0003142 0.0003198 0.0002709
# gbar_sk.somatic  0.0007396 0.0007396 0.0005418 0.0007657
# gbar_Im.somatic    0.00202   0.00202   0.00125  0.001929
# gbar_naf.basal     0.08527   0.08527   0.09404   0.08127
# gbar_kaf.basal     0.01252   0.01842   0.01632    0.0178
# gbar_kas.basal   0.0003303 4.814e-05 6.808e-05 4.814e-05
# gbar_kdr.basal   0.0001854 0.0001182  0.001013 0.0001182
# gbar_kir.basal   0.0007455 0.0007455  0.000748 0.0007455
# gbar_bk.basal    1.041e-06 1.041e-06 3.794e-07 1.093e-06
# gbar_sk.basal    2.029e-05 1.583e-05  8.33e-06 1.583e-05

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0 # 7
test_parameters = best_models[ind]
#test_parameters

# %%
"""
test_parameters = {
 'g_pas.axonal': 0.0522614390490545,
 'g_pas.somatic': 0.0002221356682615811,
 'g_pas.basal': 1.3287393288064948e-05,
 'gbar_naf.axonal': 3.907524123941544*0.9,
 'gbar_kas.axonal': 0.8092026041772808*0.1,
 'gbar_Im.axonal': 0.013798429131281487*0.1,
 'gbar_naf.somatic': 12.05623533339749*0.9,
 'gbar_kaf.somatic': 0.668265014990148*0.9,
 'gbar_kas.somatic': 0.0030085362050084317*0.1,
 'gbar_kdr.somatic': 0.009664403064277816*0.1,
 'gbar_kir.somatic': 0.00026976127926114837,
 'gbar_bk.somatic': 1e-4, #0.0001444071166319357,
 'gbar_sk.somatic': 1e-4, #0.00043876369625630023,
 'gbar_Im.somatic': 0.0015297869825603764*0.1,
 'gbar_naf.basal': 0.05895007515513068,
 'gbar_kaf.basal': 0.011476897881306965,
 'gbar_kas.basal': 0.00022037169668689155,
 'gbar_kdr.basal': 0.00022035482702281975,
 'gbar_kir.basal': 0.0015053518929334666,
 'gbar_bk.basal': 2.3951778068721904e-06,
 'gbar_sk.basal': 1.076578406281162e-05
}
"""
# Out:
# "\ntest_parameters = {\n 'g_pas.axonal': 0.0522614390490545,\n 'g_pas.somatic': 0.0002221356682615811,\n 'g_pas.basal': 1.3287393288064948e-05,\n 'gbar_naf.axonal': 3.907524123941544*0.9,\n 'gbar_kas.axonal': 0.8092026041772808*0.1,\n 'gbar_Im.axonal': 0.013798429131281487*0.1,\n 'gbar_naf.somatic': 12.05623533339749*0.9,\n 'gbar_kaf.somatic': 0.668265014990148*0.9,\n 'gbar_kas.somatic': 0.0030085362050084317*0.1,\n 'gbar_kdr.somatic': 0.009664403064277816*0.1,\n 'gbar_kir.somatic': 0.00026976127926114837,\n 'gbar_bk.somatic': 1e-4, #0.0001444071166319357,\n 'gbar_sk.somatic': 1e-4, #0.00043876369625630023,\n 'gbar_Im.somatic': 0.0015297869825603764*0.1,\n 'gbar_naf.basal': 0.05895007515513068,\n 'gbar_kaf.basal': 0.011476897881306965,\n 'gbar_kas.basal': 0.00022037169668689155,\n 'gbar_kdr.basal': 0.00022035482702281975,\n 'gbar_kir.basal': 0.0015053518929334666,\n 'gbar_bk.basal': 2.3951778068721904e-06,\n 'gbar_sk.basal': 1.076578406281162e-05\n}\n"

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_cb9fa_row0_col0, #T_cb9fa_row1_col1, #T_cb9fa_row2_col2, #T_cb9fa_row3_col3, #T_cb9fa_row4_col4, #T_cb9fa_row5_col5, #T_cb9fa_row6_col6, #T_cb9fa_row7_col7, #T_cb9fa_row8_col8, #T_cb9fa_row9_col9 {
#   background-color: #007fff;
# }
# #T_cb9fa_row0_col1 {
#   background-color: #cae4ff;
# }
# #T_cb9fa_row0_col2 {
#   background-color: #c5e1ff;
# }
# #T_cb9fa_row0_col3 {
#   background-color: #edf6ff;
# }
# #T_cb9fa_row0_col4 {
#   background-color: #f8fbff;
# }
# #T_cb9fa_row0_col5 {
#   background-color: #c5e2ff;
# }
# #T_cb9fa_row0_col6, #T_cb9fa_row0_col9, #T_cb9fa_row5_col4, #T_cb9fa_row5_col7, #T_cb9fa_row5_col8, #T_cb9fa_row5_col9, #T_cb9fa_row6_col0, #T_cb9fa_row6_col1, #T_cb9fa_row6_col2, #T_cb9fa_row8_col3, #T_cb9fa_row8_col5 {
#   background-color: #ffffff;
# }
# #T_cb9fa_row0_col7, #T_cb9fa_row1_col6, #T_cb9fa_row5_col6 {
#   background-color: #fcfdff;
# }
# #T_cb9fa_row0_col8 {
#   background-color: #f4f9ff;
# }
# #T_cb9fa_row1_col0 {
#   background-color: #c8e3ff;
# }
# #T_cb9fa_row1_col2 {
#   background-color: #67b2ff;
# }
# #T_cb9fa_row1_col3, #T_cb9fa_row8_col1 {
#   background-color: #dfefff;
# }
# #T_cb9fa_row1_col4, #T_cb9fa_row6_col3 {
#   background-color: #eff7ff;
# }
# #T_cb9fa_row1_col5, #T_cb9fa_row3_col8, #T_cb9fa_row8_col7 {
#   background-color: #c4e1ff;
# }
# #T_cb9fa_row1_col7 {
#   background-color: #ecf5ff;
# }
# #T_cb9fa_row1_col8 {
#   background-color: #d6eaff;
# }
# #T_cb9fa_row1_col9 {
#   background-color: #f0f7ff;
# }
# #T_cb9fa_row2_col0 {
#   background-color: #b3d9ff;
# }
# #T_cb9fa_row2_col1 {
#   background-color: #5faeff;
# }
# #T_cb9fa_row2_col3, #T_cb9fa_row6_col8 {
#   background-color: #bedeff;
# }
# #T_cb9fa_row2_col4, #T_cb9fa_row2_col8 {
#   background-color: #d9ecff;
# }
# #T_cb9fa_row2_col5, #T_cb9fa_row7_col8 {
#   background-color: #add5ff;
# }
# #T_cb9fa_row2_col6, #T_cb9fa_row4_col2 {
#   background-color: #e8f3ff;
# }
# #T_cb9fa_row2_col7 {
#   background-color: #d2e8ff;
# }
# #T_cb9fa_row2_col9 {
#   background-color: #d4e9ff;
# }
# #T_cb9fa_row3_col0 {
#   background-color: #bcddff;
# }
# #T_cb9fa_row3_col1 {
#   background-color: #b2d8ff;
# }
# #T_cb9fa_row3_col2 {
#   background-color: #a5d2ff;
# }
# #T_cb9fa_row3_col4 {
#   background-color: #afd6ff;
# }
# #T_cb9fa_row3_col5 {
#   background-color: #badcff;
# }
# #T_cb9fa_row3_col6 {
#   background-color: #bddeff;
# }
# #T_cb9fa_row3_col7 {
#   background-color: #c0dfff;
# }
# #T_cb9fa_row3_col9 {
#   background-color: #c2e0ff;
# }
# #T_cb9fa_row4_col0, #T_cb9fa_row5_col3 {
#   background-color: #f2f8ff;
# }
# #T_cb9fa_row4_col1 {
#   background-color: #ebf5ff;
# }
# #T_cb9fa_row4_col3 {
#   background-color: #d7ebff;
# }
# #T_cb9fa_row4_col5 {
#   background-color: #f1f8ff;
# }
# #T_cb9fa_row4_col6 {
#   background-color: #73b9ff;
# }
# #T_cb9fa_row4_col7 {
#   background-color: #54a9ff;
# }
# #T_cb9fa_row4_col8 {
#   background-color: #9eceff;
# }
# #T_cb9fa_row4_col9 {
#   background-color: #59acff;
# }
# #T_cb9fa_row5_col0 {
#   background-color: #cbe5ff;
# }
# #T_cb9fa_row5_col1 {
#   background-color: #cce5ff;
# }
# #T_cb9fa_row5_col2, #T_cb9fa_row8_col6 {
#   background-color: #c3e1ff;
# }
# #T_cb9fa_row6_col4 {
#   background-color: #76baff;
# }
# #T_cb9fa_row6_col5, #T_cb9fa_row8_col2 {
#   background-color: #f5faff;
# }
# #T_cb9fa_row6_col7, #T_cb9fa_row6_col9 {
#   background-color: #95caff;
# }
# #T_cb9fa_row7_col0, #T_cb9fa_row9_col0 {
#   background-color: #e4f1ff;
# }
# #T_cb9fa_row7_col1 {
#   background-color: #d8ebff;
# }
# #T_cb9fa_row7_col2, #T_cb9fa_row9_col2 {
#   background-color: #d1e8ff;
# }
# #T_cb9fa_row7_col3, #T_cb9fa_row9_col3 {
#   background-color: #dcedff;
# }
# #T_cb9fa_row7_col4 {
#   background-color: #4ea6ff;
# }
# #T_cb9fa_row7_col5 {
#   background-color: #e0efff;
# }
# #T_cb9fa_row7_col6 {
#   background-color: #87c3ff;
# }
# #T_cb9fa_row7_col9, #T_cb9fa_row9_col7 {
#   background-color: #1d8dff;
# }
# #T_cb9fa_row8_col0 {
#   background-color: #fbfdff;
# }
# #T_cb9fa_row8_col4 {
#   background-color: #a7d3ff;
# }
# #T_cb9fa_row8_col9 {
#   background-color: #bfdfff;
# }
# #T_cb9fa_row9_col1 {
#   background-color: #daecff;
# }
# #T_cb9fa_row9_col4 {
#   background-color: #52a8ff;
# }
# #T_cb9fa_row9_col5 {
#   background-color: #deeeff;
# }
# #T_cb9fa_row9_col6 {
#   background-color: #86c2ff;
# }
# #T_cb9fa_row9_col8 {
#   background-color: #a7d2ff;
# }
# </style>
# <table id="T_cb9fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb9fa_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cb9fa_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cb9fa_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cb9fa_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cb9fa_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_cb9fa_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_cb9fa_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_cb9fa_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_cb9fa_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_cb9fa_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb9fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb9fa_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_cb9fa_row0_col1" class="data row0 col1" >1.600000</td>
#       <td id="T_cb9fa_row0_col2" class="data row0 col2" >1.430000</td>
#       <td id="T_cb9fa_row0_col3" class="data row0 col3" >1.500000</td>
#       <td id="T_cb9fa_row0_col4" class="data row0 col4" >1.930000</td>
#       <td id="T_cb9fa_row0_col5" class="data row0 col5" >1.620000</td>
#       <td id="T_cb9fa_row0_col6" class="data row0 col6" >2.030000</td>
#       <td id="T_cb9fa_row0_col7" class="data row0 col7" >1.820000</td>
#       <td id="T_cb9fa_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_cb9fa_row0_col9" class="data row0 col9" >1.820000</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb9fa_row1_col0" class="data row1 col0" >1.600000</td>
#       <td id="T_cb9fa_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cb9fa_row1_col2" class="data row1 col2" >0.750000</td>
#       <td id="T_cb9fa_row1_col3" class="data row1 col3" >1.410000</td>
#       <td id="T_cb9fa_row1_col4" class="data row1 col4" >1.860000</td>
#       <td id="T_cb9fa_row1_col5" class="data row1 col5" >1.610000</td>
#       <td id="T_cb9fa_row1_col6" class="data row1 col6" >2.010000</td>
#       <td id="T_cb9fa_row1_col7" class="data row1 col7" >1.710000</td>
#       <td id="T_cb9fa_row1_col8" class="data row1 col8" >1.760000</td>
#       <td id="T_cb9fa_row1_col9" class="data row1 col9" >1.720000</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb9fa_row2_col0" class="data row2 col0" >1.430000</td>
#       <td id="T_cb9fa_row2_col1" class="data row2 col1" >0.750000</td>
#       <td id="T_cb9fa_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cb9fa_row2_col3" class="data row2 col3" >1.200000</td>
#       <td id="T_cb9fa_row2_col4" class="data row2 col4" >1.690000</td>
#       <td id="T_cb9fa_row2_col5" class="data row2 col5" >1.420000</td>
#       <td id="T_cb9fa_row2_col6" class="data row2 col6" >1.850000</td>
#       <td id="T_cb9fa_row2_col7" class="data row2 col7" >1.520000</td>
#       <td id="T_cb9fa_row2_col8" class="data row2 col8" >1.780000</td>
#       <td id="T_cb9fa_row2_col9" class="data row2 col9" >1.520000</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb9fa_row3_col0" class="data row3 col0" >1.500000</td>
#       <td id="T_cb9fa_row3_col1" class="data row3 col1" >1.410000</td>
#       <td id="T_cb9fa_row3_col2" class="data row3 col2" >1.200000</td>
#       <td id="T_cb9fa_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cb9fa_row3_col4" class="data row3 col4" >1.360000</td>
#       <td id="T_cb9fa_row3_col5" class="data row3 col5" >1.530000</td>
#       <td id="T_cb9fa_row3_col6" class="data row3 col6" >1.510000</td>
#       <td id="T_cb9fa_row3_col7" class="data row3 col7" >1.390000</td>
#       <td id="T_cb9fa_

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
zscores = pandas.DataFrame(best_objectives).mean(axis=1)
print(f'Z-score mean {zscores.mean():.3f}, range {zscores.min():.3f}-{zscores.max():.3f}')
# Out:
# Z-score mean 3.308, range 2.869-3.621
