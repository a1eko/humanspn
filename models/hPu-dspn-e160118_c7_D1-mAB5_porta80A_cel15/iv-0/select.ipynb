# %% [markdown]
# <h3 align="right">hPu, &nbsp; dSPN, &nbsp; 160118_c7_D1, &nbsp; AB5_porta80A_cel15 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/AB5_porta80A_cel15.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_546.soma.v': 'expdata/ECall_IV_ch3_546.dat',
    'IV_548.soma.v': 'expdata/ECall_IV_ch3_548.dat',
    'IV_550.soma.v': 'expdata/ECall_IV_ch3_550.dat',
    'IV_552.soma.v': 'expdata/ECall_IV_ch3_552.dat',
    'IV_554.soma.v': 'expdata/ECall_IV_ch3_554.dat',
    'IV_556.soma.v': 'expdata/ECall_IV_ch3_556.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/AB5_porta80A_cel15.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -90.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-80, -60]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20
#     q_kir.somatic: ['somatic'] q_kir = 1
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20
#     q_kir.basal: ['basal'] q_kir = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.003419  0.003419   0.01274   0.01015  0.003419   0.01543
# g_pas.somatic    0.0003216 0.0003216  1.65e-05 8.037e-05 0.0003216 1.042e-05
# g_pas.basal      8.847e-05 8.847e-05 6.994e-05 7.257e-05 8.334e-05 7.242e-05
# e_pas.all           -77.31    -77.33    -77.66    -77.38     -76.9    -79.89
# gbar_kir.somatic 0.0001428 0.0001428 6.449e-07 9.739e-06 9.457e-05 3.485e-05
# gbar_kir.basal   0.0004264 0.0004264 0.0004218 0.0004264 0.0004264 0.0003703
#
#                          6         7         8         9
# g_pas.axonal       0.01099   0.01408    0.0148   0.01462
# g_pas.somatic    1.044e-05 2.711e-05 1.015e-05 1.036e-05
# g_pas.basal      6.994e-05 5.679e-05 5.678e-05  5.66e-05
# e_pas.all           -75.18    -76.58    -76.73    -76.55
# gbar_kir.somatic  2.44e-05 6.616e-05 5.321e-05 8.129e-05
# gbar_kir.basal   0.0004788 0.0004219 0.0004215 0.0004214

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_816aa_row0_col0, #T_816aa_row0_col1, #T_816aa_row1_col0, #T_816aa_row1_col1, #T_816aa_row2_col2, #T_816aa_row3_col3, #T_816aa_row4_col4, #T_816aa_row5_col5, #T_816aa_row6_col6, #T_816aa_row7_col7, #T_816aa_row8_col8, #T_816aa_row9_col9 {
#   background-color: #007fff;
# }
# #T_816aa_row0_col2, #T_816aa_row0_col3, #T_816aa_row0_col5, #T_816aa_row0_col6, #T_816aa_row0_col7, #T_816aa_row0_col8, #T_816aa_row0_col9, #T_816aa_row1_col2, #T_816aa_row1_col3, #T_816aa_row1_col5, #T_816aa_row1_col6, #T_816aa_row1_col7, #T_816aa_row1_col8, #T_816aa_row1_col9, #T_816aa_row2_col0, #T_816aa_row2_col1, #T_816aa_row2_col4, #T_816aa_row4_col2 {
#   background-color: #ffffff;
# }
# #T_816aa_row0_col4, #T_816aa_row1_col4, #T_816aa_row4_col0, #T_816aa_row4_col1 {
#   background-color: #2491ff;
# }
# #T_816aa_row2_col3 {
#   background-color: #eff7ff;
# }
# #T_816aa_row2_col5, #T_816aa_row3_col4, #T_816aa_row7_col0, #T_816aa_row7_col1 {
#   background-color: #c5e2ff;
# }
# #T_816aa_row2_col6, #T_816aa_row3_col5 {
#   background-color: #c1e0ff;
# }
# #T_816aa_row2_col7 {
#   background-color: #e6f2ff;
# }
# #T_816aa_row2_col8, #T_816aa_row3_col7 {
#   background-color: #cfe7ff;
# }
# #T_816aa_row2_col9 {
#   background-color: #dcedff;
# }
# #T_816aa_row3_col0, #T_816aa_row3_col1 {
#   background-color: #cce5ff;
# }
# #T_816aa_row3_col2 {
#   background-color: #c0dfff;
# }
# #T_816aa_row3_col6 {
#   background-color: #add6ff;
# }
# #T_816aa_row3_col8 {
#   background-color: #d9ecff;
# }
# #T_816aa_row3_col9, #T_816aa_row4_col8 {
#   background-color: #f2f8ff;
# }
# #T_816aa_row4_col3, #T_816aa_row4_col9 {
#   background-color: #f6faff;
# }
# #T_816aa_row4_col5, #T_816aa_row4_col6 {
#   background-color: #f3f9ff;
# }
# #T_816aa_row4_col7 {
#   background-color: #f1f8ff;
# }
# #T_816aa_row5_col0, #T_816aa_row5_col1, #T_816aa_row6_col0, #T_816aa_row6_col1 {
#   background-color: #e1f0ff;
# }
# #T_816aa_row5_col2 {
#   background-color: #aed6ff;
# }
# #T_816aa_row5_col3 {
#   background-color: #d5eaff;
# }
# #T_816aa_row5_col4, #T_816aa_row6_col4 {
#   background-color: #d6eaff;
# }
# #T_816aa_row5_col6, #T_816aa_row6_col5 {
#   background-color: #379aff;
# }
# #T_816aa_row5_col7 {
#   background-color: #7ebeff;
# }
# #T_816aa_row5_col8 {
#   background-color: #3398ff;
# }
# #T_816aa_row5_col9 {
#   background-color: #5aacff;
# }
# #T_816aa_row6_col2 {
#   background-color: #abd4ff;
# }
# #T_816aa_row6_col3 {
#   background-color: #bfdfff;
# }
# #T_816aa_row6_col7 {
#   background-color: #94c9ff;
# }
# #T_816aa_row6_col8 {
#   background-color: #56aaff;
# }
# #T_816aa_row6_col9 {
#   background-color: #7bbcff;
# }
# #T_816aa_row7_col2, #T_816aa_row9_col2 {
#   background-color: #b2d8ff;
# }
# #T_816aa_row7_col3 {
#   background-color: #c8e3ff;
# }
# #T_816aa_row7_col4 {
#   background-color: #badcff;
# }
# #T_816aa_row7_col5 {
#   background-color: #6eb6ff;
# }
# #T_816aa_row7_col6 {
#   background-color: #82c0ff;
# }
# #T_816aa_row7_col8 {
#   background-color: #60afff;
# }
# #T_816aa_row7_col9 {
#   background-color: #63b0ff;
# }
# #T_816aa_row8_col0, #T_816aa_row8_col1 {
#   background-color: #d8ebff;
# }
# #T_816aa_row8_col2 {
#   background-color: #b0d7ff;
# }
# #T_816aa_row8_col3 {
#   background-color: #e7f2ff;
# }
# #T_816aa_row8_col4, #T_816aa_row9_col0, #T_816aa_row9_col1 {
#   background-color: #cee6ff;
# }
# #T_816aa_row8_col5 {
#   background-color: #3197ff;
# }
# #T_816aa_row8_col6, #T_816aa_row9_col5 {
#   background-color: #53a8ff;
# }
# #T_816aa_row8_col7 {
#   background-color: #6ab4ff;
# }
# #T_816aa_row8_col9 {
#   background-color: #2d95ff;
# }
# #T_816aa_row9_col3 {
#   background-color: #f4f9ff;
# }
# #T_816aa_row9_col4 {
#   background-color: #c7e2ff;
# }
# #T_816aa_row9_col6 {
#   background-color: #70b7ff;
# }
# #T_816aa_row9_col7 {
#   background-color: #67b3ff;
# }
# #T_816aa_row9_col8 {
#   background-color: #2b94ff;
# }
# </style>
# <table id="T_816aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_816aa_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_816aa_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_816aa_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_816aa_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_816aa_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_816aa_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_816aa_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_816aa_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_816aa_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_816aa_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_816aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_816aa_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_816aa_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_816aa_row0_col2" class="data row0 col2" >1.460000</td>
#       <td id="T_816aa_row0_col3" class="data row0 col3" >1.170000</td>
#       <td id="T_816aa_row0_col4" class="data row0 col4" >0.210000</td>
#       <td id="T_816aa_row0_col5" class="data row0 col5" >1.290000</td>
#       <td id="T_816aa_row0_col6" class="data row0 col6" >1.290000</td>
#       <td id="T_816aa_row0_col7" class="data row0 col7" >1.130000</td>
#       <td id="T_816aa_row0_col8" class="data row0 col8" >1.240000</td>
#       <td id="T_816aa_row0_col9" class="data row0 col9" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_816aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_816aa_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_816aa_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_816aa_row1_col2" class="data row1 col2" >1.460000</td>
#       <td id="T_816aa_row1_col3" class="data row1 col3" >1.170000</td>
#       <td id="T_816aa_row1_col4" class="data row1 col4" >0.210000</td>
#       <td id="T_816aa_row1_col5" class="data row1 col5" >1.290000</td>
#       <td id="T_816aa_row1_col6" class="data row1 col6" >1.290000</td>
#       <td id="T_816aa_row1_col7" class="data row1 col7" >1.130000</td>
#       <td id="T_816aa_row1_col8" class="data row1 col8" >1.240000</td>
#       <td id="T_816aa_row1_col9" class="data row1 col9" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_816aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_816aa_row2_col0" class="data row2 col0" >1.460000</td>
#       <td id="T_816aa_row2_col1" class="data row2 col1" >1.460000</td>
#       <td id="T_816aa_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_816aa_row2_col3" class="data row2 col3" >1.100000</td>
#       <td id="T_816aa_row2_col4" class="data row2 col4" >1.460000</td>
#       <td id="T_816aa_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_816aa_row2_col6" class="data row2 col6" >0.980000</td>
#       <td id="T_816aa_row2_col7" class="data row2 col7" >1.020000</td>
#       <td id="T_816aa_row2_col8" class="data row2 col8" >1.010000</td>
#       <td id="T_816aa_row2_col9" class="data row2 col9" >1.020000</td>
#     </tr>
#     <tr>
#       <th id="T_816aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_816aa_row3_col0" class="data row3 col0" >1.170000</td>
#       <td id="T_816aa_row3_col1" class="data row3 col1" >1.170000</td>
#       <td id="T_816aa_row3_col2" class="data row3 col2" >1.100000</td>
#       <td id="T_816aa_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_816aa_row3_col4" class="data row3 col4" >1.130000</td>
#       <td id="T_816aa_row3_col5" class="data row3 col5" >0.980000</td>
#       <td id="T_816aa_row3_col6" class="data row3 col6" >0.880000</td>
#       <td id="T_816aa_row3_col7" class="data row3 col7" >0.920000</td>
#       <td id="T_816aa_row3_col8" class="data row3 col8" >1.060000</td>
#       <td id="T_816aa_row3_col9" class="data row3 col9" >1.120000</td>
#     </tr>
#     <tr>
#       <th id="T_816aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_816aa_row4_col0" class="data row4 col0" >0.210000</td>
#       <td id="T_816aa_row4_col1" class="data row4 col1" >0.210000</td>
#       <td id="T_816aa_row4_col2" class="data row4 col2" >1.4

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
e_pas = np.mean([x['e_pas.all'] for x in best_models])
#Ra = np.mean([x['Ra.all'] for x in best_models])
#shift_kir = np.mean([x['shift_kir.somatic'] for x in best_models] + [x['shift_kir.basal'] for x in best_models])

# %%
print(f'{e_pas=}')
# Out:
# e_pas=-77.1507672956405

# %%
best_models[0]['e_pas.all'] #, best_models[0]['shift_kir.somatic']
# Out:
# -77.30867637240773
