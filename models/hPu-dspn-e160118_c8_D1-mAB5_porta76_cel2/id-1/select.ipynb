# %% [markdown]
# <h3 align="right">hPu, &nbsp; dSPN, &nbsp; 160118_c8_D1, &nbsp; AB5_porta76_cel2 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/AB5_porta76_cel2.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_546.soma.v': 'expdata/ECall_IV_ch5_546.dat',
    'IV_556.soma.v': 'expdata/ECall_IV_ch5_556.dat',    
    'IDthresh-sub_586.soma.v': 'expdata/ECall_IDthresh_ch5_586.dat',    
    'IDthresh_588.soma.v': 'expdata/ECall_IDthresh_ch5_588.dat',    
    'IDthresh_589.soma.v': 'expdata/ECall_IDthresh_ch5_589.dat',    
    'IDthresh_599.soma.v': 'expdata/ECall_IDthresh_ch5_599.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/AB5_porta76_cel2.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -92.0
#     g_pas.axonal: ['axonal'] g_pas = [0.0007206949234059816, 0.07206949234059816]
#     g_pas.somatic: ['somatic'] g_pas = [1.0003608117923085e-06, 0.00010003608117923083]
#     g_pas.basal: ['basal'] g_pas = [3.179036398967092e-06, 0.0003179036398967092]
#     e_pas.all: ['all'] e_pas = -89.82041192051048
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 1.0]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.5]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.01]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [1.365748908780371e-07, 1.3657489087803709e-05]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0.0001, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0.0001, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.01, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [2.501146445966681e-05, 0.002501146445966681]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 43
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.007129  0.005808   0.00956  0.001992   0.01485   0.01515
# g_pas.somatic    4.015e-05 4.447e-05 3.818e-05 4.753e-05 9.722e-06 3.317e-05
# g_pas.basal      3.184e-06 1.087e-05 3.184e-06   8.3e-06  3.18e-06 3.181e-06
# gbar_naf.axonal         10     4.814     7.326     5.281    0.1243     3.611
# gbar_kas.axonal      0.324   0.04089   0.05955   0.04397    0.3508   0.04031
# gbar_Im.axonal      0.3361  0.007882    0.3028    0.2169  0.006025  0.004282
# gbar_naf.somatic     16.67        14     13.63        14     13.78     13.79
# gbar_kaf.somatic    0.8181    0.4534    0.3876    0.4362    0.3853    0.3853
# gbar_kas.somatic 2.926e-05  0.001331 1.779e-05 2.195e-05 6.033e-05 7.354e-05
# gbar_kdr.somatic 0.0001007 0.0001204  0.006633  0.006022 0.0007443  0.001102
# gbar_kir.somatic 2.085e-06 2.162e-06 9.936e-06 3.967e-06 7.954e-06 6.305e-06
# gbar_bk.somatic  0.0001063 0.0001022 0.0001083 0.0001176 0.0001063 0.0001025
# gbar_sk.somatic  0.0001118 0.0001235 0.0001003 0.0001002 0.0001754 0.0001857
# gbar_Im.somatic  0.0004186 0.0002198 0.0006387 0.0001505 0.0008104 0.0004778
# gbar_naf.basal     0.07449   0.07059    0.0184   0.05511   0.09079   0.03984
# gbar_kaf.basal     0.01011   0.02166   0.01015   0.02443   0.01001   0.01059
# gbar_kas.basal   2.176e-06 1.726e-07 1.054e-07 1.273e-06 1.245e-07 2.575e-06
# gbar_kdr.basal   0.0002422 0.0002359 0.0002675 0.0001733 0.0001289 0.0003251
# gbar_kir.basal    0.000225 0.0002293 0.0003723 0.0004612 0.0002203 0.0002287
# gbar_bk.basal    2.883e-08 2.569e-07 1.746e-07 1.831e-10 1.251e-08 1.696e-08
# gbar_sk.basal    1.895e-07 1.872e-09 1.686e-09 2.388e-09 2.189e-11 3.143e-10
#
#                          6         7         8         9
# g_pas.axonal        0.0145   0.01485  0.009902   0.01471
# g_pas.somatic    3.317e-05 3.202e-06 2.058e-05 1.839e-06
# g_pas.basal      3.181e-06  3.18e-06 3.215e-06 3.934e-06
# gbar_naf.axonal      3.688     1.819     7.461     2.453
# gbar_kas.axonal     0.1083    0.1361    0.1182    0.1325
# gbar_Im.axonal     0.03219    0.0789   0.08039    0.1743
# gbar_naf.somatic     13.79     13.73     13.44     13.28
# gbar_kaf.somatic    0.3909    0.3853    0.3843    0.3044
# gbar_kas.somatic 7.162e-05 7.354e-05  0.001533 6.686e-06
# gbar_kdr.somatic  0.001464 0.0004755 5.302e-05 0.0007802
# gbar_kir.somatic 6.279e-06 3.793e-06 5.606e-06 6.271e-06
# gbar_bk.somatic  0.0001025 0.0001036 0.0001031 0.0001336
# gbar_sk.somatic  0.0001782 0.0001498 0.0001016 0.0001455
# gbar_Im.somatic  0.0004776  0.001142 0.0008703 0.0008085
# gbar_naf.basal     0.03984   0.04419   0.03652   0.03755
# gbar_kaf.basal     0.01003   0.01002      0.01   0.01036
# gbar_kas.basal   1.019e-06 1.686e-06 1.318e-07  1.46e-07
# gbar_kdr.basal   0.0003251 0.0001394 0.0002459 0.0002433
# gbar_kir.basal   0.0002287 0.0002287 0.0003658 0.0002611
# gbar_bk.basal    1.691e-08 7.196e-09 2.321e-08 2.189e-08
# gbar_sk.basal    3.137e-10 1.516e-10  1.09e-10  3.25e-10

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_5dc0b_row0_col0, #T_5dc0b_row1_col1, #T_5dc0b_row2_col2, #T_5dc0b_row3_col3, #T_5dc0b_row4_col4, #T_5dc0b_row5_col5, #T_5dc0b_row6_col6, #T_5dc0b_row7_col7, #T_5dc0b_row8_col8, #T_5dc0b_row9_col9 {
#   background-color: #007fff;
# }
# #T_5dc0b_row0_col1 {
#   background-color: #e8f3ff;
# }
# #T_5dc0b_row0_col2, #T_5dc0b_row8_col3 {
#   background-color: #e3f1ff;
# }
# #T_5dc0b_row0_col3, #T_5dc0b_row1_col8, #T_5dc0b_row5_col9 {
#   background-color: #c8e3ff;
# }
# #T_5dc0b_row0_col4, #T_5dc0b_row5_col1, #T_5dc0b_row5_col2 {
#   background-color: #d7ebff;
# }
# #T_5dc0b_row0_col5, #T_5dc0b_row9_col0 {
#   background-color: #f0f7ff;
# }
# #T_5dc0b_row0_col6, #T_5dc0b_row4_col5 {
#   background-color: #e1f0ff;
# }
# #T_5dc0b_row0_col7 {
#   background-color: #d0e7ff;
# }
# #T_5dc0b_row0_col8, #T_5dc0b_row8_col2 {
#   background-color: #cee6ff;
# }
# #T_5dc0b_row0_col9, #T_5dc0b_row2_col0, #T_5dc0b_row8_col5 {
#   background-color: #eaf4ff;
# }
# #T_5dc0b_row1_col0 {
#   background-color: #f9fcff;
# }
# #T_5dc0b_row1_col2, #T_5dc0b_row7_col3 {
#   background-color: #dbecff;
# }
# #T_5dc0b_row1_col3 {
#   background-color: #c6e2ff;
# }
# #T_5dc0b_row1_col4 {
#   background-color: #e5f2ff;
# }
# #T_5dc0b_row1_col5 {
#   background-color: #f8fbff;
# }
# #T_5dc0b_row1_col6, #T_5dc0b_row1_col7, #T_5dc0b_row1_col9, #T_5dc0b_row3_col4, #T_5dc0b_row3_col5, #T_5dc0b_row3_col8, #T_5dc0b_row4_col0, #T_5dc0b_row4_col2, #T_5dc0b_row4_col3, #T_5dc0b_row7_col1 {
#   background-color: #ffffff;
# }
# #T_5dc0b_row2_col1 {
#   background-color: #d2e8ff;
# }
# #T_5dc0b_row2_col3 {
#   background-color: #a8d3ff;
# }
# #T_5dc0b_row2_col4, #T_5dc0b_row2_col6, #T_5dc0b_row4_col6, #T_5dc0b_row6_col1 {
#   background-color: #deeeff;
# }
# #T_5dc0b_row2_col5 {
#   background-color: #eff7ff;
# }
# #T_5dc0b_row2_col7, #T_5dc0b_row3_col0 {
#   background-color: #ecf5ff;
# }
# #T_5dc0b_row2_col8 {
#   background-color: #cae4ff;
# }
# #T_5dc0b_row2_col9 {
#   background-color: #c2e0ff;
# }
# #T_5dc0b_row3_col1, #T_5dc0b_row9_col3 {
#   background-color: #daecff;
# }
# #T_5dc0b_row3_col2, #T_5dc0b_row7_col8, #T_5dc0b_row8_col4, #T_5dc0b_row9_col2 {
#   background-color: #c1e0ff;
# }
# #T_5dc0b_row3_col6 {
#   background-color: #f2f8ff;
# }
# #T_5dc0b_row3_col7 {
#   background-color: #f1f8ff;
# }
# #T_5dc0b_row3_col9 {
#   background-color: #fbfdff;
# }
# #T_5dc0b_row4_col1 {
#   background-color: #fdfeff;
# }
# #T_5dc0b_row4_col7 {
#   background-color: #bcddff;
# }
# #T_5dc0b_row4_col8, #T_5dc0b_row8_col0 {
#   background-color: #d9ecff;
# }
# #T_5dc0b_row4_col9, #T_5dc0b_row6_col0 {
#   background-color: #d3e9ff;
# }
# #T_5dc0b_row5_col0, #T_5dc0b_row7_col0 {
#   background-color: #e0efff;
# }
# #T_5dc0b_row5_col3 {
#   background-color: #c9e3ff;
# }
# #T_5dc0b_row5_col4 {
#   background-color: #b1d8ff;
# }
# #T_5dc0b_row5_col6 {
#   background-color: #71b7ff;
# }
# #T_5dc0b_row5_col7 {
#   background-color: #a5d1ff;
# }
# #T_5dc0b_row5_col8 {
#   background-color: #cfe7ff;
# }
# #T_5dc0b_row6_col2, #T_5dc0b_row8_col6 {
#   background-color: #c9e4ff;
# }
# #T_5dc0b_row6_col3 {
#   background-color: #c0dfff;
# }
# #T_5dc0b_row6_col4 {
#   background-color: #afd7ff;
# }
# #T_5dc0b_row6_col5 {
#   background-color: #71b8ff;
# }
# #T_5dc0b_row6_col7 {
#   background-color: #8bc4ff;
# }
# #T_5dc0b_row6_col8 {
#   background-color: #b3d9ff;
# }
# #T_5dc0b_row6_col9 {
#   background-color: #aed6ff;
# }
# #T_5dc0b_row7_col2 {
#   background-color: #f5faff;
# }
# #T_5dc0b_row7_col4 {
#   background-color: #abd5ff;
# }
# #T_5dc0b_row7_col5, #T_5dc0b_row9_col6 {
#   background-color: #bedeff;
# }
# #T_5dc0b_row7_col6 {
#   background-color: #9fcfff;
# }
# #T_5dc0b_row7_col9 {
#   background-color: #9dceff;
# }
# #T_5dc0b_row8_col1 {
#   background-color: #c4e1ff;
# }
# #T_5dc0b_row8_col7 {
#   background-color: #bddeff;
# }
# #T_5dc0b_row8_col9 {
#   background-color: #badcff;
# }
# #T_5dc0b_row9_col1 {
#   background-color: #f3f9ff;
# }
# #T_5dc0b_row9_col4 {
#   background-color: #b7daff;
# }
# #T_5dc0b_row9_col5 {
#   background-color: #dbedff;
# }
# #T_5dc0b_row9_col7 {
#   background-color: #96caff;
# }
# #T_5dc0b_row9_col8 {
#   background-color: #b5daff;
# }
# </style>
# <table id="T_5dc0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dc0b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5dc0b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5dc0b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_5dc0b_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_5dc0b_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_5dc0b_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_5dc0b_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_5dc0b_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_5dc0b_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_5dc0b_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dc0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dc0b_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_5dc0b_row0_col1" class="data row0 col1" >2.350000</td>
#       <td id="T_5dc0b_row0_col2" class="data row0 col2" >2.210000</td>
#       <td id="T_5dc0b_row0_col3" class="data row0 col3" >2.230000</td>
#       <td id="T_5dc0b_row0_col4" class="data row0 col4" >2.400000</td>
#       <td id="T_5dc0b_row0_col5" class="data row0 col5" >2.110000</td>
#       <td id="T_5dc0b_row0_col6" class="data row0 col6" >1.990000</td>
#       <td id="T_5dc0b_row0_col7" class="data row0 col7" >2.110000</td>
#       <td id="T_5dc0b_row0_col8" class="data row0 col8" >2.050000</td>
#       <td id="T_5dc0b_row0_col9" class="data row0 col9" >2.260000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5dc0b_row1_col0" class="data row1 col0" >2.350000</td>
#       <td id="T_5dc0b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_5dc0b_row1_col2" class="data row1 col2" >2.130000</td>
#       <td id="T_5dc0b_row1_col3" class="data row1 col3" >2.210000</td>
#       <td id="T_5dc0b_row1_col4" class="data row1 col4" >2.560000</td>
#       <td id="T_5dc0b_row1_col5" class="data row1 col5" >2.180000</td>
#       <td id="T_5dc0b_row1_col6" class="data row1 col6" >2.250000</td>
#       <td id="T_5dc0b_row1_col7" class="data row1 col7" >2.580000</td>
#       <td id="T_5dc0b_row1_col8" class="data row1 col8" >1.990000</td>
#       <td id="T_5dc0b_row1_col9" class="data row1 col9" >2.460000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5dc0b_row2_col0" class="data row2 col0" >2.210000</td>
#       <td id="T_5dc0b_row2_col1" class="data row2 col1" >2.130000</td>
#       <td id="T_5dc0b_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_5dc0b_row2_col3" class="data row2 col3" >1.880000</td>
#       <td id="T_5dc0b_row2_col4" class="data row2 col4" >2.480000</td>
#       <td id="T_5dc0b_row2_col5" class="data row2 col5" >2.100000</td>
#       <td id="T_5dc0b_row2_col6" class="data row2 col6" >1.960000</td>
#       <td id="T_5dc0b_row2_col7" class="data row2 col7" >2.390000</td>
#       <td id="T_5dc0b_row2_col8" class="data row2 col8" >2.010000</td>
#       <td id="T_5dc0b_row2_col9" class="data row2 col9" >1.880000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5dc0b_row3_col0" class="data row3 col0" >2.230000</td>
#       <td id="T_5dc0b_row3_col1" class="data row3 col1" >2.210000</td>
#       <td id="T_5dc0b_row3_col2" class="data row3 col2" >1.880000</td>
#       <td id="T_5dc0b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_5dc0b_row3_col4" class="data row3 col4" >2.840000</td>
#       <td id="T_5dc0b_row3_col5" class="data row3 col5" >2.240000</td>
#       <td id="T_5dc0b_row3_col6" class="data row3 col6" >2.140000</td>
#       <td id="T_5dc0b_row3_col7" class="data row3 col7" >2.440000</td>
#       <td id="T_5dc0b_row3_col8" class="data row3 col8" >2.530000</td>
#       <td id="T_5dc0b_row3_col9" class="data row3 col9" >2.430000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc0b

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
zscores = pandas.DataFrame(best_objectives).mean(axis=1)
print(f'Z-score mean {zscores.mean():.3f}, range {zscores.min():.3f}-{zscores.max():.3f}')
# Out:
# Z-score mean 4.254, range 3.758-4.528
