# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c9_D1, &nbsp; animal_1_n27_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n27_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_505.soma.v': 'expdata/ECBL_IV_ch1_505.dat',
    'IV_507.soma.v': 'expdata/ECBL_IV_ch1_507.dat',
    'IV_509.soma.v': 'expdata/ECBL_IV_ch1_509.dat',
    'IV_511.soma.v': 'expdata/ECBL_IV_ch1_511.dat',
    'IV_513.soma.v': 'expdata/ECBL_IV_ch1_513.dat',
    'IV_515.soma.v': 'expdata/ECBL_IV_ch1_515.dat',
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n27_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -85.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-90, -50]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20
#     q_kir.somatic: ['somatic'] q_kir = 1
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20
#     q_kir.basal: ['basal'] q_kir = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.005827   0.01235  0.005789  0.005873  0.009002  0.003758
# g_pas.somatic     0.002116  0.001311  0.002485  0.002741  0.002646  0.002124
# g_pas.basal       0.000114 0.0001398 8.207e-05 6.515e-05 5.017e-05 0.0001181
# e_pas.all           -81.99    -87.17    -88.13    -81.37    -89.91    -88.41
# gbar_kir.somatic  0.007711  0.008718   0.00536  0.007071  0.006961  0.004896
# gbar_kir.basal   0.0004467 7.072e-05 0.0002278 0.0005154  3.41e-05 0.0002519
#
#                          6         7         8         9
# g_pas.axonal       0.01232  0.007913   0.01232    0.0183
# g_pas.somatic     0.001478  0.001762  0.001478  0.002707
# g_pas.basal      0.0001181  0.000197 0.0001181 1.618e-05
# e_pas.all           -88.49    -80.45    -88.74    -86.15
# gbar_kir.somatic  0.004905  0.007357  0.004905  0.004862
# gbar_kir.basal   0.0002519 0.0005227 0.0002519 0.0003109

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_7b840_row0_col0, #T_7b840_row1_col1, #T_7b840_row2_col2, #T_7b840_row3_col3, #T_7b840_row4_col4, #T_7b840_row5_col5, #T_7b840_row6_col6, #T_7b840_row6_col8, #T_7b840_row7_col7, #T_7b840_row8_col6, #T_7b840_row8_col8, #T_7b840_row9_col9 {
#   background-color: #007fff;
# }
# #T_7b840_row0_col1, #T_7b840_row2_col4, #T_7b840_row3_col9 {
#   background-color: #c1e0ff;
# }
# #T_7b840_row0_col2 {
#   background-color: #79bcff;
# }
# #T_7b840_row0_col3 {
#   background-color: #4fa7ff;
# }
# #T_7b840_row0_col4 {
#   background-color: #e5f1ff;
# }
# #T_7b840_row0_col5 {
#   background-color: #69b3ff;
# }
# #T_7b840_row0_col6, #T_7b840_row0_col8, #T_7b840_row7_col3 {
#   background-color: #92c8ff;
# }
# #T_7b840_row0_col7 {
#   background-color: #4da6ff;
# }
# #T_7b840_row0_col9, #T_7b840_row9_col3 {
#   background-color: #daecff;
# }
# #T_7b840_row1_col0 {
#   background-color: #dfefff;
# }
# #T_7b840_row1_col2, #T_7b840_row4_col3, #T_7b840_row4_col9 {
#   background-color: #eaf4ff;
# }
# #T_7b840_row1_col3, #T_7b840_row1_col9, #T_7b840_row4_col0, #T_7b840_row4_col6, #T_7b840_row4_col7, #T_7b840_row4_col8, #T_7b840_row7_col4, #T_7b840_row9_col1, #T_7b840_row9_col2, #T_7b840_row9_col5 {
#   background-color: #ffffff;
# }
# #T_7b840_row1_col4 {
#   background-color: #a5d1ff;
# }
# #T_7b840_row1_col5 {
#   background-color: #d7eaff;
# }
# #T_7b840_row1_col6, #T_7b840_row1_col8 {
#   background-color: #add6ff;
# }
# #T_7b840_row1_col7, #T_7b840_row2_col9, #T_7b840_row5_col1 {
#   background-color: #c3e1ff;
# }
# #T_7b840_row2_col0 {
#   background-color: #6bb5ff;
# }
# #T_7b840_row2_col1 {
#   background-color: #b3d9ff;
# }
# #T_7b840_row2_col3, #T_7b840_row5_col0 {
#   background-color: #6eb6ff;
# }
# #T_7b840_row2_col5 {
#   background-color: #4ba4ff;
# }
# #T_7b840_row2_col6, #T_7b840_row2_col8 {
#   background-color: #82c0ff;
# }
# #T_7b840_row2_col7 {
#   background-color: #97caff;
# }
# #T_7b840_row3_col0 {
#   background-color: #51a7ff;
# }
# #T_7b840_row3_col1 {
#   background-color: #e1f0ff;
# }
# #T_7b840_row3_col2 {
#   background-color: #7fbfff;
# }
# #T_7b840_row3_col4 {
#   background-color: #d6eaff;
# }
# #T_7b840_row3_col5 {
#   background-color: #89c4ff;
# }
# #T_7b840_row3_col6, #T_7b840_row3_col8 {
#   background-color: #b5daff;
# }
# #T_7b840_row3_col7 {
#   background-color: #86c2ff;
# }
# #T_7b840_row4_col1 {
#   background-color: #9fceff;
# }
# #T_7b840_row4_col2, #T_7b840_row9_col4 {
#   background-color: #f3f9ff;
# }
# #T_7b840_row4_col5 {
#   background-color: #f4f9ff;
# }
# #T_7b840_row5_col2 {
#   background-color: #58abff;
# }
# #T_7b840_row5_col3, #T_7b840_row5_col7, #T_7b840_row6_col0, #T_7b840_row8_col0 {
#   background-color: #8dc6ff;
# }
# #T_7b840_row5_col4 {
#   background-color: #e7f3ff;
# }
# #T_7b840_row5_col6, #T_7b840_row5_col8 {
#   background-color: #97cbff;
# }
# #T_7b840_row5_col9 {
#   background-color: #e8f3ff;
# }
# #T_7b840_row6_col1, #T_7b840_row8_col1 {
#   background-color: #91c8ff;
# }
# #T_7b840_row6_col2, #T_7b840_row8_col2 {
#   background-color: #8ec6ff;
# }
# #T_7b840_row6_col3, #T_7b840_row8_col3 {
#   background-color: #acd5ff;
# }
# #T_7b840_row6_col4, #T_7b840_row8_col4 {
#   background-color: #ddeeff;
# }
# #T_7b840_row6_col5, #T_7b840_row8_col5 {
#   background-color: #8cc5ff;
# }
# #T_7b840_row6_col7, #T_7b840_row8_col7 {
#   background-color: #7dbdff;
# }
# #T_7b840_row6_col9, #T_7b840_row8_col9 {
#   background-color: #bfdeff;
# }
# #T_7b840_row7_col0 {
#   background-color: #56aaff;
# }
# #T_7b840_row7_col1 {
#   background-color: #bcddff;
# }
# #T_7b840_row7_col2 {
#   background-color: #bddeff;
# }
# #T_7b840_row7_col5 {
#   background-color: #96caff;
# }
# #T_7b840_row7_col6, #T_7b840_row7_col8 {
#   background-color: #8fc7ff;
# }
# #T_7b840_row7_col9 {
#   background-color: #e5f2ff;
# }
# #T_7b840_row9_col0 {
#   background-color: #fcfdff;
# }
# #T_7b840_row9_col6, #T_7b840_row9_col8 {
#   background-color: #e3f1ff;
# }
# #T_7b840_row9_col7 {
#   background-color: #eef6ff;
# }
# </style>
# <table id="T_7b840">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b840_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7b840_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7b840_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7b840_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_7b840_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_7b840_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_7b840_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_7b840_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_7b840_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_7b840_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b840_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b840_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_7b840_row0_col1" class="data row0 col1" >0.850000</td>
#       <td id="T_7b840_row0_col2" class="data row0 col2" >0.410000</td>
#       <td id="T_7b840_row0_col3" class="data row0 col3" >0.310000</td>
#       <td id="T_7b840_row0_col4" class="data row0 col4" >0.970000</td>
#       <td id="T_7b840_row0_col5" class="data row0 col5" >0.420000</td>
#       <td id="T_7b840_row0_col6" class="data row0 col6" >0.540000</td>
#       <td id="T_7b840_row0_col7" class="data row0 col7" >0.330000</td>
#       <td id="T_7b840_row0_col8" class="data row0 col8" >0.540000</td>
#       <td id="T_7b840_row0_col9" class="data row0 col9" >0.960000</td>
#     </tr>
#     <tr>
#       <th id="T_7b840_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b840_row1_col0" class="data row1 col0" >0.850000</td>
#       <td id="T_7b840_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_7b840_row1_col2" class="data row1 col2" >0.790000</td>
#       <td id="T_7b840_row1_col3" class="data row1 col3" >0.990000</td>
#       <td id="T_7b840_row1_col4" class="data row1 col4" >0.700000</td>
#       <td id="T_7b840_row1_col5" class="data row1 col5" >0.860000</td>
#       <td id="T_7b840_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_7b840_row1_col7" class="data row1 col7" >0.830000</td>
#       <td id="T_7b840_row1_col8" class="data row1 col8" >0.640000</td>
#       <td id="T_7b840_row1_col9" class="data row1 col9" >1.120000</td>
#     </tr>
#     <tr>
#       <th id="T_7b840_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b840_row2_col0" class="data row2 col0" >0.410000</td>
#       <td id="T_7b840_row2_col1" class="data row2 col1" >0.790000</td>
#       <td id="T_7b840_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_7b840_row2_col3" class="data row2 col3" >0.430000</td>
#       <td id="T_7b840_row2_col4" class="data row2 col4" >0.820000</td>
#       <td id="T_7b840_row2_col5" class="data row2 col5" >0.300000</td>
#       <td id="T_7b840_row2_col6" class="data row2 col6" >0.480000</td>
#       <td id="T_7b840_row2_col7" class="data row2 col7" >0.640000</td>
#       <td id="T_7b840_row2_col8" class="data row2 col8" >0.480000</td>
#       <td id="T_7b840_row2_col9" class="data row2 col9" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_7b840_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b840_row3_col0" class="data row3 col0" >0.310000</td>
#       <td id="T_7b840_row3_col1" class="data row3 col1" >0.990000</td>
#       <td id="T_7b840_row3_col2" class="data row3 col2" >0.430000</td>
#       <td id="T_7b840_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_7b840_row3_col4" class="data row3 col4" >0.910000</td>
#       <td id="T_7b840_row3_col5" class="data row3 col5" >0.550000</td>
#       <td id="T_7b840_row3_col6" class="data row3 col6" >0.670000</td>
#       <td id="T_7b840_row3_col7" class="data row3 col7" >0.570000</td>
#       <td id="T_7b840_row3_col8" class="data row3 col8" >0.670000</td>
#       <td id="T_7b840_row3_col9" class="data row3 col9" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_7b840_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b840_row4_col0" class="data row4 col0" >0.970000</td>
#       <td id="T_7b840_row4_col1" cl

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
e_pas = np.mean([x['e_pas.all'] for x in best_models])
#Ra = np.mean([x['Ra.all'] for x in best_models])
#shift_kir = np.mean([x['shift_kir.somatic'] for x in best_models] + [x['shift_kir.basal'] for x in best_models])

# %%
print(f'{e_pas=}')
# Out:
# e_pas=-86.08062169871634

# %%
best_models[0]['e_pas.all'] #, best_models[0]['shift_kir.somatic']
# Out:
# -81.98624647839048
