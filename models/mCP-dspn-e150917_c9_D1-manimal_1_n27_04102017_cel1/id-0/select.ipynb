# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c9_D1, &nbsp; animal_1_n27_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n27_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_507.soma.v': 'expdata/ECBL_IV_ch1_507.dat',
    'IV_511.soma.v': 'expdata/ECBL_IV_ch1_511.dat',    
    'IDthresh-sub_547.soma.v': 'expdata/ECBL_IDthresh_ch1_547.dat',    
    'IDthresh_548.soma.v': 'expdata/ECBL_IDthresh_ch1_548.dat',    
    'IDthresh_550.soma.v': 'expdata/ECBL_IDthresh_ch1_550.dat',    
    'IDthresh_561.soma.v': 'expdata/ECBL_IDthresh_ch1_561.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n27_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -88.24462072341888
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.2]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.2]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.0001, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.005, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 14
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal     7.609e-05  0.002088  0.001556  0.001568 0.0002501  0.001228
# g_pas.somatic    0.0002953 1.814e-05 0.0001925 0.0004936 5.394e-05 4.681e-05
# g_pas.basal      1.251e-05 3.191e-05 1.002e-05 1.017e-05 2.996e-05 3.191e-05
# gbar_naf.axonal      8.534     10.51      7.15     7.551     8.741     8.439
# gbar_kas.axonal     0.1428    0.1085      0.14    0.1241    0.1569    0.1183
# gbar_Im.axonal      0.1315    0.0623   0.08805    0.1451   0.03473   0.07604
# gbar_naf.somatic     12.89     14.02     16.36        18      13.1     14.14
# gbar_kaf.somatic    0.5171    0.1062    0.8305    0.6919      0.26    0.4921
# gbar_kas.somatic  0.003972   0.02674  0.001323 0.0002235  0.005224  0.005702
# gbar_kdr.somatic 0.0007259 7.977e-05 0.0006226 0.0002189  0.001381 0.0007259
# gbar_kir.somatic 0.0001272 0.0001934   0.01122  0.009367 0.0001567 0.0001272
# gbar_bk.somatic  0.0007453 0.0003692 0.0001844  0.001029  0.001301 0.0006775
# gbar_sk.somatic   0.000121 0.0008285 0.0002388 0.0004094  0.000407 0.0001208
# gbar_Im.somatic   0.003995  0.008348  0.006331   0.00783  0.009365   0.00405
# gbar_naf.basal     0.01374   0.01973   0.02188   0.09686   0.00184    0.0158
# gbar_kaf.basal     0.04442   0.05518   0.06077   0.07039    0.0417   0.04719
# gbar_kas.basal    0.002517  0.004304 0.0001539  0.002921  0.007174  0.002731
# gbar_kdr.basal    0.001317 0.0009807 0.0001782 0.0004251 0.0009956  0.001305
# gbar_kir.basal    0.001269 0.0006964 0.0007701 0.0005263  0.000541  0.001262
# gbar_bk.basal    0.0002083 0.0002522 0.0002148  1.39e-06  0.000166 0.0002083
# gbar_sk.basal    3.036e-05 0.0001927  6.47e-06 3.448e-06 0.0001759 7.074e-06
#
#                          6         7         8         9
# g_pas.axonal     0.0003666 6.917e-05 0.0001631    0.0001
# g_pas.somatic    6.052e-05 0.0001574 0.0001075  0.001384
# g_pas.basal      1.215e-05 1.362e-05 1.771e-05 1.034e-05
# gbar_naf.axonal      3.337     8.217     1.622     6.563
# gbar_kas.axonal     0.1759    0.1756    0.1772    0.1543
# gbar_Im.axonal     0.05207    0.0855   0.03565   0.04767
# gbar_naf.somatic      17.1     18.56     14.12     14.68
# gbar_kaf.somatic    0.5515    0.9427    0.3778    0.2832
# gbar_kas.somatic   0.02292  0.001889   0.01202   0.01456
# gbar_kdr.somatic  5.03e-05 5.652e-05 0.0002009  0.000569
# gbar_kir.somatic  0.002181  0.004937   0.01549  0.001283
# gbar_bk.somatic   0.000344 0.0006691 0.0005989 0.0005082
# gbar_sk.somatic  0.0006575 0.0007666 8.508e-05 0.0001815
# gbar_Im.somatic    0.00904  0.007757   0.00943 0.0001844
# gbar_naf.basal     0.07407   0.09595   0.03685   0.01678
# gbar_kaf.basal     0.02912   0.05941   0.04536   0.07221
# gbar_kas.basal    0.005483  0.002558  0.003681 0.0008108
# gbar_kdr.basal   0.0008086   0.00191  0.001049 0.0002895
# gbar_kir.basal   0.0007891  0.001245 0.0001243 0.0003352
# gbar_bk.basal    0.0002787 9.056e-06 6.524e-05 9.874e-05
# gbar_sk.basal    3.489e-05 8.846e-05 1.684e-06 1.912e-06

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)
# Out:
# /home/akozlov/.local/lib/python3.10/site-packages/efel/api.py:340: RuntimeWarning: divide by zero encountered in double_scalars
#   distance = distance / std / len(feature_values)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_b1dfe_row0_col0, #T_b1dfe_row1_col1, #T_b1dfe_row2_col2, #T_b1dfe_row3_col3, #T_b1dfe_row4_col4, #T_b1dfe_row5_col5, #T_b1dfe_row6_col6, #T_b1dfe_row7_col7, #T_b1dfe_row8_col8, #T_b1dfe_row9_col9 {
#   background-color: #007fff;
# }
# #T_b1dfe_row0_col1, #T_b1dfe_row4_col6 {
#   background-color: #dcedff;
# }
# #T_b1dfe_row0_col2 {
#   background-color: #d3e9ff;
# }
# #T_b1dfe_row0_col3, #T_b1dfe_row0_col6 {
#   background-color: #e5f1ff;
# }
# #T_b1dfe_row0_col4 {
#   background-color: #aed6ff;
# }
# #T_b1dfe_row0_col5 {
#   background-color: #93c8ff;
# }
# #T_b1dfe_row0_col7, #T_b1dfe_row3_col2 {
#   background-color: #c6e2ff;
# }
# #T_b1dfe_row0_col8, #T_b1dfe_row1_col7, #T_b1dfe_row6_col0, #T_b1dfe_row6_col2 {
#   background-color: #e4f1ff;
# }
# #T_b1dfe_row0_col9 {
#   background-color: #cce5ff;
# }
# #T_b1dfe_row1_col0, #T_b1dfe_row7_col8 {
#   background-color: #ebf5ff;
# }
# #T_b1dfe_row1_col2, #T_b1dfe_row3_col1 {
#   background-color: #fefeff;
# }
# #T_b1dfe_row1_col3, #T_b1dfe_row3_col6 {
#   background-color: #f3f9ff;
# }
# #T_b1dfe_row1_col4 {
#   background-color: #b2d8ff;
# }
# #T_b1dfe_row1_col5 {
#   background-color: #c4e1ff;
# }
# #T_b1dfe_row1_col6, #T_b1dfe_row7_col6 {
#   background-color: #c1e0ff;
# }
# #T_b1dfe_row1_col8, #T_b1dfe_row3_col0, #T_b1dfe_row3_col4, #T_b1dfe_row4_col2, #T_b1dfe_row4_col3, #T_b1dfe_row7_col5, #T_b1dfe_row7_col9, #T_b1dfe_row9_col1, #T_b1dfe_row9_col6, #T_b1dfe_row9_col7 {
#   background-color: #ffffff;
# }
# #T_b1dfe_row1_col9, #T_b1dfe_row2_col1 {
#   background-color: #fafcff;
# }
# #T_b1dfe_row2_col0, #T_b1dfe_row7_col4, #T_b1dfe_row9_col0 {
#   background-color: #deeeff;
# }
# #T_b1dfe_row2_col3 {
#   background-color: #bbddff;
# }
# #T_b1dfe_row2_col4, #T_b1dfe_row2_col6 {
#   background-color: #f1f8ff;
# }
# #T_b1dfe_row2_col5 {
#   background-color: #d0e7ff;
# }
# #T_b1dfe_row2_col7, #T_b1dfe_row8_col0 {
#   background-color: #e6f2ff;
# }
# #T_b1dfe_row2_col8 {
#   background-color: #f2f8ff;
# }
# #T_b1dfe_row2_col9, #T_b1dfe_row5_col9, #T_b1dfe_row8_col7 {
#   background-color: #daecff;
# }
# #T_b1dfe_row3_col5 {
#   background-color: #f7fbff;
# }
# #T_b1dfe_row3_col7 {
#   background-color: #c7e2ff;
# }
# #T_b1dfe_row3_col8, #T_b1dfe_row4_col8, #T_b1dfe_row4_col9, #T_b1dfe_row7_col2 {
#   background-color: #eef6ff;
# }
# #T_b1dfe_row3_col9 {
#   background-color: #ecf5ff;
# }
# #T_b1dfe_row4_col0, #T_b1dfe_row7_col3 {
#   background-color: #c2e0ff;
# }
# #T_b1dfe_row4_col1 {
#   background-color: #b9dcff;
# }
# #T_b1dfe_row4_col5 {
#   background-color: #badcff;
# }
# #T_b1dfe_row4_col7 {
#   background-color: #e3f1ff;
# }
# #T_b1dfe_row5_col0 {
#   background-color: #92c8ff;
# }
# #T_b1dfe_row5_col1 {
#   background-color: #b7dbff;
# }
# #T_b1dfe_row5_col2 {
#   background-color: #c5e1ff;
# }
# #T_b1dfe_row5_col3, #T_b1dfe_row5_col6, #T_b1dfe_row6_col5, #T_b1dfe_row8_col5 {
#   background-color: #ddeeff;
# }
# #T_b1dfe_row5_col4 {
#   background-color: #a6d2ff;
# }
# #T_b1dfe_row5_col7, #T_b1dfe_row6_col9, #T_b1dfe_row9_col4 {
#   background-color: #e9f4ff;
# }
# #T_b1dfe_row5_col8 {
#   background-color: #dbedff;
# }
# #T_b1dfe_row6_col1 {
#   background-color: #b4d9ff;
# }
# #T_b1dfe_row6_col3 {
#   background-color: #d9ecff;
# }
# #T_b1dfe_row6_col4 {
#   background-color: #c5e2ff;
# }
# #T_b1dfe_row6_col7 {
#   background-color: #b1d7ff;
# }
# #T_b1dfe_row6_col8 {
#   background-color: #cfe7ff;
# }
# #T_b1dfe_row7_col0 {
#   background-color: #d7ebff;
# }
# #T_b1dfe_row7_col1, #T_b1dfe_row8_col2 {
#   background-color: #e8f3ff;
# }
# #T_b1dfe_row8_col1 {
#   background-color: #f0f7ff;
# }
# #T_b1dfe_row8_col3, #T_b1dfe_row8_col4, #T_b1dfe_row9_col8 {
#   background-color: #d8ebff;
# }
# #T_b1dfe_row8_col6 {
#   background-color: #d2e8ff;
# }
# #T_b1dfe_row8_col9 {
#   background-color: #c8e3ff;
# }
# #T_b1dfe_row9_col2 {
#   background-color: #e1f0ff;
# }
# #T_b1dfe_row9_col3 {
#   background-color: #e7f3ff;
# }
# #T_b1dfe_row9_col5 {
#   background-color: #eff7ff;
# }
# </style>
# <table id="T_b1dfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1dfe_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b1dfe_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b1dfe_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b1dfe_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b1dfe_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_b1dfe_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_b1dfe_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_b1dfe_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_b1dfe_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_b1dfe_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1dfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1dfe_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b1dfe_row0_col1" class="data row0 col1" >2.280000</td>
#       <td id="T_b1dfe_row0_col2" class="data row0 col2" >2.160000</td>
#       <td id="T_b1dfe_row0_col3" class="data row0 col3" >2.470000</td>
#       <td id="T_b1dfe_row0_col4" class="data row0 col4" >1.880000</td>
#       <td id="T_b1dfe_row0_col5" class="data row0 col5" >1.420000</td>
#       <td id="T_b1dfe_row0_col6" class="data row0 col6" >2.210000</td>
#       <td id="T_b1dfe_row0_col7" class="data row0 col7" >2.090000</td>
#       <td id="T_b1dfe_row0_col8" class="data row0 col8" >2.230000</td>
#       <td id="T_b1dfe_row0_col9" class="data row0 col9" >2.160000</td>
#     </tr>
#     <tr>
#       <th id="T_b1dfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1dfe_row1_col0" class="data row1 col0" >2.280000</td>
#       <td id="T_b1dfe_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_b1dfe_row1_col2" class="data row1 col2" >2.590000</td>
#       <td id="T_b1dfe_row1_col3" class="data row1 col3" >2.630000</td>
#       <td id="T_b1dfe_row1_col4" class="data row1 col4" >1.920000</td>
#       <td id="T_b1dfe_row1_col5" class="data row1 col5" >1.900000</td>
#       <td id="T_b1dfe_row1_col6" class="data row1 col6" >1.870000</td>
#       <td id="T_b1dfe_row1_col7" class="data row1 col7" >2.410000</td>
#       <td id="T_b1dfe_row1_col8" class="data row1 col8" >2.490000</td>
#       <td id="T_b1dfe_row1_col9" class="data row1 col9" >2.640000</td>
#     </tr>
#     <tr>
#       <th id="T_b1dfe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1dfe_row2_col0" class="data row2 col0" >2.160000</td>
#       <td id="T_b1dfe_row2_col1" class="data row2 col1" >2.590000</td>
#       <td id="T_b1dfe_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_b1dfe_row2_col3" class="data row2 col3" >2.020000</td>
#       <td id="T_b1dfe_row2_col4" class="data row2 col4" >2.600000</td>
#       <td id="T_b1dfe_row2_col5" class="data row2 col5" >2.010000</td>
#       <td id="T_b1dfe_row2_col6" class="data row2 col6" >2.330000</td>
#       <td id="T_b1dfe_row2_col7" class="data row2 col7" >2.430000</td>
#       <td id="T_b1dfe_row2_col8" class="data row2 col8" >2.370000</td>
#       <td id="T_b1dfe_row2_col9" class="data row2 col9" >2.300000</td>
#     </tr>
#     <tr>
#       <th id="T_b1dfe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1dfe_row3_col0" class="data row3 col0" >2.470000</td>
#       <td id="T_b1dfe_row3_col1" class="data row3 col1" >2.630000</td>
#       <td id="T_b1dfe_row3_col2" class="data row3 col2" >2.020000</td>
#       <td id="T_b1dfe_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_b1dfe_row3_col4" class="data row3 col4" >2.750000</td>
#       <td id="T_b1dfe_row3_col5" class="data row3 col5" >2.390000</td>
#       <td id="T_b1dfe_row3_col6" class="data row3 col6" >2.350000</td>
#       <td id="T_b1dfe_row3_col7" class="data row3 col7" >2.100000</td>
#       <td id="T_b1dfe_row3_col8" class="data row3 col8" >2.330000</td>
#       <td id="T_b1dfe_row3_col9" class="data row3 col9" >2.500000</td>
#     </tr>
#     <tr>
#       <th id="T_b1dfe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1dfe_row4_col0" class="data row4 col0" >1.880000</td>
#       <td id="T_b1dfe_row4_col1" cl

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
