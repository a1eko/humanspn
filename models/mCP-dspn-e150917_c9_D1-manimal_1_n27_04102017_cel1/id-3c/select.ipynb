# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c9_D1, &nbsp; animal_1_n27_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n27_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_507.soma.v': 'expdata/ECBL_IV_ch1_507.dat',
    'IV_511.soma.v': 'expdata/ECBL_IV_ch1_511.dat',    
    'IDthresh-sub_547.soma.v': 'expdata/ECBL_IDthresh_ch1_547.dat',    
    'IDthresh_548.soma.v': 'expdata/ECBL_IDthresh_ch1_548.dat',    
    'IDthresh_550.soma.v': 'expdata/ECBL_IDthresh_ch1_550.dat',    
    'IDthresh_561.soma.v': 'expdata/ECBL_IDthresh_ch1_561.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n27_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.05]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -88.24462072341888
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 1.0]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.5]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.01]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.0001, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 20
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0.0001, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0.0001, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.005, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 20
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.02692   0.03513   0.03514   0.02881   0.02268   0.03639
# g_pas.somatic     0.001425  0.001299  0.001299  0.001425  0.001422 0.0009782
# g_pas.basal      1.806e-05 1.963e-05 1.963e-05 1.963e-05 1.621e-05 3.126e-05
# gbar_naf.axonal      16.52     12.21     12.05     15.23     12.84     11.26
# gbar_kas.axonal     0.1142    0.2627    0.1231    0.2627    0.2894    0.5157
# gbar_Im.axonal       0.427    0.4265    0.3753     0.427    0.4224    0.4319
# gbar_naf.somatic      11.8      12.2     12.18     11.62     11.62     11.62
# gbar_kaf.somatic    0.2629    0.3388    0.3348    0.2629    0.2625    0.2629
# gbar_kas.somatic 1.957e-06 1.859e-06 1.859e-06 1.957e-06 2.655e-06 3.451e-06
# gbar_kdr.somatic  0.003808   0.00264  0.001732  0.001679  0.002201  0.002956
# gbar_kir.somatic 0.0002292 0.0002024 0.0002024 0.0002334 0.0002334 0.0002072
# gbar_bk.somatic   0.000392 0.0003091 0.0001072 0.0002464 0.0002245 0.0002464
# gbar_sk.somatic  0.0001079 0.0001147 0.0001866 0.0001147  0.000102 0.0001292
# gbar_Im.somatic  0.0001083 0.0004949 0.0004949 0.0007067 0.0003074  0.000235
# gbar_naf.basal     0.02058   0.01846  0.003138   0.01846   0.01718   0.01857
# gbar_kaf.basal     0.01163  0.005877  0.005877  0.005877  0.008643  0.008593
# gbar_kas.basal    0.000216  0.000216  0.000216  0.000216 0.0007121 0.0006745
# gbar_kdr.basal   1.865e-05 2.318e-05  0.000204 2.318e-05 3.747e-06   0.00021
# gbar_kir.basal   0.0005783 0.0005783 0.0005807 0.0005783 0.0005995 0.0005809
# gbar_bk.basal    1.015e-05 1.021e-05 1.021e-05 1.015e-05 1.015e-05 1.016e-05
# gbar_sk.basal    7.113e-07 3.161e-08 7.651e-10 7.113e-07 4.232e-07 7.082e-07
#
#                          6         7         8         9
# g_pas.axonal       0.03334   0.02689   0.03511   0.03425
# g_pas.somatic     0.001201  0.001425  0.001299  0.001299
# g_pas.basal       2.23e-05 1.603e-05 1.507e-05 1.963e-05
# gbar_naf.axonal      10.35     15.37     12.21     12.21
# gbar_kas.axonal     0.2322    0.2844    0.2649    0.2428
# gbar_Im.axonal       0.427     0.427    0.4224    0.4107
# gbar_naf.somatic     11.94     11.62      12.2     12.18
# gbar_kaf.somatic    0.2363    0.1724    0.3348    0.3348
# gbar_kas.somatic  3.64e-06 1.957e-06  0.001464 1.859e-06
# gbar_kdr.somatic  0.002173  0.004418  0.002039  0.002618
# gbar_kir.somatic 0.0002137 0.0002334  0.000179 0.0002024
# gbar_bk.somatic  0.0001353 0.0002255 0.0003086  0.000254
# gbar_sk.somatic  0.0001033   0.00011 0.0001147 0.0002357
# gbar_Im.somatic  0.0006476 0.0003499 0.0004949 0.0004949
# gbar_naf.basal     0.01618  0.001693   0.01629   0.02256
# gbar_kaf.basal     0.02442   0.02184  0.005877  0.005877
# gbar_kas.basal   3.761e-05 0.0001187 5.035e-05  0.000216
# gbar_kdr.basal    2.65e-05 1.891e-05 6.288e-07 4.909e-06
# gbar_kir.basal   0.0005582 0.0005783 0.0006521 0.0005807
# gbar_bk.basal     4.43e-06 1.015e-05 1.021e-05 1.021e-05
# gbar_sk.basal    1.697e-07 4.185e-08 2.659e-08 1.495e-08

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_326a9_row0_col0, #T_326a9_row1_col1, #T_326a9_row2_col2, #T_326a9_row3_col3, #T_326a9_row4_col4, #T_326a9_row5_col5, #T_326a9_row6_col6, #T_326a9_row7_col7, #T_326a9_row8_col8, #T_326a9_row9_col9 {
#   background-color: #007fff;
# }
# #T_326a9_row0_col1, #T_326a9_row9_col5 {
#   background-color: #cde6ff;
# }
# #T_326a9_row0_col2 {
#   background-color: #e4f1ff;
# }
# #T_326a9_row0_col3 {
#   background-color: #8ec6ff;
# }
# #T_326a9_row0_col4 {
#   background-color: #a9d3ff;
# }
# #T_326a9_row0_col5 {
#   background-color: #abd5ff;
# }
# #T_326a9_row0_col6, #T_326a9_row2_col5 {
#   background-color: #d1e8ff;
# }
# #T_326a9_row0_col7, #T_326a9_row3_col7 {
#   background-color: #d0e7ff;
# }
# #T_326a9_row0_col8 {
#   background-color: #fafcff;
# }
# #T_326a9_row0_col9, #T_326a9_row6_col2, #T_326a9_row7_col8 {
#   background-color: #e7f3ff;
# }
# #T_326a9_row1_col0 {
#   background-color: #a3d0ff;
# }
# #T_326a9_row1_col2 {
#   background-color: #c6e2ff;
# }
# #T_326a9_row1_col3 {
#   background-color: #8bc5ff;
# }
# #T_326a9_row1_col4, #T_326a9_row1_col5, #T_326a9_row9_col0 {
#   background-color: #bcddff;
# }
# #T_326a9_row1_col6, #T_326a9_row9_col8 {
#   background-color: #bbddff;
# }
# #T_326a9_row1_col7 {
#   background-color: #a4d1ff;
# }
# #T_326a9_row1_col8 {
#   background-color: #bfdfff;
# }
# #T_326a9_row1_col9 {
#   background-color: #81c0ff;
# }
# #T_326a9_row2_col0 {
#   background-color: #e9f4ff;
# }
# #T_326a9_row2_col1, #T_326a9_row2_col4, #T_326a9_row2_col6, #T_326a9_row2_col8, #T_326a9_row5_col9, #T_326a9_row6_col9, #T_326a9_row8_col0, #T_326a9_row8_col2, #T_326a9_row8_col3, #T_326a9_row8_col5, #T_326a9_row8_col7 {
#   background-color: #ffffff;
# }
# #T_326a9_row2_col3 {
#   background-color: #e1f0ff;
# }
# #T_326a9_row2_col7 {
#   background-color: #e8f3ff;
# }
# #T_326a9_row2_col9, #T_326a9_row8_col4 {
#   background-color: #fdfeff;
# }
# #T_326a9_row3_col0 {
#   background-color: #80bfff;
# }
# #T_326a9_row3_col1 {
#   background-color: #9eceff;
# }
# #T_326a9_row3_col2 {
#   background-color: #c8e3ff;
# }
# #T_326a9_row3_col4, #T_326a9_row4_col3 {
#   background-color: #96caff;
# }
# #T_326a9_row3_col5 {
#   background-color: #9fceff;
# }
# #T_326a9_row3_col6, #T_326a9_row5_col3, #T_326a9_row9_col3 {
#   background-color: #b1d8ff;
# }
# #T_326a9_row3_col8, #T_326a9_row4_col2, #T_326a9_row4_col7, #T_326a9_row5_col6, #T_326a9_row7_col9 {
#   background-color: #e2f0ff;
# }
# #T_326a9_row3_col9 {
#   background-color: #c5e1ff;
# }
# #T_326a9_row4_col0 {
#   background-color: #99cbff;
# }
# #T_326a9_row4_col1 {
#   background-color: #d6eaff;
# }
# #T_326a9_row4_col5 {
#   background-color: #92c8ff;
# }
# #T_326a9_row4_col6 {
#   background-color: #cee6ff;
# }
# #T_326a9_row4_col8, #T_326a9_row6_col8 {
#   background-color: #e1efff;
# }
# #T_326a9_row4_col9 {
#   background-color: #c3e1ff;
# }
# #T_326a9_row5_col0 {
#   background-color: #add6ff;
# }
# #T_326a9_row5_col1 {
#   background-color: #eef6ff;
# }
# #T_326a9_row5_col2 {
#   background-color: #cfe7ff;
# }
# #T_326a9_row5_col4 {
#   background-color: #a3d1ff;
# }
# #T_326a9_row5_col7, #T_326a9_row5_col8 {
#   background-color: #fcfdff;
# }
# #T_326a9_row6_col0 {
#   background-color: #c1e0ff;
# }
# #T_326a9_row6_col1 {
#   background-color: #daecff;
# }
# #T_326a9_row6_col3 {
#   background-color: #b5daff;
# }
# #T_326a9_row6_col4, #T_326a9_row7_col2 {
#   background-color: #d3e9ff;
# }
# #T_326a9_row6_col5 {
#   background-color: #cfe6ff;
# }
# #T_326a9_row6_col7, #T_326a9_row7_col0, #T_326a9_row7_col6 {
#   background-color: #c0dfff;
# }
# #T_326a9_row7_col1 {
#   background-color: #bedeff;
# }
# #T_326a9_row7_col3 {
#   background-color: #d4e9ff;
# }
# #T_326a9_row7_col4, #T_326a9_row7_col5 {
#   background-color: #e7f2ff;
# }
# #T_326a9_row8_col1 {
#   background-color: #f5faff;
# }
# #T_326a9_row8_col6 {
#   background-color: #f8fbff;
# }
# #T_326a9_row8_col9 {
#   background-color: #eaf4ff;
# }
# #T_326a9_row9_col1 {
#   background-color: #85c1ff;
# }
# #T_326a9_row9_col2 {
#   background-color: #cae4ff;
# }
# #T_326a9_row9_col4 {
#   background-color: #b0d7ff;
# }
# #T_326a9_row9_col6 {
#   background-color: #e0efff;
# }
# #T_326a9_row9_col7 {
#   background-color: #c7e3ff;
# }
# </style>
# <table id="T_326a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_326a9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_326a9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_326a9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_326a9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_326a9_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_326a9_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_326a9_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_326a9_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_326a9_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_326a9_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_326a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_326a9_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_326a9_row0_col1" class="data row0 col1" >1.280000</td>
#       <td id="T_326a9_row0_col2" class="data row0 col2" >1.830000</td>
#       <td id="T_326a9_row0_col3" class="data row0 col3" >1.010000</td>
#       <td id="T_326a9_row0_col4" class="data row0 col4" >1.200000</td>
#       <td id="T_326a9_row0_col5" class="data row0 col5" >1.360000</td>
#       <td id="T_326a9_row0_col6" class="data row0 col6" >1.520000</td>
#       <td id="T_326a9_row0_col7" class="data row0 col7" >1.510000</td>
#       <td id="T_326a9_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_326a9_row0_col9" class="data row0 col9" >1.480000</td>
#     </tr>
#     <tr>
#       <th id="T_326a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_326a9_row1_col0" class="data row1 col0" >1.280000</td>
#       <td id="T_326a9_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_326a9_row1_col2" class="data row1 col2" >1.590000</td>
#       <td id="T_326a9_row1_col3" class="data row1 col3" >0.990000</td>
#       <td id="T_326a9_row1_col4" class="data row1 col4" >1.340000</td>
#       <td id="T_326a9_row1_col5" class="data row1 col5" >1.490000</td>
#       <td id="T_326a9_row1_col6" class="data row1 col6" >1.360000</td>
#       <td id="T_326a9_row1_col7" class="data row1 col7" >1.190000</td>
#       <td id="T_326a9_row1_col8" class="data row1 col8" >1.530000</td>
#       <td id="T_326a9_row1_col9" class="data row1 col9" >0.830000</td>
#     </tr>
#     <tr>
#       <th id="T_326a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_326a9_row2_col0" class="data row2 col0" >1.830000</td>
#       <td id="T_326a9_row2_col1" class="data row2 col1" >1.590000</td>
#       <td id="T_326a9_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_326a9_row2_col3" class="data row2 col3" >1.600000</td>
#       <td id="T_326a9_row2_col4" class="data row2 col4" >1.810000</td>
#       <td id="T_326a9_row2_col5" class="data row2 col5" >1.660000</td>
#       <td id="T_326a9_row2_col6" class="data row2 col6" >1.850000</td>
#       <td id="T_326a9_row2_col7" class="data row2 col7" >1.690000</td>
#       <td id="T_326a9_row2_col8" class="data row2 col8" >2.040000</td>
#       <td id="T_326a9_row2_col9" class="data row2 col9" >1.620000</td>
#     </tr>
#     <tr>
#       <th id="T_326a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_326a9_row3_col0" class="data row3 col0" >1.010000</td>
#       <td id="T_326a9_row3_col1" class="data row3 col1" >0.990000</td>
#       <td id="T_326a9_row3_col2" class="data row3 col2" >1.600000</td>
#       <td id="T_326a9_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_326a9_row3_col4" class="data row3 col4" >1.070000</td>
#       <td id="T_326a9_row3_col5" class="data row3 col5" >1.260000</td>
#       <td id="T_326a9_row3_col6" class="data row3 col6" >1.290000</td>
#       <td id="T_326a9_row3_col7" class="data row3 col7" >1.510000</td>
#       <td id="T_326a9_row3_col8" class="data row3 col8" >1.810000</td>
#       <td id="T_326a9_row3_col9" class="data row3 col9" >1.260000</td>
#     </tr

# %%
hall_of_fame = []
selected = [0,2,3,4,5,6,7] #range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
