# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c6_D1, &nbsp; animal_1_n24_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n24_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_499.soma.v': 'expdata/ECBL_IV_ch5_499.dat',
    'IV_502.soma.v': 'expdata/ECBL_IV_ch5_502.dat',    
    'IDthresh-sub_541.soma.v': 'expdata/ECBL_IDthresh_ch5_541.dat',    
    'IDthresh_543.soma.v': 'expdata/ECBL_IDthresh_ch5_543.dat',    
    'IDthresh_544.soma.v': 'expdata/ECBL_IDthresh_ch5_544.dat',    
    'IDthresh_553.soma.v': 'expdata/ECBL_IDthresh_ch5_553.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n24_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -81.79466631647394
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.2]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.2]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.0001, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.005, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 14
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.01117    0.0102   0.01154   0.01117   0.01087  0.007136
# g_pas.somatic    0.0002545 0.0001658 1.859e-05 0.0002545 0.0001635 0.0009291
# g_pas.basal      1.074e-05 1.146e-05 1.146e-05 1.146e-05 1.143e-05 1.042e-05
# gbar_naf.axonal     0.6838 0.0004937    0.0141   0.01803  0.002021  0.006149
# gbar_kas.axonal    0.03425    0.1067   0.09717   0.00622   0.05377   0.02844
# gbar_Im.axonal     0.02822  0.005932   0.04275  0.003297  0.002805  0.007328
# gbar_naf.somatic     9.329      9.45     8.911     9.341     8.808     9.187
# gbar_kaf.somatic    0.4409    0.4536    0.3352    0.4409    0.3174    0.3712
# gbar_kas.somatic 0.0003404 0.0006626 0.0001747 0.0007289  0.004659  0.001105
# gbar_kdr.somatic  0.001029  0.001833  0.001354  0.001784 0.0008609  0.001102
# gbar_kir.somatic 0.0007184 0.0003054 0.0001479 0.0007245  0.001462 0.0003645
# gbar_bk.somatic  2.579e-07 0.0001821 2.596e-06 2.579e-07 1.408e-07 5.391e-06
# gbar_sk.somatic  0.0002414 7.968e-06 9.159e-06 0.0002845 8.073e-05 0.0002008
# gbar_Im.somatic  0.0001873 0.0001766  0.000165 0.0001873 0.0001896 0.0002263
# gbar_naf.basal     0.06907   0.05774   0.05738   0.06907   0.04539   0.01573
# gbar_kaf.basal    0.007245  0.005468   0.01293  0.008536  0.008225  0.005353
# gbar_kas.basal   6.837e-07 9.394e-05 7.254e-07 1.441e-06 1.623e-07 3.494e-05
# gbar_kdr.basal   6.255e-07 0.0002345 0.0001808 6.255e-07 1.256e-05  0.000362
# gbar_kir.basal   0.0001201 0.0001404 0.0002823 0.0001497 0.0001025 0.0001289
# gbar_bk.basal    1.305e-07  4.09e-10 6.453e-06 1.177e-06 8.033e-07 1.507e-07
# gbar_sk.basal     7.05e-08 1.852e-05 3.511e-05  3.58e-08 1.266e-05 2.511e-07
#
#                          6         7         8         9
# g_pas.axonal       0.01112   0.01096   0.01127   0.01118
# g_pas.somatic    4.642e-05 4.338e-05  7.08e-05 2.737e-05
# g_pas.basal      1.137e-05 1.098e-05 1.137e-05 1.001e-05
# gbar_naf.axonal  0.0006198   0.01224    0.0141    0.9714
# gbar_kas.axonal    0.09579  0.002769   0.09962   0.03694
# gbar_Im.axonal    0.009572   0.02644   0.01338  0.002978
# gbar_naf.somatic      9.45     9.341      9.45     9.979
# gbar_kaf.somatic    0.4536    0.4409    0.4834    0.6341
# gbar_kas.somatic 3.882e-05  0.005516 7.796e-05 3.903e-05
# gbar_kdr.somatic  0.000807  0.001872  0.001354  0.001943
# gbar_kir.somatic 0.0003054  0.002456 0.0001479 0.0001001
# gbar_bk.somatic  1.805e-06 2.579e-07 2.596e-06 0.0001231
# gbar_sk.somatic  0.0002732  0.000303 0.0001026 0.0003301
# gbar_Im.somatic  0.0002088 0.0001227  0.000165 0.0002014
# gbar_naf.basal       0.058   0.06907   0.05741   0.07667
# gbar_kaf.basal    0.005329  0.008536  0.006863  0.005636
# gbar_kas.basal   1.745e-06 1.441e-06 7.276e-07 1.245e-05
# gbar_kdr.basal   8.229e-07 4.682e-06 0.0001808 4.207e-06
# gbar_kir.basal   0.0003737 0.0001122 0.0001015 0.0001532
# gbar_bk.basal    1.481e-10 1.118e-06 7.639e-06 1.418e-05
# gbar_sk.basal    1.305e-05 3.253e-08  2.02e-05 8.978e-06

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_cf5d8_row0_col0, #T_cf5d8_row1_col1, #T_cf5d8_row2_col2, #T_cf5d8_row3_col3, #T_cf5d8_row4_col4, #T_cf5d8_row5_col5, #T_cf5d8_row6_col6, #T_cf5d8_row7_col7, #T_cf5d8_row8_col8, #T_cf5d8_row9_col9 {
#   background-color: #007fff;
# }
# #T_cf5d8_row0_col1, #T_cf5d8_row4_col5 {
#   background-color: #e7f3ff;
# }
# #T_cf5d8_row0_col2, #T_cf5d8_row0_col8, #T_cf5d8_row5_col2, #T_cf5d8_row7_col6 {
#   background-color: #fbfdff;
# }
# #T_cf5d8_row0_col3 {
#   background-color: #a0cfff;
# }
# #T_cf5d8_row0_col4, #T_cf5d8_row5_col7, #T_cf5d8_row8_col0, #T_cf5d8_row8_col3 {
#   background-color: #e1f0ff;
# }
# #T_cf5d8_row0_col5, #T_cf5d8_row5_col0, #T_cf5d8_row9_col6 {
#   background-color: #d6eaff;
# }
# #T_cf5d8_row0_col6 {
#   background-color: #e2f0ff;
# }
# #T_cf5d8_row0_col7 {
#   background-color: #b5daff;
# }
# #T_cf5d8_row0_col9 {
#   background-color: #f1f8ff;
# }
# #T_cf5d8_row1_col0, #T_cf5d8_row1_col3, #T_cf5d8_row1_col7, #T_cf5d8_row2_col4, #T_cf5d8_row3_col2, #T_cf5d8_row5_col6, #T_cf5d8_row5_col9, #T_cf5d8_row7_col1, #T_cf5d8_row7_col8, #T_cf5d8_row9_col5 {
#   background-color: #ffffff;
# }
# #T_cf5d8_row1_col2 {
#   background-color: #e3f1ff;
# }
# #T_cf5d8_row1_col4, #T_cf5d8_row2_col9 {
#   background-color: #edf6ff;
# }
# #T_cf5d8_row1_col5, #T_cf5d8_row8_col4 {
#   background-color: #dfefff;
# }
# #T_cf5d8_row1_col6 {
#   background-color: #deeeff;
# }
# #T_cf5d8_row1_col8, #T_cf5d8_row4_col8, #T_cf5d8_row9_col0 {
#   background-color: #f0f7ff;
# }
# #T_cf5d8_row1_col9 {
#   background-color: #e9f4ff;
# }
# #T_cf5d8_row2_col0, #T_cf5d8_row5_col8 {
#   background-color: #f3f9ff;
# }
# #T_cf5d8_row2_col1 {
#   background-color: #c8e3ff;
# }
# #T_cf5d8_row2_col3 {
#   background-color: #f7fbff;
# }
# #T_cf5d8_row2_col5, #T_cf5d8_row9_col2 {
#   background-color: #f4f9ff;
# }
# #T_cf5d8_row2_col6 {
#   background-color: #ddedff;
# }
# #T_cf5d8_row2_col7, #T_cf5d8_row6_col2, #T_cf5d8_row6_col7 {
#   background-color: #dcedff;
# }
# #T_cf5d8_row2_col8, #T_cf5d8_row3_col7 {
#   background-color: #8ac4ff;
# }
# #T_cf5d8_row3_col0 {
#   background-color: #9fcfff;
# }
# #T_cf5d8_row3_col1 {
#   background-color: #e7f2ff;
# }
# #T_cf5d8_row3_col4, #T_cf5d8_row9_col1 {
#   background-color: #d3e9ff;
# }
# #T_cf5d8_row3_col5, #T_cf5d8_row4_col0, #T_cf5d8_row5_col3 {
#   background-color: #d9ecff;
# }
# #T_cf5d8_row3_col6 {
#   background-color: #ecf5ff;
# }
# #T_cf5d8_row3_col8, #T_cf5d8_row7_col2, #T_cf5d8_row9_col4 {
#   background-color: #fafcff;
# }
# #T_cf5d8_row3_col9, #T_cf5d8_row7_col5, #T_cf5d8_row9_col3 {
#   background-color: #f8fbff;
# }
# #T_cf5d8_row4_col1, #T_cf5d8_row6_col9, #T_cf5d8_row8_col7 {
#   background-color: #cfe7ff;
# }
# #T_cf5d8_row4_col2 {
#   background-color: #fefeff;
# }
# #T_cf5d8_row4_col3 {
#   background-color: #cce5ff;
# }
# #T_cf5d8_row4_col6, #T_cf5d8_row6_col4 {
#   background-color: #ebf5ff;
# }
# #T_cf5d8_row4_col7 {
#   background-color: #b7daff;
# }
# #T_cf5d8_row4_col9 {
#   background-color: #f2f8ff;
# }
# #T_cf5d8_row5_col1, #T_cf5d8_row6_col8 {
#   background-color: #cae4ff;
# }
# #T_cf5d8_row5_col4 {
#   background-color: #eff6ff;
# }
# #T_cf5d8_row6_col0 {
#   background-color: #daecff;
# }
# #T_cf5d8_row6_col1 {
#   background-color: #c2e0ff;
# }
# #T_cf5d8_row6_col3 {
#   background-color: #e4f1ff;
# }
# #T_cf5d8_row6_col5 {
#   background-color: #f6faff;
# }
# #T_cf5d8_row7_col0 {
#   background-color: #c7e3ff;
# }
# #T_cf5d8_row7_col3 {
#   background-color: #99cbff;
# }
# #T_cf5d8_row7_col4 {
#   background-color: #d0e7ff;
# }
# #T_cf5d8_row7_col9 {
#   background-color: #fdfeff;
# }
# #T_cf5d8_row8_col1 {
#   background-color: #c4e1ff;
# }
# #T_cf5d8_row8_col2 {
#   background-color: #80bfff;
# }
# #T_cf5d8_row8_col5 {
#   background-color: #dbedff;
# }
# #T_cf5d8_row8_col6 {
#   background-color: #bcddff;
# }
# #T_cf5d8_row8_col9 {
#   background-color: #cee6ff;
# }
# #T_cf5d8_row9_col7, #T_cf5d8_row9_col8 {
#   background-color: #e5f2ff;
# }
# </style>
# <table id="T_cf5d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf5d8_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cf5d8_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cf5d8_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cf5d8_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cf5d8_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_cf5d8_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_cf5d8_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_cf5d8_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_cf5d8_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_cf5d8_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf5d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf5d8_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_cf5d8_row0_col1" class="data row0 col1" >2.810000</td>
#       <td id="T_cf5d8_row0_col2" class="data row0 col2" >2.680000</td>
#       <td id="T_cf5d8_row0_col3" class="data row0 col3" >1.760000</td>
#       <td id="T_cf5d8_row0_col4" class="data row0 col4" >2.400000</td>
#       <td id="T_cf5d8_row0_col5" class="data row0 col5" >2.360000</td>
#       <td id="T_cf5d8_row0_col6" class="data row0 col6" >2.410000</td>
#       <td id="T_cf5d8_row0_col7" class="data row0 col7" >2.200000</td>
#       <td id="T_cf5d8_row0_col8" class="data row0 col8" >2.490000</td>
#       <td id="T_cf5d8_row0_col9" class="data row0 col9" >2.650000</td>
#     </tr>
#     <tr>
#       <th id="T_cf5d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf5d8_row1_col0" class="data row1 col0" >2.810000</td>
#       <td id="T_cf5d8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cf5d8_row1_col2" class="data row1 col2" >2.430000</td>
#       <td id="T_cf5d8_row1_col3" class="data row1 col3" >2.800000</td>
#       <td id="T_cf5d8_row1_col4" class="data row1 col4" >2.520000</td>
#       <td id="T_cf5d8_row1_col5" class="data row1 col5" >2.450000</td>
#       <td id="T_cf5d8_row1_col6" class="data row1 col6" >2.360000</td>
#       <td id="T_cf5d8_row1_col7" class="data row1 col7" >3.090000</td>
#       <td id="T_cf5d8_row1_col8" class="data row1 col8" >2.380000</td>
#       <td id="T_cf5d8_row1_col9" class="data row1 col9" >2.560000</td>
#     </tr>
#     <tr>
#       <th id="T_cf5d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf5d8_row2_col0" class="data row2 col0" >2.680000</td>
#       <td id="T_cf5d8_row2_col1" class="data row2 col1" >2.430000</td>
#       <td id="T_cf5d8_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cf5d8_row2_col3" class="data row2 col3" >2.720000</td>
#       <td id="T_cf5d8_row2_col4" class="data row2 col4" >2.710000</td>
#       <td id="T_cf5d8_row2_col5" class="data row2 col5" >2.680000</td>
#       <td id="T_cf5d8_row2_col6" class="data row2 col6" >2.350000</td>
#       <td id="T_cf5d8_row2_col7" class="data row2 col7" >2.670000</td>
#       <td id="T_cf5d8_row2_col8" class="data row2 col8" >1.370000</td>
#       <td id="T_cf5d8_row2_col9" class="data row2 col9" >2.610000</td>
#     </tr>
#     <tr>
#       <th id="T_cf5d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf5d8_row3_col0" class="data row3 col0" >1.760000</td>
#       <td id="T_cf5d8_row3_col1" class="data row3 col1" >2.800000</td>
#       <td id="T_cf5d8_row3_col2" class="data row3 col2" >2.720000</td>
#       <td id="T_cf5d8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cf5d8_row3_col4" class="data row3 col4" >2.250000</td>
#       <td id="T_cf5d8_row3_col5" class="data row3 col5" >2.390000</td>
#       <td id="T_cf5d8_row3_col6" class="data row3 col6" >2.510000</td>
#       <td id="T_cf5d8_row3_col7" class="data row3 col7" >1.680000</td>
#       <td id="T_cf5d8_row3_col8" class="data row3 col8" >2.480000</td>
#       <td id="T_cf5d8_row3_col9" class="data row3 col9" >2.730000</td>
#     </tr>
#     <tr>
#       <th id="T_cf5d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cf5d8_row4_col0" class="data row4 col0" >2.400000</td>
#       <td id="T_cf5d8_row4_col1" class="data row4 col1" >2.520000</

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
