# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c6_D1, &nbsp; animal_1_n24_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n24_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_499.soma.v': 'expdata/ECBL_IV_ch5_499.dat',
    'IV_502.soma.v': 'expdata/ECBL_IV_ch5_502.dat',    
    'IDthresh-sub_541.soma.v': 'expdata/ECBL_IDthresh_ch5_541.dat',    
    'IDthresh_543.soma.v': 'expdata/ECBL_IDthresh_ch5_543.dat',    
    'IDthresh_544.soma.v': 'expdata/ECBL_IDthresh_ch5_544.dat',    
    'IDthresh_553.soma.v': 'expdata/ECBL_IDthresh_ch5_553.dat',    
}
# Out:
# /home/akozlov/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/akozlov/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:64: UserWarning: Pandas requires version '1.3.2' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n24_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -81.79466631647394
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.2]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.2]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.0001, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.0005, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 14
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.01076    0.0119   0.01193   0.01315   0.01078   0.01219
# g_pas.somatic    0.0003535 0.0002414 0.0001914 5.041e-05 0.0003342 0.0003159
# g_pas.basal      1.027e-05 1.043e-05 1.402e-05 1.043e-05 1.066e-05 1.015e-05
# gbar_naf.axonal      5.667     5.525     4.699     5.717     4.126     9.824
# gbar_kas.axonal    0.02791  0.004214  0.001522    0.0138  0.008593  0.009247
# gbar_Im.axonal     0.03211    0.0701   0.01056   0.05819   0.02473   0.03259
# gbar_naf.somatic     7.835     7.751     7.754     7.742     7.917     7.288
# gbar_kaf.somatic    0.2907    0.2907    0.2907    0.2906    0.2907    0.2181
# gbar_kas.somatic 0.0003958     0.001 0.0002882 0.0004271 0.0004017 3.165e-05
# gbar_kdr.somatic 0.0006576 0.0009062  0.001098 0.0009035 0.0006844  0.001302
# gbar_kir.somatic  0.002321  0.000108 0.0004437 0.0001307  0.002066 0.0001106
# gbar_bk.somatic  2.055e-05 1.366e-06 0.0003035 0.0006412 0.0001047 7.367e-06
# gbar_sk.somatic  9.662e-05 2.048e-06 7.368e-05 1.535e-07  0.000114   6.7e-08
# gbar_Im.somatic  0.0002756 0.0002269 0.0001019 0.0001009 0.0001588 0.0001239
# gbar_naf.basal     0.09221   0.09318   0.09022    0.0921   0.08587   0.07676
# gbar_kaf.basal    0.002072 0.0006976  0.006975 0.0005064  0.002458  0.001435
# gbar_kas.basal   2.035e-07 3.755e-07 4.193e-07 6.828e-06 7.494e-07 2.855e-05
# gbar_kdr.basal   3.983e-06 0.0001085 0.0002337 5.835e-05 0.0005339 5.922e-05
# gbar_kir.basal     0.00018 0.0003437 0.0002391 0.0002482 0.0003106 0.0001708
# gbar_bk.basal    1.562e-05 1.021e-09 1.727e-09 2.648e-06 6.581e-09 5.142e-05
# gbar_sk.basal    6.856e-06 2.611e-05 8.012e-06 6.888e-06     8e-06 1.002e-06
#
#                          6         7         8         9
# g_pas.axonal       0.01245  0.006697   0.01191  0.006799
# g_pas.somatic    0.0002414 0.0005581 0.0003182 0.0005581
# g_pas.basal      1.043e-05     1e-05 1.041e-05 1.574e-05
# gbar_naf.axonal      4.611     1.221     6.121     0.655
# gbar_kas.axonal   0.007025  0.007751  0.008043  0.004031
# gbar_Im.axonal      0.0581  0.007998   0.00965   0.02068
# gbar_naf.somatic     7.842     10.43     7.741     9.933
# gbar_kaf.somatic    0.2883    0.7945    0.2624    0.6988
# gbar_kas.somatic   0.00101 0.0004152 0.0005441 0.0004233
# gbar_kdr.somatic  0.001008  0.000919  0.001105 0.0006842
# gbar_kir.somatic 0.0003004  0.001608 0.0003261  0.003521
# gbar_bk.somatic  5.446e-07 4.097e-06 0.0001066 1.411e-05
# gbar_sk.somatic  4.407e-06 0.0003289 9.099e-05 0.0001027
# gbar_Im.somatic  0.0002269 0.0002482  0.000103  0.001151
# gbar_naf.basal     0.08764   0.05569   0.09043   0.09848
# gbar_kaf.basal    0.001745  0.002887  0.006008  0.001122
# gbar_kas.basal   6.571e-06 4.774e-06  6.03e-07 1.983e-05
# gbar_kdr.basal   0.0001431 1.447e-05 6.396e-05  3.32e-05
# gbar_kir.basal   0.0002006 0.0002501 0.0001182 0.0001001
# gbar_bk.basal    7.353e-10 1.575e-08 3.013e-05 4.378e-06
# gbar_sk.basal    3.123e-05 2.365e-07 8.012e-06 1.218e-05

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="599.65">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="599.65">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="599.65">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_473ee_row0_col0, #T_473ee_row1_col1, #T_473ee_row2_col2, #T_473ee_row3_col3, #T_473ee_row4_col4, #T_473ee_row5_col5, #T_473ee_row6_col6, #T_473ee_row7_col7, #T_473ee_row8_col8, #T_473ee_row9_col9 {
#   background-color: #007fff;
# }
# #T_473ee_row0_col1, #T_473ee_row2_col7 {
#   background-color: #e9f4ff;
# }
# #T_473ee_row0_col2 {
#   background-color: #d5eaff;
# }
# #T_473ee_row0_col3, #T_473ee_row1_col5, #T_473ee_row3_col2, #T_473ee_row5_col1, #T_473ee_row8_col6 {
#   background-color: #e4f1ff;
# }
# #T_473ee_row0_col4 {
#   background-color: #aed6ff;
# }
# #T_473ee_row0_col5 {
#   background-color: #e7f3ff;
# }
# #T_473ee_row0_col6, #T_473ee_row1_col0 {
#   background-color: #fbfdff;
# }
# #T_473ee_row0_col7, #T_473ee_row3_col1 {
#   background-color: #d4e9ff;
# }
# #T_473ee_row0_col8 {
#   background-color: #c0dfff;
# }
# #T_473ee_row0_col9 {
#   background-color: #c2e0ff;
# }
# #T_473ee_row1_col2, #T_473ee_row2_col1, #T_473ee_row3_col5 {
#   background-color: #cce5ff;
# }
# #T_473ee_row1_col3, #T_473ee_row8_col3 {
#   background-color: #cde6ff;
# }
# #T_473ee_row1_col4 {
#   background-color: #d9ecff;
# }
# #T_473ee_row1_col6 {
#   background-color: #84c1ff;
# }
# #T_473ee_row1_col7 {
#   background-color: #f6faff;
# }
# #T_473ee_row1_col8 {
#   background-color: #f2f8ff;
# }
# #T_473ee_row1_col9, #T_473ee_row2_col5, #T_473ee_row3_col0, #T_473ee_row3_col7, #T_473ee_row5_col2, #T_473ee_row5_col4, #T_473ee_row6_col0, #T_473ee_row7_col1, #T_473ee_row7_col3, #T_473ee_row7_col8, #T_473ee_row9_col6 {
#   background-color: #ffffff;
# }
# #T_473ee_row2_col0 {
#   background-color: #e6f2ff;
# }
# #T_473ee_row2_col3, #T_473ee_row8_col9 {
#   background-color: #ddeeff;
# }
# #T_473ee_row2_col4 {
#   background-color: #96caff;
# }
# #T_473ee_row2_col6, #T_473ee_row6_col5 {
#   background-color: #dfefff;
# }
# #T_473ee_row2_col8 {
#   background-color: #a2d0ff;
# }
# #T_473ee_row2_col9, #T_473ee_row5_col0 {
#   background-color: #f9fcff;
# }
# #T_473ee_row3_col4, #T_473ee_row5_col7 {
#   background-color: #ebf5ff;
# }
# #T_473ee_row3_col6 {
#   background-color: #dcedff;
# }
# #T_473ee_row3_col8, #T_473ee_row7_col0 {
#   background-color: #ecf5ff;
# }
# #T_473ee_row3_col9, #T_473ee_row7_col2, #T_473ee_row9_col5 {
#   background-color: #f1f8ff;
# }
# #T_473ee_row4_col0 {
#   background-color: #b7dbff;
# }
# #T_473ee_row4_col1 {
#   background-color: #d3e9ff;
# }
# #T_473ee_row4_col2, #T_473ee_row8_col2 {
#   background-color: #92c8ff;
# }
# #T_473ee_row4_col3, #T_473ee_row4_col6, #T_473ee_row8_col7 {
#   background-color: #deeeff;
# }
# #T_473ee_row4_col5 {
#   background-color: #f8fbff;
# }
# #T_473ee_row4_col7 {
#   background-color: #c4e1ff;
# }
# #T_473ee_row4_col8 {
#   background-color: #b3d9ff;
# }
# #T_473ee_row4_col9, #T_473ee_row8_col1 {
#   background-color: #daecff;
# }
# #T_473ee_row5_col3 {
#   background-color: #c5e2ff;
# }
# #T_473ee_row5_col6, #T_473ee_row6_col8 {
#   background-color: #eef6ff;
# }
# #T_473ee_row5_col8 {
#   background-color: #eff7ff;
# }
# #T_473ee_row5_col9, #T_473ee_row7_col5 {
#   background-color: #f3f9ff;
# }
# #T_473ee_row6_col1 {
#   background-color: #7bbdff;
# }
# #T_473ee_row6_col2 {
#   background-color: #d1e8ff;
# }
# #T_473ee_row6_col3 {
#   background-color: #c8e3ff;
# }
# #T_473ee_row6_col4 {
#   background-color: #d6eaff;
# }
# #T_473ee_row6_col7 {
#   background-color: #e3f1ff;
# }
# #T_473ee_row6_col9 {
#   background-color: #f0f7ff;
# }
# #T_473ee_row7_col4, #T_473ee_row9_col0 {
#   background-color: #d0e7ff;
# }
# #T_473ee_row7_col6 {
#   background-color: #fafcff;
# }
# #T_473ee_row7_col9 {
#   background-color: #c9e4ff;
# }
# #T_473ee_row8_col0 {
#   background-color: #badcff;
# }
# #T_473ee_row8_col4 {
#   background-color: #a5d2ff;
# }
# #T_473ee_row8_col5 {
#   background-color: #d7ebff;
# }
# #T_473ee_row9_col1 {
#   background-color: #fdfeff;
# }
# #T_473ee_row9_col2 {
#   background-color: #f7fbff;
# }
# #T_473ee_row9_col3 {
#   background-color: #e8f3ff;
# }
# #T_473ee_row9_col4 {
#   background-color: #dfeeff;
# }
# #T_473ee_row9_col7 {
#   background-color: #c1e0ff;
# }
# #T_473ee_row9_col8 {
#   background-color: #f4f9ff;
# }
# </style>
# <table id="T_473ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_473ee_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_473ee_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_473ee_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_473ee_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_473ee_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_473ee_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_473ee_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_473ee_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_473ee_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_473ee_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_473ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_473ee_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_473ee_row0_col1" class="data row0 col1" >2.470000</td>
#       <td id="T_473ee_row0_col2" class="data row0 col2" >2.260000</td>
#       <td id="T_473ee_row0_col3" class="data row0 col3" >2.500000</td>
#       <td id="T_473ee_row0_col4" class="data row0 col4" >1.800000</td>
#       <td id="T_473ee_row0_col5" class="data row0 col5" >2.450000</td>
#       <td id="T_473ee_row0_col6" class="data row0 col6" >2.500000</td>
#       <td id="T_473ee_row0_col7" class="data row0 col7" >2.320000</td>
#       <td id="T_473ee_row0_col8" class="data row0 col8" >1.830000</td>
#       <td id="T_473ee_row0_col9" class="data row0 col9" >2.040000</td>
#     </tr>
#     <tr>
#       <th id="T_473ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_473ee_row1_col0" class="data row1 col0" >2.470000</td>
#       <td id="T_473ee_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_473ee_row1_col2" class="data row1 col2" >2.170000</td>
#       <td id="T_473ee_row1_col3" class="data row1 col3" >2.250000</td>
#       <td id="T_473ee_row1_col4" class="data row1 col4" >2.240000</td>
#       <td id="T_473ee_row1_col5" class="data row1 col5" >2.420000</td>
#       <td id="T_473ee_row1_col6" class="data row1 col6" >1.310000</td>
#       <td id="T_473ee_row1_col7" class="data row1 col7" >2.700000</td>
#       <td id="T_473ee_row1_col8" class="data row1 col8" >2.310000</td>
#       <td id="T_473ee_row1_col9" class="data row1 col9" >2.680000</td>
#     </tr>
#     <tr>
#       <th id="T_473ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_473ee_row2_col0" class="data row2 col0" >2.260000</td>
#       <td id="T_473ee_row2_col1" class="data row2 col1" >2.170000</td>
#       <td id="T_473ee_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_473ee_row2_col3" class="data row2 col3" >2.420000</td>
#       <td id="T_473ee_row2_col4" class="data row2 col4" >1.550000</td>
#       <td id="T_473ee_row2_col5" class="data row2 col5" >2.700000</td>
#       <td id="T_473ee_row2_col6" class="data row2 col6" >2.220000</td>
#       <td id="T_473ee_row2_col7" class="data row2 col7" >2.560000</td>
#       <td id="T_473ee_row2_col8" class="data row2 col8" >1.550000</td>
#       <td id="T_473ee_row2_col9" class="data row2 col9" >2.620000</td>
#     </tr>
#     <tr>
#       <th id="T_473ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_473ee_row3_col0" class="data row3 col0" >2.500000</td>
#       <td id="T_473ee_row3_col1" class="data row3 col1" >2.250000</td>
#       <td id="T_473ee_row3_col2" class="data row3 col2" >2.420000</td>
#       <td id="T_473ee_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_473ee_row3_col4" class="data row3 col4" >2.430000</td>
#       <td id="T_473ee_row3_col5" class="data row3 col5" >2.160000</td>
#       <td id="T_473ee_row3_col6" class="data row3 col6" >2.190000</td>
#       <td id="T_473ee_row3_col7" class="data row3 col7" >2.790000</td>
#       <td id="T_473ee_row3_col8" class="data row3 col8" >2.250000</td>
#       <td id="T_473ee_row3_col9" class="data row3 col9" >2.540000</td>
#     </tr>
#     <tr>
#       <th id="T_473ee_level0_row4" class="row_heading

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
