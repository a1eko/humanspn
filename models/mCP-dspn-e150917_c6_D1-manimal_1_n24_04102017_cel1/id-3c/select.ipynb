# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150917_c6_D1, &nbsp; animal_1_n24_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n24_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_499.soma.v': 'expdata/ECBL_IV_ch5_499.dat',
    'IV_502.soma.v': 'expdata/ECBL_IV_ch5_502.dat',    
    'IDthresh-sub_541.soma.v': 'expdata/ECBL_IDthresh_ch5_541.dat',    
    'IDthresh_543.soma.v': 'expdata/ECBL_IDthresh_ch5_543.dat',    
    'IDthresh_544.soma.v': 'expdata/ECBL_IDthresh_ch5_544.dat',    
    'IDthresh_553.soma.v': 'expdata/ECBL_IDthresh_ch5_553.dat',    
}
# Out:
# /home/akozlov/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/akozlov/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:59: UserWarning: Pandas requires version '1.3.2' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n24_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -81.79466631647394
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.2]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.2]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.0001, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 43
#     gbar_bk.somatic: ['somatic'] gbar_bk = [1e-05, 0.001]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [1e-05, 0.001]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.0001, 0.1]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 43
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.01109    0.0125   0.01181   0.01109   0.01037   0.01205
# g_pas.somatic    2.357e-05 1.627e-05 7.514e-05 2.357e-05 0.0002851 1.261e-05
# g_pas.basal      1.081e-05 1.355e-05 1.026e-05 1.081e-05 1.539e-05 1.213e-05
# gbar_naf.axonal    0.06401     1.176      4.45     1.035    0.2382     3.349
# gbar_kas.axonal   0.007635   0.03254   0.05877   0.02509   0.02098   0.01114
# gbar_Im.axonal     0.05623    0.1267    0.1613   0.05542    0.1058   0.08267
# gbar_naf.somatic     9.306     8.833     8.087     8.817     9.215     8.527
# gbar_kaf.somatic    0.4325    0.3412    0.3067    0.3772    0.3683    0.3823
# gbar_kas.somatic 8.304e-06 1.276e-05  5.18e-06 8.304e-06     7e-05 1.009e-05
# gbar_kdr.somatic 0.0004295 1.897e-05 0.0004862   0.00038 0.0007141 0.0004581
# gbar_kir.somatic 0.0005402  0.001502  0.001079 0.0005402 0.0003456 0.0007712
# gbar_bk.somatic  0.0002931 0.0001522 0.0002193 0.0002931 0.0002623 0.0002876
# gbar_sk.somatic  1.837e-05 4.014e-05 2.028e-05 1.837e-05 0.0001144 3.214e-05
# gbar_Im.somatic  0.0001591  0.001011 0.0002163 0.0001591  0.001004 0.0006833
# gbar_naf.basal     0.07382   0.07845   0.09183   0.07156   0.09365   0.07712
# gbar_kaf.basal    0.004316 0.0001186 0.0004866   0.00874 0.0001031  0.002118
# gbar_kas.basal    0.000283 3.574e-06 2.907e-06 1.458e-06 6.272e-08  0.000128
# gbar_kdr.basal   6.378e-05 2.217e-05 1.292e-05 6.378e-05 0.0003072  5.82e-06
# gbar_kir.basal   0.0001938 0.0001659 0.0001001 0.0002061 0.0001519 0.0001042
# gbar_bk.basal    2.388e-05 2.102e-07 5.756e-09 2.388e-05 1.974e-07 1.472e-07
# gbar_sk.basal    2.042e-07 7.295e-06 1.446e-06 2.042e-07 2.916e-06 6.998e-08
#
#                          6         7         8         9
# g_pas.axonal       0.01193   0.01109   0.01193   0.01019
# g_pas.somatic    3.131e-05 2.213e-05 2.929e-05 1.436e-05
# g_pas.basal      1.125e-05 1.081e-05 1.288e-05 1.081e-05
# gbar_naf.axonal      14.26    0.9948     14.26     1.193
# gbar_kas.axonal    0.02116   0.03445   0.03705   0.06183
# gbar_Im.axonal      0.1307   0.07288    0.1333   0.05348
# gbar_naf.somatic     8.216     8.811     8.216     10.04
# gbar_kaf.somatic     0.342    0.3762    0.3412    0.6929
# gbar_kas.somatic 2.309e-05 2.148e-06 2.309e-05 7.945e-06
# gbar_kdr.somatic 4.949e-05   0.00038 2.357e-05 0.0005629
# gbar_kir.somatic 0.0007236 0.0007216 0.0007211 0.0005401
# gbar_bk.somatic  0.0003251 0.0002917 0.0001495 0.0002609
# gbar_sk.somatic   3.95e-05 1.837e-05 4.014e-05 1.017e-05
# gbar_Im.somatic   0.000844 0.0004843  0.001034  0.000158
# gbar_naf.basal     0.08748   0.09396   0.07845    0.0763
# gbar_kaf.basal    0.001144  0.006289  0.001144 0.0001316
# gbar_kas.basal    3.06e-05  1.47e-06 1.867e-05 1.276e-06
# gbar_kdr.basal   5.353e-05 4.316e-05 4.078e-05 6.378e-05
# gbar_kir.basal   0.0001054 0.0002061 0.0001659 0.0001062
# gbar_bk.basal    2.102e-07 2.274e-05 2.102e-07 7.857e-08
# gbar_sk.basal    7.153e-06 2.042e-07 7.153e-06 3.678e-08

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
evaluate_all = False #True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="599.65">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="599.65">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_d32db_row0_col0, #T_d32db_row1_col1, #T_d32db_row2_col2, #T_d32db_row3_col3, #T_d32db_row4_col4, #T_d32db_row5_col5, #T_d32db_row6_col6, #T_d32db_row7_col7, #T_d32db_row8_col8, #T_d32db_row9_col9 {
#   background-color: #007fff;
# }
# #T_d32db_row0_col1, #T_d32db_row0_col4, #T_d32db_row0_col8, #T_d32db_row4_col0, #T_d32db_row4_col2, #T_d32db_row4_col3, #T_d32db_row4_col5, #T_d32db_row4_col7, #T_d32db_row4_col9, #T_d32db_row9_col6 {
#   background-color: #ffffff;
# }
# #T_d32db_row0_col2 {
#   background-color: #f2f8ff;
# }
# #T_d32db_row0_col3 {
#   background-color: #8cc5ff;
# }
# #T_d32db_row0_col5 {
#   background-color: #c4e1ff;
# }
# #T_d32db_row0_col6 {
#   background-color: #fdfeff;
# }
# #T_d32db_row0_col7, #T_d32db_row6_col1 {
#   background-color: #a2d0ff;
# }
# #T_d32db_row0_col9 {
#   background-color: #e8f3ff;
# }
# #T_d32db_row1_col0 {
#   background-color: #fefeff;
# }
# #T_d32db_row1_col2, #T_d32db_row3_col2, #T_d32db_row7_col5, #T_d32db_row8_col5 {
#   background-color: #cee6ff;
# }
# #T_d32db_row1_col3, #T_d32db_row6_col4 {
#   background-color: #dcedff;
# }
# #T_d32db_row1_col4, #T_d32db_row1_col5, #T_d32db_row2_col5 {
#   background-color: #d8ebff;
# }
# #T_d32db_row1_col6, #T_d32db_row9_col7 {
#   background-color: #b4d9ff;
# }
# #T_d32db_row1_col7, #T_d32db_row5_col2 {
#   background-color: #d6eaff;
# }
# #T_d32db_row1_col8 {
#   background-color: #95caff;
# }
# #T_d32db_row1_col9, #T_d32db_row5_col9 {
#   background-color: #d3e9ff;
# }
# #T_d32db_row2_col0, #T_d32db_row2_col6 {
#   background-color: #e7f3ff;
# }
# #T_d32db_row2_col1, #T_d32db_row5_col7 {
#   background-color: #c6e2ff;
# }
# #T_d32db_row2_col3, #T_d32db_row7_col2 {
#   background-color: #c8e3ff;
# }
# #T_d32db_row2_col4 {
#   background-color: #f3f9ff;
# }
# #T_d32db_row2_col7, #T_d32db_row7_col9, #T_d32db_row9_col1 {
#   background-color: #c2e0ff;
# }
# #T_d32db_row2_col8, #T_d32db_row3_col1 {
#   background-color: #daecff;
# }
# #T_d32db_row2_col9 {
#   background-color: #d0e7ff;
# }
# #T_d32db_row3_col0 {
#   background-color: #8ac4ff;
# }
# #T_d32db_row3_col4, #T_d32db_row7_col4, #T_d32db_row7_col6, #T_d32db_row8_col9 {
#   background-color: #fbfdff;
# }
# #T_d32db_row3_col5 {
#   background-color: #d1e8ff;
# }
# #T_d32db_row3_col6 {
#   background-color: #fcfdff;
# }
# #T_d32db_row3_col7, #T_d32db_row7_col3 {
#   background-color: #53a8ff;
# }
# #T_d32db_row3_col8, #T_d32db_row4_col6 {
#   background-color: #f5faff;
# }
# #T_d32db_row3_col9 {
#   background-color: #b2d8ff;
# }
# #T_d32db_row4_col1 {
#   background-color: #d9ebff;
# }
# #T_d32db_row4_col8, #T_d32db_row8_col0 {
#   background-color: #eff7ff;
# }
# #T_d32db_row5_col0 {
#   background-color: #badcff;
# }
# #T_d32db_row5_col1 {
#   background-color: #cde6ff;
# }
# #T_d32db_row5_col3, #T_d32db_row5_col6 {
#   background-color: #c9e4ff;
# }
# #T_d32db_row5_col4, #T_d32db_row7_col8 {
#   background-color: #f1f8ff;
# }
# #T_d32db_row5_col8 {
#   background-color: #cfe7ff;
# }
# #T_d32db_row6_col0 {
#   background-color: #e3f1ff;
# }
# #T_d32db_row6_col2 {
#   background-color: #d9ecff;
# }
# #T_d32db_row6_col3 {
#   background-color: #e6f2ff;
# }
# #T_d32db_row6_col5 {
#   background-color: #bedeff;
# }
# #T_d32db_row6_col7 {
#   background-color: #e5f2ff;
# }
# #T_d32db_row6_col8 {
#   background-color: #46a2ff;
# }
# #T_d32db_row6_col9 {
#   background-color: #f9fcff;
# }
# #T_d32db_row7_col0 {
#   background-color: #a0cfff;
# }
# #T_d32db_row7_col1, #T_d32db_row9_col0 {
#   background-color: #d4e9ff;
# }
# #T_d32db_row8_col1 {
#   background-color: #8dc5ff;
# }
# #T_d32db_row8_col2 {
#   background-color: #d7ebff;
# }
# #T_d32db_row8_col3 {
#   background-color: #eaf4ff;
# }
# #T_d32db_row8_col4 {
#   background-color: #e1f0ff;
# }
# #T_d32db_row8_col6 {
#   background-color: #49a4ff;
# }
# #T_d32db_row8_col7 {
#   background-color: #e7f2ff;
# }
# #T_d32db_row9_col2 {
#   background-color: #c7e3ff;
# }
# #T_d32db_row9_col3 {
#   background-color: #a5d2ff;
# }
# #T_d32db_row9_col4 {
#   background-color: #e9f4ff;
# }
# #T_d32db_row9_col5 {
#   background-color: #cce5ff;
# }
# #T_d32db_row9_col8 {
#   background-color: #f4f9ff;
# }
# </style>
# <table id="T_d32db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d32db_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d32db_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d32db_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d32db_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_d32db_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_d32db_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_d32db_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_d32db_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_d32db_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_d32db_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d32db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d32db_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_d32db_row0_col1" class="data row0 col1" >2.690000</td>
#       <td id="T_d32db_row0_col2" class="data row0 col2" >2.450000</td>
#       <td id="T_d32db_row0_col3" class="data row0 col3" >1.470000</td>
#       <td id="T_d32db_row0_col4" class="data row0 col4" >2.700000</td>
#       <td id="T_d32db_row0_col5" class="data row0 col5" >1.970000</td>
#       <td id="T_d32db_row0_col6" class="data row0 col6" >2.410000</td>
#       <td id="T_d32db_row0_col7" class="data row0 col7" >1.700000</td>
#       <td id="T_d32db_row0_col8" class="data row0 col8" >2.540000</td>
#       <td id="T_d32db_row0_col9" class="data row0 col9" >2.250000</td>
#     </tr>
#     <tr>
#       <th id="T_d32db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d32db_row1_col0" class="data row1 col0" >2.690000</td>
#       <td id="T_d32db_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d32db_row1_col2" class="data row1 col2" >2.090000</td>
#       <td id="T_d32db_row1_col3" class="data row1 col3" >2.300000</td>
#       <td id="T_d32db_row1_col4" class="data row1 col4" >2.290000</td>
#       <td id="T_d32db_row1_col5" class="data row1 col5" >2.170000</td>
#       <td id="T_d32db_row1_col6" class="data row1 col6" >1.710000</td>
#       <td id="T_d32db_row1_col7" class="data row1 col7" >2.240000</td>
#       <td id="T_d32db_row1_col8" class="data row1 col8" >1.490000</td>
#       <td id="T_d32db_row1_col9" class="data row1 col9" >2.050000</td>
#     </tr>
#     <tr>
#       <th id="T_d32db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d32db_row2_col0" class="data row2 col0" >2.450000</td>
#       <td id="T_d32db_row2_col1" class="data row2 col1" >2.090000</td>
#       <td id="T_d32db_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d32db_row2_col3" class="data row2 col3" >2.090000</td>
#       <td id="T_d32db_row2_col4" class="data row2 col4" >2.580000</td>
#       <td id="T_d32db_row2_col5" class="data row2 col5" >2.170000</td>
#       <td id="T_d32db_row2_col6" class="data row2 col6" >2.200000</td>
#       <td id="T_d32db_row2_col7" class="data row2 col7" >2.030000</td>
#       <td id="T_d32db_row2_col8" class="data row2 col8" >2.180000</td>
#       <td id="T_d32db_row2_col9" class="data row2 col9" >2.020000</td>
#     </tr>
#     <tr>
#       <th id="T_d32db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d32db_row3_col0" class="data row3 col0" >1.470000</td>
#       <td id="T_d32db_row3_col1" class="data row3 col1" >2.300000</td>
#       <td id="T_d32db_row3_col2" class="data row3 col2" >2.090000</td>
#       <td id="T_d32db_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_d32db_row3_col4" class="data row3 col4" >2.660000</td>
#       <td id="T_d32db_row3_col5" class="data row3 col5" >2.100000</td>
#       <td id="T_d32db_row3_col6" class="data row3 col6" >2.400000</td>
#       <td id="T_d32db_row3_col7" class="data row3 col7" >0.870000</td>
#       <td id="T_d32db_row3_col8" class="data row3 col8" >2.450000</td>
#       <td id="T_d32db_row3_col9" class="data row3 col9" >1.730000</td>
#     </tr>
#     <tr>
#       <th id="T_d32db_level0_row4" class="row_heading

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
