# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150908_c5_D1, &nbsp; animal_1_n33_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n33_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_506.soma.v': 'expdata/ECall_IV_ch3_506.dat',
    'IV_514.soma.v': 'expdata/ECall_IV_ch3_514.dat',    
    'IDthresh-sub_545.soma.v': 'expdata/ECall_IDthresh_ch3_545.dat',    
    'IDthresh_546.soma.v': 'expdata/ECall_IDthresh_ch3_546.dat',    
    'IDthresh_547.soma.v': 'expdata/ECall_IDthresh_ch3_547.dat',    
    'IDthresh_553.soma.v': 'expdata/ECall_IDthresh_ch3_553.dat',    
    'IDthresh_563.soma.v': 'expdata/ECall_IDthresh_ch3_563.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n33_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kaf.axonal: kaf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     kdr.axonal: kdr at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.01]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -70
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 2
#     Ra.all: ['all'] Ra = 150
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 20]
#     gbar_kaf.axonal: ['axonal'] gbar_kaf = [0, 5.0]
#     q_kaf.axonal: ['axonal'] q_kaf = 1.2310764224556812
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.1]
#     gbar_kdr.axonal: ['axonal'] gbar_kdr = [0, 0.002]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.1]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 10]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1.2310764224556812
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.003, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -23.72098402710996
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 3
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 3
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.2]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.0, 0.5]
#     q_kaf.basal: ['basal'] q_kaf = 1.2310764224556812
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -23.72098402710996
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 14
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 3
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 3

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.axonal
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.axonal
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.001251 0.0001531  0.005829  0.007657 0.0002491  0.002122
# g_pas.somatic    0.0001027  0.001876  0.001973  0.001222  0.001391 3.298e-05
# g_pas.basal      6.275e-05 1.141e-05 0.0001284  0.000214 0.0004449 0.0001347
# gbar_naf.axonal      19.39     19.57     19.08     19.49     18.56     18.39
# gbar_kaf.axonal    0.06668   0.03559  0.005247  0.003109     0.106   0.03911
# gbar_kas.axonal    0.01829   0.01627   0.02175    0.0386   0.04248   0.05342
# gbar_kdr.axonal   0.001662  0.001647  0.001935  0.001926  0.001869  0.001914
# gbar_Im.axonal     0.01241   0.08452   0.04485   0.04485   0.02411   0.02223
# gbar_naf.somatic     6.785     7.978     9.119     9.148     9.733     7.864
# gbar_kaf.somatic     1.157    0.1809   0.02217   0.02217    0.1886    0.4502
# gbar_kas.somatic 0.0004581   0.01337 0.0006054 0.0006054  0.004156  0.005829
# gbar_kdr.somatic   0.00156  0.001344  0.001326  0.001311  0.001395  0.001415
# gbar_kir.somatic  0.004965  0.004135  0.003148  0.007933   0.01064   0.01216
# gbar_bk.somatic   0.001527    0.0009   0.00116  0.001381  0.001423  0.001273
# gbar_sk.somatic  0.0009395 2.076e-05 0.0002584 1.103e-05 0.0009171  3.87e-05
# gbar_Im.somatic    0.00485  0.006726  0.009523  0.008498  0.005568  0.006047
# gbar_naf.basal      0.1999     0.175    0.1639     0.156    0.1994    0.1971
# gbar_kaf.basal     0.05169 0.0002068 0.0004268   0.00222  0.002472  0.004672
# gbar_kas.basal    0.001006 4.412e-05  0.001075  0.001334 0.0009552  0.001985
# gbar_kdr.basal    0.001748  0.001479  0.001236  0.001236  0.001133  0.001214
# gbar_kir.basal    0.001245  0.002409   0.00188  0.001395 0.0003543 0.0003993
# gbar_bk.basal    0.0002057 0.0004084 0.0002089 0.0002089 8.093e-05 0.0004427
# gbar_sk.basal    0.0003351 0.0001376 2.869e-05 2.869e-05 2.197e-06 0.0008287
#
#                          6         7         8         9
# g_pas.axonal     0.0002398  0.002198  0.006546  0.004778
# g_pas.somatic    0.0006629 0.0008118  0.000161 0.0002198
# g_pas.basal      0.0001824 5.421e-05  9.83e-05 1.455e-05
# gbar_naf.axonal      17.51     11.99     17.55     18.57
# gbar_kaf.axonal    0.08942    0.2084    0.4122    0.6311
# gbar_kas.axonal   0.009778  0.002643   0.02791   0.02932
# gbar_kdr.axonal   0.001677  0.001811  0.001664  0.001906
# gbar_Im.axonal      0.0594   0.02195   0.05111   0.05071
# gbar_naf.somatic     9.514     9.049     9.986      9.22
# gbar_kaf.somatic   0.05726   0.00121   0.05726 8.181e-05
# gbar_kas.somatic   0.01586   0.02204   0.02557   0.06918
# gbar_kdr.somatic  0.001521 0.0009082   0.00111  0.001257
# gbar_kir.somatic  0.007134  0.004162   0.00499  0.006838
# gbar_bk.somatic  0.0007996 0.0009975  0.001045 0.0008512
# gbar_sk.somatic  3.519e-05  0.000211 9.939e-05 0.0009631
# gbar_Im.somatic   0.008203  0.009455  0.002497  0.008348
# gbar_naf.basal      0.1908    0.1921     0.177    0.1959
# gbar_kaf.basal    0.004374   0.08407   0.01223   0.03337
# gbar_kas.basal   0.0008848  0.001048 0.0008848  0.003166
# gbar_kdr.basal    0.001148 0.0008255  0.001151  0.001224
# gbar_kir.basal    0.002094 0.0001987   0.00228 0.0001275
# gbar_bk.basal    0.0006398 0.0002867 0.0007147 0.0002571
# gbar_sk.basal    7.785e-05 1.101e-05 7.785e-05 2.816e-05

# %%
axs = bm.hist(grid=False, xrot=20, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_8f92b_row0_col0, #T_8f92b_row1_col1, #T_8f92b_row2_col2, #T_8f92b_row3_col3, #T_8f92b_row4_col4, #T_8f92b_row5_col5, #T_8f92b_row6_col6, #T_8f92b_row7_col7, #T_8f92b_row8_col8, #T_8f92b_row9_col9 {
#   background-color: #007fff;
# }
# #T_8f92b_row0_col1, #T_8f92b_row3_col7, #T_8f92b_row7_col2 {
#   background-color: #eff7ff;
# }
# #T_8f92b_row0_col2, #T_8f92b_row6_col0 {
#   background-color: #eaf4ff;
# }
# #T_8f92b_row0_col3 {
#   background-color: #f5faff;
# }
# #T_8f92b_row0_col4, #T_8f92b_row9_col0 {
#   background-color: #e6f2ff;
# }
# #T_8f92b_row0_col5, #T_8f92b_row3_col6 {
#   background-color: #c7e3ff;
# }
# #T_8f92b_row0_col6, #T_8f92b_row7_col4 {
#   background-color: #edf6ff;
# }
# #T_8f92b_row0_col7, #T_8f92b_row2_col6 {
#   background-color: #d9ecff;
# }
# #T_8f92b_row0_col8 {
#   background-color: #e3f1ff;
# }
# #T_8f92b_row0_col9, #T_8f92b_row2_col8, #T_8f92b_row5_col8, #T_8f92b_row8_col2 {
#   background-color: #d8ebff;
# }
# #T_8f92b_row1_col0, #T_8f92b_row1_col7, #T_8f92b_row1_col9, #T_8f92b_row4_col8, #T_8f92b_row7_col3, #T_8f92b_row9_col1, #T_8f92b_row9_col2, #T_8f92b_row9_col4, #T_8f92b_row9_col5, #T_8f92b_row9_col6 {
#   background-color: #ffffff;
# }
# #T_8f92b_row1_col2, #T_8f92b_row1_col8, #T_8f92b_row3_col0 {
#   background-color: #f2f8ff;
# }
# #T_8f92b_row1_col3, #T_8f92b_row1_col5 {
#   background-color: #f7fbff;
# }
# #T_8f92b_row1_col4, #T_8f92b_row7_col5, #T_8f92b_row8_col4 {
#   background-color: #f8fbff;
# }
# #T_8f92b_row1_col6 {
#   background-color: #b6daff;
# }
# #T_8f92b_row2_col0, #T_8f92b_row3_col5, #T_8f92b_row4_col3, #T_8f92b_row7_col6 {
#   background-color: #e2f0ff;
# }
# #T_8f92b_row2_col1, #T_8f92b_row8_col1 {
#   background-color: #dcedff;
# }
# #T_8f92b_row2_col3 {
#   background-color: #81c0ff;
# }
# #T_8f92b_row2_col4 {
#   background-color: #e9f4ff;
# }
# #T_8f92b_row2_col5 {
#   background-color: #fafcff;
# }
# #T_8f92b_row2_col7, #T_8f92b_row3_col8, #T_8f92b_row8_col0 {
#   background-color: #dbedff;
# }
# #T_8f92b_row2_col9, #T_8f92b_row4_col1, #T_8f92b_row5_col7 {
#   background-color: #e7f3ff;
# }
# #T_8f92b_row3_col1, #T_8f92b_row7_col0 {
#   background-color: #e5f2ff;
# }
# #T_8f92b_row3_col2 {
#   background-color: #84c1ff;
# }
# #T_8f92b_row3_col4, #T_8f92b_row5_col3, #T_8f92b_row7_col8 {
#   background-color: #e1f0ff;
# }
# #T_8f92b_row3_col9, #T_8f92b_row5_col9 {
#   background-color: #ebf5ff;
# }
# #T_8f92b_row4_col0, #T_8f92b_row5_col1 {
#   background-color: #e4f1ff;
# }
# #T_8f92b_row4_col2 {
#   background-color: #f0f7ff;
# }
# #T_8f92b_row4_col5, #T_8f92b_row6_col7 {
#   background-color: #d4e9ff;
# }
# #T_8f92b_row4_col6, #T_8f92b_row5_col6 {
#   background-color: #cfe7ff;
# }
# #T_8f92b_row4_col7 {
#   background-color: #e0efff;
# }
# #T_8f92b_row4_col9 {
#   background-color: #eef6ff;
# }
# #T_8f92b_row5_col0 {
#   background-color: #c4e1ff;
# }
# #T_8f92b_row5_col2 {
#   background-color: #fefeff;
# }
# #T_8f92b_row5_col4 {
#   background-color: #d1e8ff;
# }
# #T_8f92b_row6_col1 {
#   background-color: #a9d3ff;
# }
# #T_8f92b_row6_col2 {
#   background-color: #ddeeff;
# }
# #T_8f92b_row6_col3 {
#   background-color: #c7e2ff;
# }
# #T_8f92b_row6_col4 {
#   background-color: #cee6ff;
# }
# #T_8f92b_row6_col5 {
#   background-color: #d0e7ff;
# }
# #T_8f92b_row6_col8 {
#   background-color: #a6d2ff;
# }
# #T_8f92b_row6_col9 {
#   background-color: #ecf5ff;
# }
# #T_8f92b_row7_col1 {
#   background-color: #fcfdff;
# }
# #T_8f92b_row7_col9 {
#   background-color: #b7dbff;
# }
# #T_8f92b_row8_col3 {
#   background-color: #d6eaff;
# }
# #T_8f92b_row8_col5 {
#   background-color: #d5eaff;
# }
# #T_8f92b_row8_col6 {
#   background-color: #a3d0ff;
# }
# #T_8f92b_row8_col7 {
#   background-color: #cfe6ff;
# }
# #T_8f92b_row8_col9 {
#   background-color: #c0dfff;
# }
# #T_8f92b_row9_col3 {
#   background-color: #fdfeff;
# }
# #T_8f92b_row9_col7 {
#   background-color: #b9dcff;
# }
# #T_8f92b_row9_col8 {
#   background-color: #d3e9ff;
# }
# </style>
# <table id="T_8f92b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f92b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8f92b_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8f92b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_8f92b_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_8f92b_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_8f92b_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_8f92b_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_8f92b_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_8f92b_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_8f92b_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f92b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f92b_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_8f92b_row0_col1" class="data row0 col1" >2.680000</td>
#       <td id="T_8f92b_row0_col2" class="data row0 col2" >2.380000</td>
#       <td id="T_8f92b_row0_col3" class="data row0 col3" >2.550000</td>
#       <td id="T_8f92b_row0_col4" class="data row0 col4" >2.400000</td>
#       <td id="T_8f92b_row0_col5" class="data row0 col5" >2.060000</td>
#       <td id="T_8f92b_row0_col6" class="data row0 col6" >2.460000</td>
#       <td id="T_8f92b_row0_col7" class="data row0 col7" >2.410000</td>
#       <td id="T_8f92b_row0_col8" class="data row0 col8" >2.310000</td>
#       <td id="T_8f92b_row0_col9" class="data row0 col9" >2.420000</td>
#     </tr>
#     <tr>
#       <th id="T_8f92b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f92b_row1_col0" class="data row1 col0" >2.680000</td>
#       <td id="T_8f92b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_8f92b_row1_col2" class="data row1 col2" >2.460000</td>
#       <td id="T_8f92b_row1_col3" class="data row1 col3" >2.570000</td>
#       <td id="T_8f92b_row1_col4" class="data row1 col4" >2.590000</td>
#       <td id="T_8f92b_row1_col5" class="data row1 col5" >2.550000</td>
#       <td id="T_8f92b_row1_col6" class="data row1 col6" >1.890000</td>
#       <td id="T_8f92b_row1_col7" class="data row1 col7" >2.820000</td>
#       <td id="T_8f92b_row1_col8" class="data row1 col8" >2.460000</td>
#       <td id="T_8f92b_row1_col9" class="data row1 col9" >2.850000</td>
#     </tr>
#     <tr>
#       <th id="T_8f92b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f92b_row2_col0" class="data row2 col0" >2.380000</td>
#       <td id="T_8f92b_row2_col1" class="data row2 col1" >2.460000</td>
#       <td id="T_8f92b_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8f92b_row2_col3" class="data row2 col3" >1.350000</td>
#       <td id="T_8f92b_row2_col4" class="data row2 col4" >2.440000</td>
#       <td id="T_8f92b_row2_col5" class="data row2 col5" >2.580000</td>
#       <td id="T_8f92b_row2_col6" class="data row2 col6" >2.250000</td>
#       <td id="T_8f92b_row2_col7" class="data row2 col7" >2.430000</td>
#       <td id="T_8f92b_row2_col8" class="data row2 col8" >2.200000</td>
#       <td id="T_8f92b_row2_col9" class="data row2 col9" >2.590000</td>
#     </tr>
#     <tr>
#       <th id="T_8f92b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f92b_row3_col0" class="data row3 col0" >2.550000</td>
#       <td id="T_8f92b_row3_col1" class="data row3 col1" >2.570000</td>
#       <td id="T_8f92b_row3_col2" class="data row3 col2" >1.350000</td>
#       <td id="T_8f92b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_8f92b_row3_col4" class="data row3 col4" >2.350000</td>
#       <td id="T_8f92b_row3_col5" class="data row3 col5" >2.340000</td>
#       <td id="T_8f92b_row3_col6" class="data row3 col6" >2.070000</td>
#       <td id="T_8f92b_row3_col7" class="data row3 col7" >2.650000</td>
#       <td id="T_8f92b_row3_col8" class="data row3 col8" >2.230000</td>
#       <td id="T_8f92b_row3_col9" class="data row3 col9" >2.630000</td>
#     </tr>
#     <tr>
#       <th id="T_8f92b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f92b_row4_col0" class="data row4 col0" >2.400000</td>
#       <td id="T_8f92b_row4_col1" class="data row4 col1" >2.590000</

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
