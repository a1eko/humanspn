# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150908_c5_D1, &nbsp; animal_1_n33_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n33_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_504.soma.v': 'expdata/ECall_IV_ch3_504.dat',
    'IV_506.soma.v': 'expdata/ECall_IV_ch3_506.dat',
    'IV_508.soma.v': 'expdata/ECall_IV_ch3_508.dat',
    'IV_510.soma.v': 'expdata/ECall_IV_ch3_510.dat',
    'IV_512.soma.v': 'expdata/ECall_IV_ch3_512.dat',
    'IV_514.soma.v': 'expdata/ECall_IV_ch3_514.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n33_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -85.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-80, -60]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20
#     q_kir.somatic: ['somatic'] q_kir = 1
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20
#     q_kir.basal: ['basal'] q_kir = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.01542   0.01509   0.01502   0.01455   0.01663   0.01382
# g_pas.somatic     0.004505  0.001028 0.0009213  0.001029  0.001003  0.001029
# g_pas.basal      0.0001796 0.0007939 0.0008191 0.0007887   0.00079 0.0007912
# e_pas.all           -68.87    -69.29    -69.31    -69.32    -69.21    -69.32
# gbar_kir.somatic   0.02918   0.02781   0.02781   0.02772   0.02781   0.02772
# gbar_kir.basal   0.0001535 0.0004605 0.0004605 0.0004605 0.0004605 0.0004605
#
#                          6         7         8         9
# g_pas.axonal       0.01382   0.01533  0.006316   0.00986
# g_pas.somatic     0.001029 0.0009227  0.002479  0.002042
# g_pas.basal      0.0007901 0.0007911 0.0005216 0.0005824
# e_pas.all           -69.32    -68.83    -69.34    -69.31
# gbar_kir.somatic   0.02772   0.02781   0.02756   0.02782
# gbar_kir.basal   0.0004605 0.0005526 0.0004104 0.0003841

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_0045c_row0_col0, #T_0045c_row1_col1, #T_0045c_row2_col2, #T_0045c_row3_col3, #T_0045c_row4_col4, #T_0045c_row5_col5, #T_0045c_row5_col6, #T_0045c_row6_col5, #T_0045c_row6_col6, #T_0045c_row7_col7, #T_0045c_row8_col8, #T_0045c_row9_col9 {
#   background-color: #007fff;
# }
# #T_0045c_row0_col1, #T_0045c_row0_col2, #T_0045c_row0_col3, #T_0045c_row0_col4, #T_0045c_row0_col5, #T_0045c_row0_col6, #T_0045c_row0_col7, #T_0045c_row0_col8, #T_0045c_row0_col9, #T_0045c_row7_col0 {
#   background-color: #ffffff;
# }
# #T_0045c_row1_col0, #T_0045c_row3_col0, #T_0045c_row5_col0, #T_0045c_row6_col0 {
#   background-color: #f3f9ff;
# }
# #T_0045c_row1_col2, #T_0045c_row3_col2 {
#   background-color: #0e86ff;
# }
# #T_0045c_row1_col3, #T_0045c_row3_col1 {
#   background-color: #0581ff;
# }
# #T_0045c_row1_col4, #T_0045c_row4_col1 {
#   background-color: #0c85ff;
# }
# #T_0045c_row1_col5, #T_0045c_row1_col6, #T_0045c_row5_col1, #T_0045c_row6_col1 {
#   background-color: #0a84ff;
# }
# #T_0045c_row1_col7, #T_0045c_row3_col7, #T_0045c_row4_col7 {
#   background-color: #1a8cff;
# }
# #T_0045c_row1_col8 {
#   background-color: #bcddff;
# }
# #T_0045c_row1_col9 {
#   background-color: #87c2ff;
# }
# #T_0045c_row2_col0 {
#   background-color: #fafcff;
# }
# #T_0045c_row2_col1, #T_0045c_row2_col3 {
#   background-color: #0f86ff;
# }
# #T_0045c_row2_col4, #T_0045c_row2_col5, #T_0045c_row2_col6, #T_0045c_row3_col4, #T_0045c_row4_col2, #T_0045c_row4_col3, #T_0045c_row5_col2, #T_0045c_row6_col2 {
#   background-color: #1187ff;
# }
# #T_0045c_row2_col7, #T_0045c_row7_col2 {
#   background-color: #1589ff;
# }
# #T_0045c_row2_col8, #T_0045c_row4_col8 {
#   background-color: #c5e2ff;
# }
# #T_0045c_row2_col9 {
#   background-color: #93c9ff;
# }
# #T_0045c_row3_col5, #T_0045c_row3_col6, #T_0045c_row5_col3, #T_0045c_row6_col3 {
#   background-color: #0782ff;
# }
# #T_0045c_row3_col8 {
#   background-color: #b9dbff;
# }
# #T_0045c_row3_col9 {
#   background-color: #84c1ff;
# }
# #T_0045c_row4_col0 {
#   background-color: #f5faff;
# }
# #T_0045c_row4_col5, #T_0045c_row4_col6, #T_0045c_row5_col4, #T_0045c_row6_col4 {
#   background-color: #168aff;
# }
# #T_0045c_row4_col9 {
#   background-color: #90c7ff;
# }
# #T_0045c_row5_col7, #T_0045c_row6_col7 {
#   background-color: #1c8dff;
# }
# #T_0045c_row5_col8, #T_0045c_row6_col8 {
#   background-color: #b6daff;
# }
# #T_0045c_row5_col9, #T_0045c_row6_col9 {
#   background-color: #81bfff;
# }
# #T_0045c_row7_col1, #T_0045c_row7_col3, #T_0045c_row7_col4 {
#   background-color: #1b8cff;
# }
# #T_0045c_row7_col5, #T_0045c_row7_col6 {
#   background-color: #1e8eff;
# }
# #T_0045c_row7_col8 {
#   background-color: #cbe5ff;
# }
# #T_0045c_row7_col9, #T_0045c_row8_col2 {
#   background-color: #9dceff;
# }
# #T_0045c_row8_col0 {
#   background-color: #c8e3ff;
# }
# #T_0045c_row8_col1 {
#   background-color: #9bccff;
# }
# #T_0045c_row8_col3 {
#   background-color: #98cbff;
# }
# #T_0045c_row8_col4 {
#   background-color: #a0cfff;
# }
# #T_0045c_row8_col5, #T_0045c_row8_col6 {
#   background-color: #96caff;
# }
# #T_0045c_row8_col7 {
#   background-color: #9fcfff;
# }
# #T_0045c_row8_col9 {
#   background-color: #4ea6ff;
# }
# #T_0045c_row9_col0 {
#   background-color: #c1dfff;
# }
# #T_0045c_row9_col1 {
#   background-color: #6bb4ff;
# }
# #T_0045c_row9_col2 {
#   background-color: #72b8ff;
# }
# #T_0045c_row9_col3 {
#   background-color: #69b3ff;
# }
# #T_0045c_row9_col4 {
#   background-color: #71b8ff;
# }
# #T_0045c_row9_col5, #T_0045c_row9_col6 {
#   background-color: #66b2ff;
# }
# #T_0045c_row9_col7 {
#   background-color: #77baff;
# }
# #T_0045c_row9_col8 {
#   background-color: #4ba5ff;
# }
# </style>
# <table id="T_0045c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0045c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_0045c_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_0045c_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_0045c_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_0045c_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_0045c_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_0045c_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_0045c_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_0045c_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_0045c_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0045c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0045c_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_0045c_row0_col1" class="data row0 col1" >1.020000</td>
#       <td id="T_0045c_row0_col2" class="data row0 col2" >1.050000</td>
#       <td id="T_0045c_row0_col3" class="data row0 col3" >1.020000</td>
#       <td id="T_0045c_row0_col4" class="data row0 col4" >1.030000</td>
#       <td id="T_0045c_row0_col5" class="data row0 col5" >1.020000</td>
#       <td id="T_0045c_row0_col6" class="data row0 col6" >1.020000</td>
#       <td id="T_0045c_row0_col7" class="data row0 col7" >1.070000</td>
#       <td id="T_0045c_row0_col8" class="data row0 col8" >0.840000</td>
#       <td id="T_0045c_row0_col9" class="data row0 col9" >0.810000</td>
#     </tr>
#     <tr>
#       <th id="T_0045c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0045c_row1_col0" class="data row1 col0" >1.020000</td>
#       <td id="T_0045c_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0045c_row1_col2" class="data row1 col2" >0.060000</td>
#       <td id="T_0045c_row1_col3" class="data row1 col3" >0.020000</td>
#       <td id="T_0045c_row1_col4" class="data row1 col4" >0.050000</td>
#       <td id="T_0045c_row1_col5" class="data row1 col5" >0.040000</td>
#       <td id="T_0045c_row1_col6" class="data row1 col6" >0.040000</td>
#       <td id="T_0045c_row1_col7" class="data row1 col7" >0.110000</td>
#       <td id="T_0045c_row1_col8" class="data row1 col8" >0.620000</td>
#       <td id="T_0045c_row1_col9" class="data row1 col9" >0.430000</td>
#     </tr>
#     <tr>
#       <th id="T_0045c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0045c_row2_col0" class="data row2 col0" >1.050000</td>
#       <td id="T_0045c_row2_col1" class="data row2 col1" >0.060000</td>
#       <td id="T_0045c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_0045c_row2_col3" class="data row2 col3" >0.060000</td>
#       <td id="T_0045c_row2_col4" class="data row2 col4" >0.070000</td>
#       <td id="T_0045c_row2_col5" class="data row2 col5" >0.070000</td>
#       <td id="T_0045c_row2_col6" class="data row2 col6" >0.070000</td>
#       <td id="T_0045c_row2_col7" class="data row2 col7" >0.090000</td>
#       <td id="T_0045c_row2_col8" class="data row2 col8" >0.650000</td>
#       <td id="T_0045c_row2_col9" class="data row2 col9" >0.470000</td>
#     </tr>
#     <tr>
#       <th id="T_0045c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0045c_row3_col0" class="data row3 col0" >1.020000</td>
#       <td id="T_0045c_row3_col1" class="data row3 col1" >0.020000</td>
#       <td id="T_0045c_row3_col2" class="data row3 col2" >0.060000</td>
#       <td id="T_0045c_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_0045c_row3_col4" class="data row3 col4" >0.070000</td>
#       <td id="T_0045c_row3_col5" class="data row3 col5" >0.030000</td>
#       <td id="T_0045c_row3_col6" class="data row3 col6" >0.030000</td>
#       <td id="T_0045c_row3_col7" class="data row3 col7" >0.110000</td>
#       <td id="T_0045c_row3_col8" class="data row3 col8" >0.610000</td>
#       <td id="T_0045c_row3_col9" class="data row3 col9" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_0045c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0045c_row4_col0" class="data row4 col0" >1.030000</td>
#       <td id="T_0045c_row4_col1" class="data row4 col1" >0.050000</td>
#       <td id="T_0045c_row4_col2" class="data row4 col2" >0.070000</td>
#       <td id="T_0045c_row4_col3" class="data row4 col3" >0.070000</td>
#       <td id="T_0045c_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_0045c_row4_col5" class=

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
e_pas = np.mean([x['e_pas.all'] for x in best_models])
#Ra = np.mean([x['Ra.all'] for x in best_models])
#shift_kir = np.mean([x['shift_kir.somatic'] for x in best_models] + [x['shift_kir.basal'] for x in best_models])

# %%
print(f'{e_pas=}')
# Out:
# e_pas=-69.21282015145744

# %%
best_models[0]['e_pas.all'] #, best_models[0]['shift_kir.somatic']
# Out:
# -68.87319110837785
