# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150908_c5_D1, &nbsp; animal_1_n33_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n33_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_506.soma.v': 'expdata/ECall_IV_ch3_506.dat',
    'IV_514.soma.v': 'expdata/ECall_IV_ch3_514.dat',    
    'IDthresh-sub_545.soma.v': 'expdata/ECall_IDthresh_ch3_545.dat',    
    'IDthresh_546.soma.v': 'expdata/ECall_IDthresh_ch3_546.dat',    
    'IDthresh_547.soma.v': 'expdata/ECall_IDthresh_ch3_547.dat',    
    'IDthresh_553.soma.v': 'expdata/ECall_IDthresh_ch3_553.dat',    
    'IDthresh_563.soma.v': 'expdata/ECall_IDthresh_ch3_563.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n33_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.01]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = -70
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 2
#     Ra.all: ['all'] Ra = 150
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -95
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 5]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.1]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.1]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1.2310764224556812
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.001]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.003, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -23.72098402710996
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0, 0.001]
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0, 0.0001]
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.1]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.0, 0.5]
#     q_kaf.basal: ['basal'] q_kaf = 1.2310764224556812
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.001]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -23.72098402710996
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.0001]
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 1e-05]

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal      0.007814  0.007147  0.009311  0.009941  0.008076   0.00306
# g_pas.somatic    0.0008165 0.0005328 0.0008165 0.0001048 0.0001637  0.001171
# g_pas.basal      1.007e-05 3.798e-05 1.206e-05 1.607e-05 1.041e-05 4.082e-05
# gbar_naf.axonal      1.035   0.04797     1.035     0.147      2.71    0.1247
# gbar_kas.axonal    0.08967   0.06518   0.05993   0.08267   0.05145    0.0708
# gbar_Im.axonal     0.02417   0.03051   0.02157    0.0461   0.03435  0.008894
# gbar_naf.somatic     17.45     18.09     17.45     18.37     18.92     15.93
# gbar_kaf.somatic      1.45     2.031     1.475     1.817     2.268     1.167
# gbar_kas.somatic   0.01674  0.004463   0.01674   0.01013  0.004313  0.004077
# gbar_kdr.somatic 0.0002575 0.0007158  0.000286 0.0002112 0.0007617 0.0003595
# gbar_kir.somatic   0.03288   0.03618   0.03288   0.01088   0.00813   0.03748
# gbar_bk.somatic  2.112e-05 0.0002959 1.777e-05 8.736e-05 0.0003424 2.735e-05
# gbar_sk.somatic  8.799e-05 7.656e-07 7.976e-05  1.75e-06 6.905e-05 9.983e-05
# gbar_Im.somatic  0.0005826  0.001265  0.001199  0.002344 0.0001055  0.003114
# gbar_naf.basal     0.08639   0.09097   0.08639   0.08195    0.0794   0.08244
# gbar_kaf.basal     0.01837  0.005548  0.002293   0.00347  0.001413    0.0122
# gbar_kas.basal    0.002446 0.0006205  0.002446  0.001662 4.221e-05  0.001698
# gbar_kdr.basal   0.0009149  0.000987 0.0009901 0.0005224 0.0006028 0.0006394
# gbar_kir.basal   0.0008456 0.0005246 0.0009656  0.002949  0.002991  0.001021
# gbar_bk.basal    8.781e-05 9.947e-05 9.332e-05 6.344e-05 9.996e-05 7.229e-05
# gbar_sk.basal    3.057e-06 3.839e-06 8.452e-06 3.243e-06 5.407e-06   7.9e-06
#
#                          6         7         8         9
# g_pas.axonal      0.007382  0.007096  0.005037  0.005567
# g_pas.somatic    0.0005697 0.0008165 0.0002129 1.013e-05
# g_pas.basal      3.649e-05 1.001e-05 1.002e-05  2.92e-05
# gbar_naf.axonal     0.2571     1.036     1.368   0.02797
# gbar_kas.axonal    0.06915   0.06796   0.09915   0.02433
# gbar_Im.axonal     0.03051   0.02401  0.006928   0.04399
# gbar_naf.somatic     18.11     18.35      18.1     19.72
# gbar_kaf.somatic     1.631     1.553     1.952     2.494
# gbar_kas.somatic  0.004449   0.01438  0.002231  0.001075
# gbar_kdr.somatic 0.0003349 0.0003337 3.952e-06 6.864e-05
# gbar_kir.somatic   0.04132   0.03479  0.005675  0.005834
# gbar_bk.somatic  0.0001532 5.373e-05 0.0007191 2.036e-06
# gbar_sk.somatic  1.827e-05 9.023e-05 2.292e-07 4.243e-08
# gbar_Im.somatic  0.0008984 0.0006827 0.0001128  0.002316
# gbar_naf.basal      0.0988   0.08524   0.07528   0.03928
# gbar_kaf.basal     0.04703   0.01839  0.001347 0.0002665
# gbar_kas.basal   6.337e-05  0.002446 0.0009379  0.001459
# gbar_kdr.basal   0.0009178  0.000761 0.0007277 0.0009438
# gbar_kir.basal   0.0001075 0.0006125   0.00337  0.002879
# gbar_bk.basal    9.532e-05 7.973e-05 6.523e-05 8.692e-05
# gbar_sk.basal    4.235e-06 3.057e-06 8.406e-06 7.034e-06

# %%
axs = bm.hist(grid=False, xrot=20, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_cf8e6_row0_col0, #T_cf8e6_row1_col1, #T_cf8e6_row2_col2, #T_cf8e6_row3_col3, #T_cf8e6_row4_col4, #T_cf8e6_row5_col5, #T_cf8e6_row6_col6, #T_cf8e6_row7_col7, #T_cf8e6_row8_col8, #T_cf8e6_row9_col9 {
#   background-color: #007fff;
# }
# #T_cf8e6_row0_col1, #T_cf8e6_row0_col4, #T_cf8e6_row2_col3 {
#   background-color: #d2e8ff;
# }
# #T_cf8e6_row0_col2 {
#   background-color: #61b0ff;
# }
# #T_cf8e6_row0_col3 {
#   background-color: #deeeff;
# }
# #T_cf8e6_row0_col5, #T_cf8e6_row5_col2 {
#   background-color: #9ccdff;
# }
# #T_cf8e6_row0_col6 {
#   background-color: #add6ff;
# }
# #T_cf8e6_row0_col7 {
#   background-color: #2f96ff;
# }
# #T_cf8e6_row0_col8, #T_cf8e6_row5_col4, #T_cf8e6_row7_col8 {
#   background-color: #ebf5ff;
# }
# #T_cf8e6_row0_col9 {
#   background-color: #f7fbff;
# }
# #T_cf8e6_row1_col0, #T_cf8e6_row1_col3 {
#   background-color: #bfdfff;
# }
# #T_cf8e6_row1_col2 {
#   background-color: #c7e3ff;
# }
# #T_cf8e6_row1_col4 {
#   background-color: #d6eaff;
# }
# #T_cf8e6_row1_col5, #T_cf8e6_row6_col0 {
#   background-color: #b3d9ff;
# }
# #T_cf8e6_row1_col6 {
#   background-color: #a0cfff;
# }
# #T_cf8e6_row1_col7 {
#   background-color: #b0d7ff;
# }
# #T_cf8e6_row1_col8 {
#   background-color: #dcedff;
# }
# #T_cf8e6_row1_col9, #T_cf8e6_row2_col8 {
#   background-color: #e0efff;
# }
# #T_cf8e6_row2_col0 {
#   background-color: #5badff;
# }
# #T_cf8e6_row2_col1, #T_cf8e6_row4_col0 {
#   background-color: #cee6ff;
# }
# #T_cf8e6_row2_col4 {
#   background-color: #c6e2ff;
# }
# #T_cf8e6_row2_col5, #T_cf8e6_row7_col5 {
#   background-color: #9accff;
# }
# #T_cf8e6_row2_col6 {
#   background-color: #bcddff;
# }
# #T_cf8e6_row2_col7 {
#   background-color: #65b1ff;
# }
# #T_cf8e6_row2_col9 {
#   background-color: #e8f3ff;
# }
# #T_cf8e6_row3_col0, #T_cf8e6_row5_col1 {
#   background-color: #bbddff;
# }
# #T_cf8e6_row3_col1, #T_cf8e6_row5_col6 {
#   background-color: #b1d8ff;
# }
# #T_cf8e6_row3_col2 {
#   background-color: #bdddff;
# }
# #T_cf8e6_row3_col4 {
#   background-color: #cbe4ff;
# }
# #T_cf8e6_row3_col5, #T_cf8e6_row4_col7, #T_cf8e6_row7_col1 {
#   background-color: #c5e2ff;
# }
# #T_cf8e6_row3_col6 {
#   background-color: #c3e0ff;
# }
# #T_cf8e6_row3_col7 {
#   background-color: #b2d8ff;
# }
# #T_cf8e6_row3_col8 {
#   background-color: #d4e9ff;
# }
# #T_cf8e6_row3_col9 {
#   background-color: #d0e7ff;
# }
# #T_cf8e6_row4_col1, #T_cf8e6_row8_col7 {
#   background-color: #e7f3ff;
# }
# #T_cf8e6_row4_col2, #T_cf8e6_row6_col2 {
#   background-color: #cfe7ff;
# }
# #T_cf8e6_row4_col3 {
#   background-color: #ecf5ff;
# }
# #T_cf8e6_row4_col5 {
#   background-color: #f4f9ff;
# }
# #T_cf8e6_row4_col6 {
#   background-color: #c3e1ff;
# }
# #T_cf8e6_row4_col8 {
#   background-color: #b4d9ff;
# }
# #T_cf8e6_row4_col9, #T_cf8e6_row5_col8 {
#   background-color: #f2f8ff;
# }
# #T_cf8e6_row5_col0 {
#   background-color: #94c9ff;
# }
# #T_cf8e6_row5_col3 {
#   background-color: #ddeeff;
# }
# #T_cf8e6_row5_col7 {
#   background-color: #90c7ff;
# }
# #T_cf8e6_row5_col9 {
#   background-color: #e4f1ff;
# }
# #T_cf8e6_row6_col1, #T_cf8e6_row8_col4 {
#   background-color: #b6daff;
# }
# #T_cf8e6_row6_col3, #T_cf8e6_row8_col2 {
#   background-color: #eef6ff;
# }
# #T_cf8e6_row6_col4 {
#   background-color: #cde6ff;
# }
# #T_cf8e6_row6_col5 {
#   background-color: #c1e0ff;
# }
# #T_cf8e6_row6_col7 {
#   background-color: #a4d1ff;
# }
# #T_cf8e6_row6_col8, #T_cf8e6_row6_col9, #T_cf8e6_row8_col5, #T_cf8e6_row9_col0, #T_cf8e6_row9_col1, #T_cf8e6_row9_col2, #T_cf8e6_row9_col3, #T_cf8e6_row9_col4, #T_cf8e6_row9_col6, #T_cf8e6_row9_col7 {
#   background-color: #ffffff;
# }
# #T_cf8e6_row7_col0 {
#   background-color: #3097ff;
# }
# #T_cf8e6_row7_col2 {
#   background-color: #6db5ff;
# }
# #T_cf8e6_row7_col3 {
#   background-color: #d7eaff;
# }
# #T_cf8e6_row7_col4 {
#   background-color: #cce5ff;
# }
# #T_cf8e6_row7_col6 {
#   background-color: #a1d0ff;
# }
# #T_cf8e6_row7_col9 {
#   background-color: #fafcff;
# }
# #T_cf8e6_row8_col0 {
#   background-color: #eaf4ff;
# }
# #T_cf8e6_row8_col1 {
#   background-color: #f1f8ff;
# }
# #T_cf8e6_row8_col3 {
#   background-color: #fbfdff;
# }
# #T_cf8e6_row8_col6 {
#   background-color: #f6faff;
# }
# #T_cf8e6_row8_col9 {
#   background-color: #e5f2ff;
# }
# #T_cf8e6_row9_col5 {
#   background-color: #f9fcff;
# }
# #T_cf8e6_row9_col8 {
#   background-color: #edf6ff;
# }
# </style>
# <table id="T_cf8e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf8e6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cf8e6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cf8e6_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cf8e6_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cf8e6_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_cf8e6_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_cf8e6_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_cf8e6_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_cf8e6_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_cf8e6_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf8e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf8e6_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_cf8e6_row0_col1" class="data row0 col1" >2.100000</td>
#       <td id="T_cf8e6_row0_col2" class="data row0 col2" >1.010000</td>
#       <td id="T_cf8e6_row0_col3" class="data row0 col3" >2.060000</td>
#       <td id="T_cf8e6_row0_col4" class="data row0 col4" >2.270000</td>
#       <td id="T_cf8e6_row0_col5" class="data row0 col5" >1.630000</td>
#       <td id="T_cf8e6_row0_col6" class="data row0 col6" >1.970000</td>
#       <td id="T_cf8e6_row0_col7" class="data row0 col7" >0.530000</td>
#       <td id="T_cf8e6_row0_col8" class="data row0 col8" >2.580000</td>
#       <td id="T_cf8e6_row0_col9" class="data row0 col9" >2.800000</td>
#     </tr>
#     <tr>
#       <th id="T_cf8e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf8e6_row1_col0" class="data row1 col0" >2.100000</td>
#       <td id="T_cf8e6_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cf8e6_row1_col2" class="data row1 col2" >2.060000</td>
#       <td id="T_cf8e6_row1_col3" class="data row1 col3" >1.770000</td>
#       <td id="T_cf8e6_row1_col4" class="data row1 col4" >2.310000</td>
#       <td id="T_cf8e6_row1_col5" class="data row1 col5" >1.870000</td>
#       <td id="T_cf8e6_row1_col6" class="data row1 col6" >1.820000</td>
#       <td id="T_cf8e6_row1_col7" class="data row1 col7" >1.970000</td>
#       <td id="T_cf8e6_row1_col8" class="data row1 col8" >2.410000</td>
#       <td id="T_cf8e6_row1_col9" class="data row1 col9" >2.540000</td>
#     </tr>
#     <tr>
#       <th id="T_cf8e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf8e6_row2_col0" class="data row2 col0" >1.010000</td>
#       <td id="T_cf8e6_row2_col1" class="data row2 col1" >2.060000</td>
#       <td id="T_cf8e6_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cf8e6_row2_col3" class="data row2 col3" >1.950000</td>
#       <td id="T_cf8e6_row2_col4" class="data row2 col4" >2.140000</td>
#       <td id="T_cf8e6_row2_col5" class="data row2 col5" >1.610000</td>
#       <td id="T_cf8e6_row2_col6" class="data row2 col6" >2.140000</td>
#       <td id="T_cf8e6_row2_col7" class="data row2 col7" >1.130000</td>
#       <td id="T_cf8e6_row2_col8" class="data row2 col8" >2.460000</td>
#       <td id="T_cf8e6_row2_col9" class="data row2 col9" >2.630000</td>
#     </tr>
#     <tr>
#       <th id="T_cf8e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf8e6_row3_col0" class="data row3 col0" >2.060000</td>
#       <td id="T_cf8e6_row3_col1" class="data row3 col1" >1.770000</td>
#       <td id="T_cf8e6_row3_col2" class="data row3 col2" >1.950000</td>
#       <td id="T_cf8e6_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cf8e6_row3_col4" class="data row3 col4" >2.190000</td>
#       <td id="T_cf8e6_row3_col5" class="data row3 col5" >2.050000</td>
#       <td id="T_cf8e6_row3_col6" class="data row3 col6" >2.210000</td>
#       <td id="T_cf8e6_row3_col7" class="data row3 col7" >1.990000</td>
#       <td id="T_cf8e6_

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
