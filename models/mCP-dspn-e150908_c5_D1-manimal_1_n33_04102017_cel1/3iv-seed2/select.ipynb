# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150908_c5_D1, &nbsp; animal_1_n33_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n33_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_504.soma.v': 'expdata/ECall_IV_ch3_504.dat',
    'IV_506.soma.v': 'expdata/ECall_IV_ch3_506.dat',
    'IV_508.soma.v': 'expdata/ECall_IV_ch3_508.dat',
    'IV_510.soma.v': 'expdata/ECall_IV_ch3_510.dat',
    'IV_512.soma.v': 'expdata/ECall_IV_ch3_512.dat',
    'IV_514.soma.v': 'expdata/ECall_IV_ch3_514.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n33_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -85.0
#     g_pas.all: ['all'] g_pas = [1e-06, 0.002]
#     e_pas.all: ['all'] e_pas = [-100, -60]
#     cm.all: ['all'] cm = [1.5, 2.5]
#     Ra.all: ['all'] Ra = [100, 300]
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.02]
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.002]

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# Ra.all
# cm.all
# e_pas.all
# g_pas.all
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.all        0.0004538 0.0004479 0.0004565 0.0003928 0.0004889 0.0004314
# e_pas.all           -60.01    -60.43     -60.8    -60.55    -60.02    -60.07
# cm.all               2.199     2.367     2.358     2.482     2.301     2.448
# Ra.all               151.5     171.2     127.3     100.7     175.3     151.8
# gbar_kir.somatic   0.01068   0.01047  0.009686      0.01  0.008302   0.01063
# gbar_kir.basal   4.554e-05 2.847e-05 0.0001597 5.697e-05 0.0003854 6.629e-06
#
#                          6         7         8         9
# g_pas.all         0.000403  0.000457 0.0005128 0.0004571
# e_pas.all           -60.55    -60.05    -60.19    -60.04
# cm.all               2.494     2.443     2.341     2.216
# Ra.all               101.2     115.1       174     143.7
# gbar_kir.somatic   0.01007  0.008835  0.009775   0.01096
# gbar_kir.basal   5.697e-05 0.0003034 0.0002331 2.876e-05

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_cb92f_row0_col0, #T_cb92f_row1_col1, #T_cb92f_row2_col2, #T_cb92f_row3_col3, #T_cb92f_row4_col4, #T_cb92f_row5_col5, #T_cb92f_row6_col6, #T_cb92f_row7_col7, #T_cb92f_row8_col8, #T_cb92f_row9_col9 {
#   background-color: #007fff;
# }
# #T_cb92f_row0_col1 {
#   background-color: #46a2ff;
# }
# #T_cb92f_row0_col2 {
#   background-color: #9ccdff;
# }
# #T_cb92f_row0_col3, #T_cb92f_row0_col6 {
#   background-color: #4da6ff;
# }
# #T_cb92f_row0_col4, #T_cb92f_row2_col1, #T_cb92f_row3_col4, #T_cb92f_row6_col4, #T_cb92f_row8_col6 {
#   background-color: #d0e7ff;
# }
# #T_cb92f_row0_col5 {
#   background-color: #c3e0ff;
# }
# #T_cb92f_row0_col7 {
#   background-color: #c7e3ff;
# }
# #T_cb92f_row0_col8, #T_cb92f_row3_col8, #T_cb92f_row5_col9 {
#   background-color: #b6daff;
# }
# #T_cb92f_row0_col9 {
#   background-color: #42a0ff;
# }
# #T_cb92f_row1_col0 {
#   background-color: #4ca5ff;
# }
# #T_cb92f_row1_col2 {
#   background-color: #c2e0ff;
# }
# #T_cb92f_row1_col3, #T_cb92f_row1_col6 {
#   background-color: #85c2ff;
# }
# #T_cb92f_row1_col4, #T_cb92f_row1_col7 {
#   background-color: #e2f0ff;
# }
# #T_cb92f_row1_col5, #T_cb92f_row9_col5 {
#   background-color: #a3d1ff;
# }
# #T_cb92f_row1_col8, #T_cb92f_row9_col8 {
#   background-color: #d4e9ff;
# }
# #T_cb92f_row1_col9 {
#   background-color: #1c8dff;
# }
# #T_cb92f_row2_col0, #T_cb92f_row3_col7, #T_cb92f_row6_col7 {
#   background-color: #b5daff;
# }
# #T_cb92f_row2_col3 {
#   background-color: #9bcdff;
# }
# #T_cb92f_row2_col4 {
#   background-color: #75b9ff;
# }
# #T_cb92f_row2_col5 {
#   background-color: #f1f8ff;
# }
# #T_cb92f_row2_col6 {
#   background-color: #98cbff;
# }
# #T_cb92f_row2_col7 {
#   background-color: #54a9ff;
# }
# #T_cb92f_row2_col8, #T_cb92f_row7_col8, #T_cb92f_row8_col4 {
#   background-color: #43a0ff;
# }
# #T_cb92f_row2_col9 {
#   background-color: #cae4ff;
# }
# #T_cb92f_row3_col0, #T_cb92f_row6_col0 {
#   background-color: #4fa7ff;
# }
# #T_cb92f_row3_col1, #T_cb92f_row6_col1 {
#   background-color: #7ebeff;
# }
# #T_cb92f_row3_col2 {
#   background-color: #89c3ff;
# }
# #T_cb92f_row3_col5, #T_cb92f_row6_col5 {
#   background-color: #d5eaff;
# }
# #T_cb92f_row3_col6, #T_cb92f_row6_col3 {
#   background-color: #0380ff;
# }
# #T_cb92f_row3_col9 {
#   background-color: #71b7ff;
# }
# #T_cb92f_row4_col0, #T_cb92f_row4_col1, #T_cb92f_row4_col5, #T_cb92f_row4_col9, #T_cb92f_row5_col2, #T_cb92f_row5_col3, #T_cb92f_row5_col4, #T_cb92f_row5_col6, #T_cb92f_row5_col7, #T_cb92f_row5_col8 {
#   background-color: #ffffff;
# }
# #T_cb92f_row4_col2 {
#   background-color: #7bbcff;
# }
# #T_cb92f_row4_col3, #T_cb92f_row4_col6 {
#   background-color: #f8fbff;
# }
# #T_cb92f_row4_col7, #T_cb92f_row7_col4, #T_cb92f_row8_col7 {
#   background-color: #419fff;
# }
# #T_cb92f_row4_col8 {
#   background-color: #45a2ff;
# }
# #T_cb92f_row5_col0 {
#   background-color: #eff7ff;
# }
# #T_cb92f_row5_col1 {
#   background-color: #b8dbff;
# }
# #T_cb92f_row6_col2 {
#   background-color: #86c2ff;
# }
# #T_cb92f_row6_col8 {
#   background-color: #b3d9ff;
# }
# #T_cb92f_row6_col9 {
#   background-color: #6eb6ff;
# }
# #T_cb92f_row7_col0 {
#   background-color: #f2f8ff;
# }
# #T_cb92f_row7_col1, #T_cb92f_row7_col5 {
#   background-color: #fcfdff;
# }
# #T_cb92f_row7_col2 {
#   background-color: #57abff;
# }
# #T_cb92f_row7_col3, #T_cb92f_row7_col6 {
#   background-color: #d6eaff;
# }
# #T_cb92f_row7_col9 {
#   background-color: #f3f9ff;
# }
# #T_cb92f_row8_col0 {
#   background-color: #d8ebff;
# }
# #T_cb92f_row8_col1 {
#   background-color: #e7f3ff;
# }
# #T_cb92f_row8_col2 {
#   background-color: #44a1ff;
# }
# #T_cb92f_row8_col3 {
#   background-color: #d3e9ff;
# }
# #T_cb92f_row8_col5 {
#   background-color: #f7fbff;
# }
# #T_cb92f_row8_col9, #T_cb92f_row9_col4 {
#   background-color: #e4f1ff;
# }
# #T_cb92f_row9_col0 {
#   background-color: #49a3ff;
# }
# #T_cb92f_row9_col1 {
#   background-color: #1d8dff;
# }
# #T_cb92f_row9_col2 {
#   background-color: #bfdfff;
# }
# #T_cb92f_row9_col3 {
#   background-color: #79bbff;
# }
# #T_cb92f_row9_col6 {
#   background-color: #76baff;
# }
# #T_cb92f_row9_col7 {
#   background-color: #dcedff;
# }
# </style>
# <table id="T_cb92f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb92f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cb92f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cb92f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cb92f_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_cb92f_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_cb92f_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_cb92f_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_cb92f_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_cb92f_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_cb92f_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb92f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb92f_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_cb92f_row0_col1" class="data row0 col1" >0.240000</td>
#       <td id="T_cb92f_row0_col2" class="data row0 col2" >0.570000</td>
#       <td id="T_cb92f_row0_col3" class="data row0 col3" >0.250000</td>
#       <td id="T_cb92f_row0_col4" class="data row0 col4" >0.800000</td>
#       <td id="T_cb92f_row0_col5" class="data row0 col5" >0.750000</td>
#       <td id="T_cb92f_row0_col6" class="data row0 col6" >0.250000</td>
#       <td id="T_cb92f_row0_col7" class="data row0 col7" >0.760000</td>
#       <td id="T_cb92f_row0_col8" class="data row0 col8" >0.680000</td>
#       <td id="T_cb92f_row0_col9" class="data row0 col9" >0.230000</td>
#     </tr>
#     <tr>
#       <th id="T_cb92f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb92f_row1_col0" class="data row1 col0" >0.240000</td>
#       <td id="T_cb92f_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cb92f_row1_col2" class="data row1 col2" >0.710000</td>
#       <td id="T_cb92f_row1_col3" class="data row1 col3" >0.430000</td>
#       <td id="T_cb92f_row1_col4" class="data row1 col4" >0.870000</td>
#       <td id="T_cb92f_row1_col5" class="data row1 col5" >0.630000</td>
#       <td id="T_cb92f_row1_col6" class="data row1 col6" >0.430000</td>
#       <td id="T_cb92f_row1_col7" class="data row1 col7" >0.860000</td>
#       <td id="T_cb92f_row1_col8" class="data row1 col8" >0.790000</td>
#       <td id="T_cb92f_row1_col9" class="data row1 col9" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_cb92f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb92f_row2_col0" class="data row2 col0" >0.570000</td>
#       <td id="T_cb92f_row2_col1" class="data row2 col1" >0.710000</td>
#       <td id="T_cb92f_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cb92f_row2_col3" class="data row2 col3" >0.500000</td>
#       <td id="T_cb92f_row2_col4" class="data row2 col4" >0.450000</td>
#       <td id="T_cb92f_row2_col5" class="data row2 col5" >0.930000</td>
#       <td id="T_cb92f_row2_col6" class="data row2 col6" >0.490000</td>
#       <td id="T_cb92f_row2_col7" class="data row2 col7" >0.320000</td>
#       <td id="T_cb92f_row2_col8" class="data row2 col8" >0.250000</td>
#       <td id="T_cb92f_row2_col9" class="data row2 col9" >0.700000</td>
#     </tr>
#     <tr>
#       <th id="T_cb92f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb92f_row3_col0" class="data row3 col0" >0.250000</td>
#       <td id="T_cb92f_row3_col1" class="data row3 col1" >0.430000</td>
#       <td id="T_cb92f_row3_col2" class="data row3 col2" >0.500000</td>
#       <td id="T_cb92f_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_cb92f_row3_col4" class="data row3 col4" >0.800000</td>
#       <td id="T_cb92f_row3_col5" class="data row3 col5" >0.820000</td>
#       <td id="T_cb92f_row3_col6" class="data row3 col6" >0.010000</td>
#       <td id="T_cb92f_row3_col7" class="data row3 col7" >0.690000</td>
#       <td id="T_cb92f_row3_col8" class="data row3 col8" >0.680000</td>
#       <td id="T_cb92f_row3_col9" class="data row3 col9" >0.390000</td>
#     </tr>
#     <tr>
#       <th id="T_cb92f_level0_row4" class="row_heading

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
