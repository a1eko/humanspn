# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 150908_c5_D1, &nbsp; animal_1_n33_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n33_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_506.soma.v': 'expdata/ECall_IV_ch3_506.dat',
    'IV_514.soma.v': 'expdata/ECall_IV_ch3_514.dat',    
    'IDthresh-sub_545.soma.v': 'expdata/ECall_IDthresh_ch3_545.dat',    
    'IDthresh_546.soma.v': 'expdata/ECall_IDthresh_ch3_546.dat',    
    'IDthresh_547.soma.v': 'expdata/ECall_IDthresh_ch3_547.dat',    
    'IDthresh_553.soma.v': 'expdata/ECall_IDthresh_ch3_553.dat',    
    'IDthresh_563.soma.v': 'expdata/ECall_IDthresh_ch3_563.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n33_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     naf.somatic: naf at ['somatic']
#     kaf.somatic: kaf at ['somatic']
#     kas.somatic: kas at ['somatic']
#     kdr.somatic: kdr at ['somatic']
#     kir.somatic: kir at ['somatic']
#     cal12.somatic: cal12 at ['somatic']
#     cal13.somatic: cal13 at ['somatic']
#     can.somatic: can at ['somatic']
#     car.somatic: car at ['somatic']
#     cadyn.somatic: cadyn at ['somatic']
#     caldyn.somatic: caldyn at ['somatic']
#     sk.somatic: sk at ['somatic']
#     bk.somatic: bk at ['somatic']
#     Im.somatic: Im at ['somatic']
#     naf.axonal: naf at ['axonal']
#     kas.axonal: kas at ['axonal']
#     Im.axonal: Im at ['axonal']
#     naf.basal: naf at ['basal']
#     kaf.basal: kaf at ['basal']
#     kas.basal: kas at ['basal']
#     kdr.basal: kdr at ['basal']
#     kir.basal: kir at ['basal']
#     cal12.basal: cal12 at ['basal']
#     cal13.basal: cal13 at ['basal']
#     car.basal: car at ['basal']
#     cat32.basal: cat32 at ['basal']
#     cat33.basal: cat33 at ['basal']
#     cadyn.basal: cadyn at ['basal']
#     caldyn.basal: caldyn at ['basal']
#     sk.basal: sk at ['basal']
#     bk.basal: bk at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -86.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-80, -60]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ena.all: ['all'] ena = 53.34
#     ek.all: ['all'] ek = -105.9
#     gbar_naf.axonal: ['axonal'] gbar_naf = [0, 10]
#     gbar_kas.axonal: ['axonal'] gbar_kas = [0, 0.2]
#     gbar_Im.axonal: ['axonal'] gbar_Im = [0.001, 0.2]
#     gbar_naf.somatic: ['somatic'] gbar_naf = [0, 20]
#     gbar_kaf.somatic: ['somatic'] gbar_kaf = [0, 5.0]
#     q_kaf.somatic: ['somatic'] q_kaf = 1
#     gbar_kas.somatic: ['somatic'] gbar_kas = [0, 0.1]
#     gbar_kdr.somatic: ['somatic'] gbar_kdr = [0, 0.002]
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0.003, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20.0
#     q_kir.somatic: ['somatic'] q_kir = 1
#     pbar_cal12.somatic: ['somatic'] pbar_cal12 = 1e-05
#     pbar_cal13.somatic: ['somatic'] pbar_cal13 = 1e-06
#     pbar_can.somatic: ['somatic'] pbar_can = 3e-05
#     pbar_car.somatic: ['somatic'] pbar_car = 0.0001
#     taur_cadyn.somatic: ['somatic'] taur_cadyn = 14
#     gbar_bk.somatic: ['somatic'] gbar_bk = [0.0001, 0.002]
#     q_bk.somatic: ['somatic'] q_bk = 1
#     gbar_sk.somatic: ['somatic'] gbar_sk = [0.0001, 0.002]
#     q_sk.somatic: ['somatic'] q_sk = 1
#     gbar_Im.somatic: ['somatic'] gbar_Im = [0.0001, 0.01]
#     gbar_naf.basal: ['basal'] gbar_naf = [0.0, 0.2]
#     gbar_kaf.basal: ['basal'] gbar_kaf = [0.0, 0.5]
#     q_kaf.basal: ['basal'] q_kaf = 1
#     gbar_kas.basal: ['basal'] gbar_kas = [0, 0.01]
#     gbar_kdr.basal: ['basal'] gbar_kdr = [0, 0.002]
#     gbar_kir.basal: ['basal'] gbar_kir = [0.0001, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20.0
#     q_kir.basal: ['basal'] q_kir = 1
#     pbar_cal12.basal: ['basal'] pbar_cal12 = 1e-05
#     pbar_cal13.basal: ['basal'] pbar_cal13 = 1e-06
#     pbar_car.basal: ['basal'] pbar_car = 0.0001
#     pbar_cat32.basal: ['basal'] pbar_cat32 = 2e-09
#     pbar_cat33.basal: ['basal'] pbar_cat33 = 2e-09
#     taur_cadyn.basal: ['basal'] taur_cadyn = 14
#     gbar_bk.basal: ['basal'] gbar_bk = [0, 0.002]
#     q_bk.basal: ['basal'] q_bk = 1
#     gbar_sk.basal: ['basal'] gbar_sk = [0, 0.002]
#     q_sk.basal: ['basal'] q_sk = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_Im.axonal
# gbar_Im.somatic
# gbar_bk.basal
# gbar_bk.somatic
# gbar_kaf.basal
# gbar_kaf.somatic
# gbar_kas.axonal
# gbar_kas.basal
# gbar_kas.somatic
# gbar_kdr.basal
# gbar_kdr.somatic
# gbar_kir.basal
# gbar_kir.somatic
# gbar_naf.axonal
# gbar_naf.basal
# gbar_naf.somatic
# gbar_sk.basal
# gbar_sk.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.00362  0.008918   0.01161   0.01036  0.008098  0.008098
# g_pas.somatic     0.003176  0.003827  0.003923  0.004515  0.004024  0.004645
# g_pas.basal      5.404e-05 3.616e-05 1.146e-05 1.476e-05 3.616e-05 3.625e-05
# e_pas.all           -62.59    -62.22     -62.5    -63.33    -62.23    -62.95
# gbar_naf.axonal     0.8312     9.297     3.395      4.76     8.375     8.583
# gbar_kas.axonal    0.06528   0.08046   0.08377    0.1872   0.06593   0.07699
# gbar_Im.axonal      0.1577    0.1988   0.08392   0.06817       0.2    0.1998
# gbar_naf.somatic     14.78      12.1     12.38     12.48     11.93     12.08
# gbar_kaf.somatic    0.9647    0.4433    0.6203    0.5718    0.4433    0.3629
# gbar_kas.somatic  0.003208  0.001659 0.0002002   0.00019  0.001659  0.002689
# gbar_kdr.somatic 0.0004043 0.0005336 0.0007286 0.0001784 0.0004715 0.0004715
# gbar_kir.somatic   0.01361    0.0396   0.03914   0.03524    0.0394   0.03793
# gbar_bk.somatic  0.0003182 0.0001203 0.0002376 0.0001013 0.0001608 0.0001608
# gbar_sk.somatic  0.0001641 0.0001784 0.0002156 0.0001268 0.0002538 0.0005146
# gbar_Im.somatic   0.000159  0.001141  0.001503 0.0001247  0.000136 0.0001489
# gbar_naf.basal      0.1167    0.1527   0.09849    0.1375     0.159     0.159
# gbar_kaf.basal   0.0008389   0.01535 0.0001468 0.0005623   0.01535   0.01535
# gbar_kas.basal   0.0007949 8.637e-05 6.259e-06 0.0005991 4.515e-05 2.653e-05
# gbar_kdr.basal   0.0004394 0.0003974   0.00116  0.001544 0.0002631 0.0002631
# gbar_kir.basal    0.001694 0.0001237 0.0001001 0.0001356 0.0001632 0.0001632
# gbar_bk.basal     7.84e-06 7.333e-07 7.026e-08 5.404e-06 2.025e-07 2.189e-07
# gbar_sk.basal    1.022e-07 2.032e-06 3.182e-07 5.775e-07 1.966e-06 1.966e-06
#
#                          6         7         8         9
# g_pas.axonal      0.007803  0.008098  0.007287  0.009248
# g_pas.somatic     0.004024  0.004024  0.003209  0.004024
# g_pas.basal      3.079e-05 3.616e-05 0.0001703 2.724e-05
# e_pas.all           -62.71    -62.23    -62.52    -62.23
# gbar_naf.axonal      8.375     8.375     5.346     8.375
# gbar_kas.axonal    0.05535   0.06593    0.1272   0.06419
# gbar_Im.axonal      0.1576    0.1998    0.0765    0.1994
# gbar_naf.somatic     12.01      12.1      12.1      12.1
# gbar_kaf.somatic    0.4543    0.4433    0.6242    0.4433
# gbar_kas.somatic  0.000224  0.001659 0.0001633  0.002175
# gbar_kdr.somatic 0.0004882 0.0004715 0.0002179   0.00123
# gbar_kir.somatic    0.0394    0.0394   0.03747    0.0394
# gbar_bk.somatic  0.0001087 0.0001608 0.0001059 0.0001203
# gbar_sk.somatic  0.0001931 0.0001931 0.0001016 0.0001815
# gbar_Im.somatic  0.0004393 0.0001609  0.002758 0.0005777
# gbar_naf.basal      0.1527     0.159    0.1538    0.1442
# gbar_kaf.basal     0.01535   0.01535  0.002071   0.01535
# gbar_kas.basal    6.38e-05 6.821e-05 1.963e-05 6.821e-05
# gbar_kdr.basal   0.0001904 0.0002631 0.0009744 0.0002631
# gbar_kir.basal   0.0001037 0.0001632 0.0001066 0.0001632
# gbar_bk.basal     5.97e-07 2.025e-07 5.847e-06 1.257e-07
# gbar_sk.basal    2.054e-06 1.966e-06 3.199e-07 1.659e-06

# %%
axs = bm.hist(grid=False, xrot=30, figsize=(8,8))
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
axs = bm.hist(bins=1, grid=False, xrot=30, figsize=(8,8))
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_ad61e_row0_col0, #T_ad61e_row1_col1, #T_ad61e_row2_col2, #T_ad61e_row3_col3, #T_ad61e_row4_col4, #T_ad61e_row5_col5, #T_ad61e_row6_col6, #T_ad61e_row7_col7, #T_ad61e_row8_col8, #T_ad61e_row9_col9 {
#   background-color: #007fff;
# }
# #T_ad61e_row0_col1, #T_ad61e_row0_col2, #T_ad61e_row0_col4, #T_ad61e_row0_col5, #T_ad61e_row0_col6, #T_ad61e_row0_col7, #T_ad61e_row0_col8, #T_ad61e_row0_col9, #T_ad61e_row2_col0, #T_ad61e_row9_col3 {
#   background-color: #ffffff;
# }
# #T_ad61e_row0_col3, #T_ad61e_row4_col0 {
#   background-color: #e9f4ff;
# }
# #T_ad61e_row1_col0, #T_ad61e_row1_col3, #T_ad61e_row3_col7, #T_ad61e_row3_col9 {
#   background-color: #f0f7ff;
# }
# #T_ad61e_row1_col2 {
#   background-color: #d5eaff;
# }
# #T_ad61e_row1_col4 {
#   background-color: #74b9ff;
# }
# #T_ad61e_row1_col5 {
#   background-color: #83c0ff;
# }
# #T_ad61e_row1_col6 {
#   background-color: #64b1ff;
# }
# #T_ad61e_row1_col7, #T_ad61e_row5_col9, #T_ad61e_row7_col6 {
#   background-color: #6cb5ff;
# }
# #T_ad61e_row1_col8 {
#   background-color: #daecff;
# }
# #T_ad61e_row1_col9 {
#   background-color: #61afff;
# }
# #T_ad61e_row2_col1, #T_ad61e_row6_col3 {
#   background-color: #e2f0ff;
# }
# #T_ad61e_row2_col3, #T_ad61e_row8_col1 {
#   background-color: #d6eaff;
# }
# #T_ad61e_row2_col4 {
#   background-color: #edf6ff;
# }
# #T_ad61e_row2_col5 {
#   background-color: #ebf4ff;
# }
# #T_ad61e_row2_col6 {
#   background-color: #d1e8ff;
# }
# #T_ad61e_row2_col7 {
#   background-color: #f3f8ff;
# }
# #T_ad61e_row2_col8 {
#   background-color: #cae4ff;
# }
# #T_ad61e_row2_col9 {
#   background-color: #d5e9ff;
# }
# #T_ad61e_row3_col0 {
#   background-color: #d3e9ff;
# }
# #T_ad61e_row3_col1 {
#   background-color: #e8f3ff;
# }
# #T_ad61e_row3_col2 {
#   background-color: #c2e0ff;
# }
# #T_ad61e_row3_col4 {
#   background-color: #f1f7ff;
# }
# #T_ad61e_row3_col5, #T_ad61e_row9_col0 {
#   background-color: #f5faff;
# }
# #T_ad61e_row3_col6 {
#   background-color: #d0e7ff;
# }
# #T_ad61e_row3_col8 {
#   background-color: #b9dcff;
# }
# #T_ad61e_row4_col1 {
#   background-color: #70b7ff;
# }
# #T_ad61e_row4_col2, #T_ad61e_row6_col8 {
#   background-color: #d9ecff;
# }
# #T_ad61e_row4_col3, #T_ad61e_row7_col8 {
#   background-color: #f3f9ff;
# }
# #T_ad61e_row4_col5 {
#   background-color: #3599ff;
# }
# #T_ad61e_row4_col6 {
#   background-color: #71b7ff;
# }
# #T_ad61e_row4_col7 {
#   background-color: #1c8dff;
# }
# #T_ad61e_row4_col8 {
#   background-color: #f2f8ff;
# }
# #T_ad61e_row4_col9 {
#   background-color: #5aacff;
# }
# #T_ad61e_row5_col0, #T_ad61e_row7_col3 {
#   background-color: #eff7ff;
# }
# #T_ad61e_row5_col1 {
#   background-color: #82c0ff;
# }
# #T_ad61e_row5_col2 {
#   background-color: #dcedff;
# }
# #T_ad61e_row5_col3 {
#   background-color: #fdfeff;
# }
# #T_ad61e_row5_col4 {
#   background-color: #369aff;
# }
# #T_ad61e_row5_col6 {
#   background-color: #83c1ff;
# }
# #T_ad61e_row5_col7 {
#   background-color: #4ba4ff;
# }
# #T_ad61e_row5_col8, #T_ad61e_row8_col7 {
#   background-color: #f8fbff;
# }
# #T_ad61e_row6_col0 {
#   background-color: #fcfdff;
# }
# #T_ad61e_row6_col1 {
#   background-color: #69b3ff;
# }
# #T_ad61e_row6_col2 {
#   background-color: #cee6ff;
# }
# #T_ad61e_row6_col4 {
#   background-color: #7abcff;
# }
# #T_ad61e_row6_col5 {
#   background-color: #8ac4ff;
# }
# #T_ad61e_row6_col7, #T_ad61e_row9_col6 {
#   background-color: #76baff;
# }
# #T_ad61e_row6_col9 {
#   background-color: #79bcff;
# }
# #T_ad61e_row7_col0 {
#   background-color: #e6f2ff;
# }
# #T_ad61e_row7_col1 {
#   background-color: #68b3ff;
# }
# #T_ad61e_row7_col2 {
#   background-color: #dbedff;
# }
# #T_ad61e_row7_col4 {
#   background-color: #1b8dff;
# }
# #T_ad61e_row7_col5 {
#   background-color: #48a3ff;
# }
# #T_ad61e_row7_col9 {
#   background-color: #51a8ff;
# }
# #T_ad61e_row8_col0 {
#   background-color: #ebf5ff;
# }
# #T_ad61e_row8_col2 {
#   background-color: #bbdcff;
# }
# #T_ad61e_row8_col3 {
#   background-color: #bcddff;
# }
# #T_ad61e_row8_col4, #T_ad61e_row8_col5 {
#   background-color: #f4f9ff;
# }
# #T_ad61e_row8_col6 {
#   background-color: #cbe5ff;
# }
# #T_ad61e_row8_col9 {
#   background-color: #ecf5ff;
# }
# #T_ad61e_row9_col1 {
#   background-color: #63b0ff;
# }
# #T_ad61e_row9_col2 {
#   background-color: #cce5ff;
# }
# #T_ad61e_row9_col4 {
#   background-color: #5eaeff;
# }
# #T_ad61e_row9_col5 {
#   background-color: #6fb6ff;
# }
# #T_ad61e_row9_col7 {
#   background-color: #57aaff;
# }
# #T_ad61e_row9_col8 {
#   background-color: #f6faff;
# }
# </style>
# <table id="T_ad61e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad61e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ad61e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ad61e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ad61e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ad61e_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_ad61e_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_ad61e_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_ad61e_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_ad61e_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_ad61e_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad61e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad61e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_ad61e_row0_col1" class="data row0 col1" >2.440000</td>
#       <td id="T_ad61e_row0_col2" class="data row0 col2" >2.590000</td>
#       <td id="T_ad61e_row0_col3" class="data row0 col3" >2.150000</td>
#       <td id="T_ad61e_row0_col4" class="data row0 col4" >2.370000</td>
#       <td id="T_ad61e_row0_col5" class="data row0 col5" >2.430000</td>
#       <td id="T_ad61e_row0_col6" class="data row0 col6" >2.560000</td>
#       <td id="T_ad61e_row0_col7" class="data row0 col7" >2.340000</td>
#       <td id="T_ad61e_row0_col8" class="data row0 col8" >2.390000</td>
#       <td id="T_ad61e_row0_col9" class="data row0 col9" >2.490000</td>
#     </tr>
#     <tr>
#       <th id="T_ad61e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad61e_row1_col0" class="data row1 col0" >2.440000</td>
#       <td id="T_ad61e_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_ad61e_row1_col2" class="data row1 col2" >2.170000</td>
#       <td id="T_ad61e_row1_col3" class="data row1 col3" >2.220000</td>
#       <td id="T_ad61e_row1_col4" class="data row1 col4" >1.080000</td>
#       <td id="T_ad61e_row1_col5" class="data row1 col5" >1.250000</td>
#       <td id="T_ad61e_row1_col6" class="data row1 col6" >1.010000</td>
#       <td id="T_ad61e_row1_col7" class="data row1 col7" >1.000000</td>
#       <td id="T_ad61e_row1_col8" class="data row1 col8" >2.050000</td>
#       <td id="T_ad61e_row1_col9" class="data row1 col9" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_ad61e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad61e_row2_col0" class="data row2 col0" >2.590000</td>
#       <td id="T_ad61e_row2_col1" class="data row2 col1" >2.170000</td>
#       <td id="T_ad61e_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_ad61e_row2_col3" class="data row2 col3" >1.980000</td>
#       <td id="T_ad61e_row2_col4" class="data row2 col4" >2.210000</td>
#       <td id="T_ad61e_row2_col5" class="data row2 col5" >2.240000</td>
#       <td id="T_ad61e_row2_col6" class="data row2 col6" >2.100000</td>
#       <td id="T_ad61e_row2_col7" class="data row2 col7" >2.230000</td>
#       <td id="T_ad61e_row2_col8" class="data row2 col8" >1.900000</td>
#       <td id="T_ad61e_row2_col9" class="data row2 col9" >2.080000</td>
#     </tr>
#     <tr>
#       <th id="T_ad61e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad61e_row3_col0" class="data row3 col0" >2.150000</td>
#       <td id="T_ad61e_row3_col1" class="data row3 col1" >2.220000</td>
#       <td id="T_ad61e_row3_col2" class="data row3 col2" >1.980000</td>
#       <td id="T_ad61e_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_ad61e_row3_col4" class="data row3 col4" >2.240000</td>
#       <td id="T_ad61e_row3_col5" class="data row3 col5" >2.340000</td>
#       <td id="T_ad61e_row3_col6" cla

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)
