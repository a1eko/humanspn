# %% [markdown]
# <h3 align="right">mCP, &nbsp; dSPN, &nbsp; 160118_c8_D1, &nbsp; animal_1_n27_04102017_cel1 </h3>

# %% [markdown]
# # Model selection

# %% [markdown]
# ## Model data

# %%
import cell_model, cell_evaluator
morphofile = 'morphology/animal_1_n27_04102017_cel1.swc'
parameters = cell_model.define_parameters('parameters.json')
mechanisms = cell_model.define_mechanisms('mechanisms.json')
protocols = cell_evaluator.define_protocols('protocols.json')
calculator = cell_evaluator.define_fitness_calculator(protocols, 'features.json')
expdata = {
    'IV_546.soma.v': 'expdata/ECall_IV_ch5_546.dat',
    'IV_548.soma.v': 'expdata/ECall_IV_ch5_548.dat',
    'IV_550.soma.v': 'expdata/ECall_IV_ch5_550.dat',
    'IV_552.soma.v': 'expdata/ECall_IV_ch5_552.dat',
    'IV_554.soma.v': 'expdata/ECall_IV_ch5_554.dat',
    'IV_556.soma.v': 'expdata/ECall_IV_ch5_556.dat',    
}

# %% [markdown]
# ## Simulation environment

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import json
import pandas
import efel
import numpy as np
import bluepyopt as bpopt
import bluepyopt.ephys as ephys

# %%
from utils import *

# %%
# %%capture
# !rm -rf x86_64
# !nrnivmodl mechanisms

# %% [markdown]
# ## Cell model definition

# %%
morphology = ephys.morphologies.NrnFileMorphology(
    morphofile, do_replace_axon=True)

# %%
cell = ephys.models.CellModel(
    'dspn', 
    morph=morphology, 
    mechs=mechanisms, 
    params=parameters)
print (cell)
# Out:
# dspn:
#   morphology:
#     morphology/animal_1_n27_04102017_cel1.swc
#   mechanisms:
#     pas.all: pas at ['all']
#     kir.somatic: kir at ['somatic']
#     kir.basal: kir at ['basal']
#   params:
#     celsius: celsius = 35
#     v_init: v_init = -85.0
#     g_pas.axonal: ['axonal'] g_pas = [1e-05, 0.02]
#     g_pas.somatic: ['somatic'] g_pas = [1e-05, 0.01]
#     g_pas.basal: ['basal'] g_pas = [1e-05, 0.01]
#     e_pas.all: ['all'] e_pas = [-90, -50]
#     cm.axonal: ['axonal'] cm = 1
#     cm.somatic: ['somatic'] cm = 1
#     cm.basal: ['basal'] cm = 1
#     Ra.all: ['all'] Ra = 150.0
#     ek.somatic: ['somatic'] ek = -105.9
#     ek.basal: ['basal'] ek = -105.9
#     gbar_kir.somatic: ['somatic'] gbar_kir = [0, 0.1]
#     shift_kir.somatic: ['somatic'] shift_kir = -20
#     q_kir.somatic: ['somatic'] q_kir = 1
#     gbar_kir.basal: ['basal'] gbar_kir = [0, 0.01]
#     shift_kir.basal: ['basal'] shift_kir = -20
#     q_kir.basal: ['basal'] q_kir = 1

# %%
opt_params = [p.name for p in cell.params.values() if not p.frozen]
opt_bounds = [p.bounds for p in cell.params.values() if not p.frozen]
for x in sorted(opt_params): print (x)
# Out:
# e_pas.all
# g_pas.axonal
# g_pas.basal
# g_pas.somatic
# gbar_kir.basal
# gbar_kir.somatic

# %% [markdown]
# ## Cell evaluator

# %%
simulator = ephys.simulators.NrnSimulator()

# %%
evaluator = ephys.evaluators.CellEvaluator(
    cell_model=cell,
    param_names=opt_params,
    fitness_protocols=protocols,
    fitness_calculator=calculator,
    sim=simulator)

# %% [markdown]
# ## Optimisation results

# %%
with open('log.json') as fp:
    log = json.load(fp)

# %%
plot_log(log)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
best_models = json.load(open('best_models.json'))
pandas.options.display.float_format = '{:,.4g}'.format
bm = pandas.DataFrame(best_models)
bm.T
# Out:
#                          0         1         2         3         4         5  \
# g_pas.axonal       0.01156  0.002984  0.001704  0.006123  0.005977  0.006727
# g_pas.somatic    0.0002825 1.099e-05 0.0005296 3.251e-05 6.138e-05 1.874e-05
# g_pas.basal      0.0001041   0.00014 0.0001394 0.0001415 0.0001425 0.0001425
# e_pas.all           -89.39    -88.94    -88.63       -90    -89.97       -90
# gbar_kir.somatic  0.001933  0.001573  0.005119  0.004991  0.005145  0.005135
# gbar_kir.basal   0.0005686 0.0006462 0.0003829 0.0002902 0.0002831  0.000288
#
#                          6         7         8         9
# g_pas.axonal      0.006209  0.006305  0.006123  0.006305
# g_pas.somatic    1.071e-05 7.801e-05 1.053e-05 3.292e-05
# g_pas.basal      0.0001426 0.0001317 0.0001426 0.0001317
# e_pas.all              -90    -89.99       -90    -89.99
# gbar_kir.somatic  0.004955  0.004909  0.004944  0.004948
# gbar_kir.basal   0.0002902 0.0002922 0.0002902 0.0002902

# %%
axs = bm.hist(grid=False, xrot=20)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axs = bm.hist(bins=1, grid=False, xrot=20)
for ax, bounds in zip(axs.flatten(), opt_bounds):
        ax.set_xlim(bounds)
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
evaluate_all = True
best_objectives = []
if evaluate_all:
    for params in best_models:
        objectives = evaluator.evaluate_with_dicts(params)
        best_objectives.append(objectives)
    df = pandas.DataFrame(best_objectives).T
    df = df.sort_index(axis=0, ascending=False)

# %%
if evaluate_all:
    plot_scores(df, figsize=(6, 8), vmin=0, vmax=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Single-cell simulation

# %%
ind = 0
test_parameters = best_models[ind]

# %%
test_responses = evaluator.run_protocols(
    protocols=protocols.values(), 
    param_values=test_parameters)

# %%
plot_responses(test_responses, expdata=expdata, junction_potential=11.5, figsize=(6,12))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
if evaluate_all:
    objectives = best_objectives[ind]
else:
    objectives = evaluator.evaluate_with_dicts(test_parameters)
plot_objectives(objectives, figsize=(6,8))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from numpy.linalg import norm
d = []
for i in range(len(best_models)):
    v = []
    for j in range(len(best_models)):
        p1 = np.array([best_models[i][p] for p in sorted(best_models[i])])
        p2 = np.array([best_models[j][p] for p in sorted(best_models[j])])
        v.append(norm((p1-p2)/(p1+p2)))
    d.append(v)
df = pandas.DataFrame(data=np.round(d,2))
def highlight_low(x):
    def c(v):
        r = int(v/x.max()*255)
        g = int(v/x.max()*128)+127
        b = 255
        return '#%02x%02x%02x' % (r, g, b)
    return ['background-color: %s' % c(v) for v in x]
df.style.apply(highlight_low)
# Out:
# <style type="text/css">
# #T_8dd88_row0_col0, #T_8dd88_row1_col1, #T_8dd88_row2_col2, #T_8dd88_row3_col3, #T_8dd88_row4_col4, #T_8dd88_row5_col5, #T_8dd88_row6_col6, #T_8dd88_row7_col7, #T_8dd88_row8_col8, #T_8dd88_row9_col9 {
#   background-color: #007fff;
# }
# #T_8dd88_row0_col1, #T_8dd88_row2_col4, #T_8dd88_row5_col2 {
#   background-color: #f4f9ff;
# }
# #T_8dd88_row0_col2, #T_8dd88_row7_col2 {
#   background-color: #d0e7ff;
# }
# #T_8dd88_row0_col3 {
#   background-color: #f5faff;
# }
# #T_8dd88_row0_col4 {
#   background-color: #e8f3ff;
# }
# #T_8dd88_row0_col5, #T_8dd88_row6_col2 {
#   background-color: #f8fbff;
# }
# #T_8dd88_row0_col6, #T_8dd88_row0_col8, #T_8dd88_row1_col2, #T_8dd88_row1_col4, #T_8dd88_row1_col7, #T_8dd88_row2_col1, #T_8dd88_row2_col3, #T_8dd88_row2_col5, #T_8dd88_row2_col6, #T_8dd88_row2_col9, #T_8dd88_row6_col0, #T_8dd88_row8_col0 {
#   background-color: #ffffff;
# }
# #T_8dd88_row0_col7 {
#   background-color: #cee6ff;
# }
# #T_8dd88_row0_col9 {
#   background-color: #f2f8ff;
# }
# #T_8dd88_row1_col0 {
#   background-color: #fafcff;
# }
# #T_8dd88_row1_col3 {
#   background-color: #d3e9ff;
# }
# #T_8dd88_row1_col5 {
#   background-color: #b7dbff;
# }
# #T_8dd88_row1_col6, #T_8dd88_row1_col8 {
#   background-color: #a4d1ff;
# }
# #T_8dd88_row1_col9, #T_8dd88_row2_col0 {
#   background-color: #d6eaff;
# }
# #T_8dd88_row2_col7, #T_8dd88_row3_col0, #T_8dd88_row7_col1 {
#   background-color: #e6f2ff;
# }
# #T_8dd88_row2_col8 {
#   background-color: #fcfdff;
# }
# #T_8dd88_row3_col1 {
#   background-color: #c1e0ff;
# }
# #T_8dd88_row3_col2, #T_8dd88_row9_col2 {
#   background-color: #e9f3ff;
# }
# #T_8dd88_row3_col4, #T_8dd88_row9_col4 {
#   background-color: #4da5ff;
# }
# #T_8dd88_row3_col5 {
#   background-color: #3e9eff;
# }
# #T_8dd88_row3_col6 {
#   background-color: #70b7ff;
# }
# #T_8dd88_row3_col7, #T_8dd88_row9_col7 {
#   background-color: #63b0ff;
# }
# #T_8dd88_row3_col8, #T_8dd88_row9_col6 {
#   background-color: #73b8ff;
# }
# #T_8dd88_row3_col9, #T_8dd88_row9_col3 {
#   background-color: #0983ff;
# }
# #T_8dd88_row4_col0 {
#   background-color: #d1e8ff;
# }
# #T_8dd88_row4_col1 {
#   background-color: #e0efff;
# }
# #T_8dd88_row4_col2 {
#   background-color: #d7ebff;
# }
# #T_8dd88_row4_col3, #T_8dd88_row4_col9 {
#   background-color: #4aa4ff;
# }
# #T_8dd88_row4_col5 {
#   background-color: #7cbdff;
# }
# #T_8dd88_row4_col6 {
#   background-color: #9dceff;
# }
# #T_8dd88_row4_col7 {
#   background-color: #1f8eff;
# }
# #T_8dd88_row4_col8, #T_8dd88_row6_col1, #T_8dd88_row8_col1 {
#   background-color: #a0cfff;
# }
# #T_8dd88_row5_col0 {
#   background-color: #f3f9ff;
# }
# #T_8dd88_row5_col1 {
#   background-color: #afd7ff;
# }
# #T_8dd88_row5_col3, #T_8dd88_row6_col5, #T_8dd88_row9_col5 {
#   background-color: #409fff;
# }
# #T_8dd88_row5_col4 {
#   background-color: #87c2ff;
# }
# #T_8dd88_row5_col6 {
#   background-color: #3f9eff;
# }
# #T_8dd88_row5_col7 {
#   background-color: #96caff;
# }
# #T_8dd88_row5_col8 {
#   background-color: #419fff;
# }
# #T_8dd88_row5_col9 {
#   background-color: #43a0ff;
# }
# #T_8dd88_row6_col3 {
#   background-color: #78bbff;
# }
# #T_8dd88_row6_col4 {
#   background-color: #aed6ff;
# }
# #T_8dd88_row6_col7, #T_8dd88_row8_col7 {
#   background-color: #b8dbff;
# }
# #T_8dd88_row6_col8, #T_8dd88_row8_col6 {
#   background-color: #0280ff;
# }
# #T_8dd88_row6_col9, #T_8dd88_row8_col3 {
#   background-color: #7abcff;
# }
# #T_8dd88_row7_col0 {
#   background-color: #bfdfff;
# }
# #T_8dd88_row7_col3, #T_8dd88_row7_col9 {
#   background-color: #62b0ff;
# }
# #T_8dd88_row7_col4 {
#   background-color: #208fff;
# }
# #T_8dd88_row7_col5 {
#   background-color: #8ec6ff;
# }
# #T_8dd88_row7_col6, #T_8dd88_row7_col8 {
#   background-color: #abd5ff;
# }
# #T_8dd88_row8_col2 {
#   background-color: #f6faff;
# }
# #T_8dd88_row8_col4 {
#   background-color: #b1d8ff;
# }
# #T_8dd88_row8_col5 {
#   background-color: #42a0ff;
# }
# #T_8dd88_row8_col9 {
#   background-color: #7dbdff;
# }
# #T_8dd88_row9_col0 {
#   background-color: #e3f1ff;
# }
# #T_8dd88_row9_col1 {
#   background-color: #c3e1ff;
# }
# #T_8dd88_row9_col8 {
#   background-color: #75b9ff;
# }
# </style>
# <table id="T_8dd88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dd88_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8dd88_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8dd88_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_8dd88_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_8dd88_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_8dd88_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_8dd88_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_8dd88_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_8dd88_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_8dd88_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dd88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8dd88_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_8dd88_row0_col1" class="data row0 col1" >1.110000</td>
#       <td id="T_8dd88_row0_col2" class="data row0 col2" >0.950000</td>
#       <td id="T_8dd88_row0_col3" class="data row0 col3" >1.020000</td>
#       <td id="T_8dd88_row0_col4" class="data row0 col4" >0.930000</td>
#       <td id="T_8dd88_row0_col5" class="data row0 col5" >1.080000</td>
#       <td id="T_8dd88_row0_col6" class="data row0 col6" >1.130000</td>
#       <td id="T_8dd88_row0_col7" class="data row0 col7" >0.850000</td>
#       <td id="T_8dd88_row0_col8" class="data row0 col8" >1.130000</td>
#       <td id="T_8dd88_row0_col9" class="data row0 col9" >1.010000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8dd88_row1_col0" class="data row1 col0" >1.110000</td>
#       <td id="T_8dd88_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_8dd88_row1_col2" class="data row1 col2" >1.160000</td>
#       <td id="T_8dd88_row1_col3" class="data row1 col3" >0.880000</td>
#       <td id="T_8dd88_row1_col4" class="data row1 col4" >1.020000</td>
#       <td id="T_8dd88_row1_col5" class="data row1 col5" >0.800000</td>
#       <td id="T_8dd88_row1_col6" class="data row1 col6" >0.730000</td>
#       <td id="T_8dd88_row1_col7" class="data row1 col7" >1.050000</td>
#       <td id="T_8dd88_row1_col8" class="data row1 col8" >0.730000</td>
#       <td id="T_8dd88_row1_col9" class="data row1 col9" >0.890000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8dd88_row2_col0" class="data row2 col0" >0.950000</td>
#       <td id="T_8dd88_row2_col1" class="data row2 col1" >1.160000</td>
#       <td id="T_8dd88_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8dd88_row2_col3" class="data row2 col3" >1.060000</td>
#       <td id="T_8dd88_row2_col4" class="data row2 col4" >0.980000</td>
#       <td id="T_8dd88_row2_col5" class="data row2 col5" >1.110000</td>
#       <td id="T_8dd88_row2_col6" class="data row2 col6" >1.130000</td>
#       <td id="T_8dd88_row2_col7" class="data row2 col7" >0.950000</td>
#       <td id="T_8dd88_row2_col8" class="data row2 col8" >1.120000</td>
#       <td id="T_8dd88_row2_col9" class="data row2 col9" >1.060000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8dd88_row3_col0" class="data row3 col0" >1.020000</td>
#       <td id="T_8dd88_row3_col1" class="data row3 col1" >0.880000</td>
#       <td id="T_8dd88_row3_col2" class="data row3 col2" >1.060000</td>
#       <td id="T_8dd88_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_8dd88_row3_col4" class="data row3 col4" >0.310000</td>
#       <td id="T_8dd88_row3_col5" class="data row3 col5" >0.270000</td>
#       <td id="T_8dd88_row3_col6" class="data row3 col6" >0.500000</td>
#       <td id="T_8dd88_row3_col7" class="data row3 col7" >0.410000</td>
#       <td id="T_8dd88_row3_col8" class="data row3 col8" >0.510000</td>
#       <td id="T_8dd88_row3_col9" class="data row3 col9" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd88_level0_row4" class="row_heading

# %%
hall_of_fame = []
selected = range(10)
for model in selected:
    hall_of_fame.append(best_models[model])
with open('hall_of_fame.json', 'w') as fp:
    json.dump(hall_of_fame, fp, indent=4, sort_keys=True)

# %%
e_pas = np.mean([x['e_pas.all'] for x in best_models])
#Ra = np.mean([x['Ra.all'] for x in best_models])
#shift_kir = np.mean([x['shift_kir.somatic'] for x in best_models] + [x['shift_kir.basal'] for x in best_models])

# %%
print(f'{e_pas=}')
# Out:
# e_pas=-89.69063087459045

# %%
best_models[0]['e_pas.all'] #, best_models[0]['shift_kir.somatic']
# Out:
# -89.38879800633171
